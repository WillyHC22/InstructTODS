# %%
import os
import ast
import json
import string
import openai
import numpy as np
import pandas as pd

from tqdm import tqdm
from langchain import PromptTemplate

from src.DST.evaluate_utils import remapping
from src.DST.dst import SLOTS_DESCRIPTIONS, SLOTS_REVERSE_REMAPPING
from src.config import CONFIG

from dataclasses import dataclass, field
from typing import Optional
from transformers import TrainingArguments
from src.DST.evaluate_utils import unpack_belief_states, fix_typos, nested_fix, remapping


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 500)



@dataclass
class ModelArguments:
    """
    Arguments pertaining to which model/config/tokenizer we are going to utilize.
    """
    model_name_or_path: Optional[str] = field(
        default=None,
        metadata={"help": "The path of the HuggingFace model."}
    )
    model_name_or_path_agent: Optional[str] = field(
        default=None,
        metadata={"help": "The path of the HuggingFace model for the agent"}
    )
    use_int8: Optional[bool] = field(
        default=False,
        metadata={"help": "Whether to use int8 model or not."}
    )
    use_deepspeed: Optional[bool] = field(
        default=False,
        metadata={"help": "Whether to use deepspeed model or not."}
    )
    
    

@dataclass
class DataArguments:
    """
    Arguments pertaining to the data loading and preprocessing pipeline.
    """
    dataset_name: Optional[str] = field(
        default=None,
        metadata={"help": "Train dataset path"}
    )
    dataset_names: Optional[str] = field(
        default=None,
        metadata={"help": "Train dataset paths"}
    )
    root_data_path: Optional[str] = field(
        default="./data", metadata={"help": "The path to the data directory."},
    )
    mwoz_path: Optional[str] = field(
        default="/home/willy/instructod/MultiWOZ_2.1/",
        metadata={"help": "MWOZ path"}
    )
    dialog_history_limit_dst: Optional[int] = field(
        default=0,
        metadata={"help": "Lenght of dialogue history for dst"}
    )
    dialog_history_limit_dst_recorrect: Optional[int] = field(
        default=0,
        metadata={"help": "Lenght of dialogue history for dst update"}
    )
    dialog_history_limit_rg: Optional[int] = field(
        default=20,
        metadata={"help": "Lenght of dialogue history for response generation"}
    )
    dialog_history_limit_e2e: Optional[int] = field(
        default=20,
        metadata={"help": "Lenght of dialogue history for e2e"}
    )
    single_domain_only: Optional[bool] = field(
        default=False,
        metadata={"help": "Whether to keep only the single domain sample or not"}
    )
    with_slot_description: Optional[bool] = field(
        default=False,
        metadata={"help": "Whether to use slot description or not for DST"}
    )
    with_slot_domain_diff: Optional[bool] = field(
        default=False,
        metadata={"help": "differentiation between slot and domain"}
    )
    with_all_slots: Optional[bool] = field(
        default=True,
        metadata={"help": "Whether to use all slots or not"}
    )
    debug_mode: Optional[bool] = field(
        default=False,
        metadata={"help": "debug mode to only try 20 samples"}
    )
    start_idx: Optional[int] = field(
        default=0,
        metadata={"help": "Starting index to restart the prediction if needed"}
    )
    save_path: Optional[str] = field(
        default="results/",
        metadata={"help": "save path"}
    )
    save_every: Optional[int] = field(
        default=5,
        metadata={"help": "every step to save in case api fail"}
    )
    db_format_type: Optional[str] = field(
        default="1",
        metadata={"help": "1 is more precise, 2 is more concise for db integration"},
    )
    load_path: Optional[str] = field(
        default="results/",
        metadata={"help": "load path"}
    )
    agent_max_iterations: Optional[int] = field(
        default=5,
        metadata={"help": "Max number of iterations for agents in e2e (higher=better but more expensive)"}
    )
    verbose: Optional[bool] = field(
        default=False,
        metadata={"help": "verbosity for agent call in database retrieval"}
    )
    do_inference: Optional[bool] = field(
        default=False,
        metadata={"help": "use to do inference with the e2e agent setting"}
    )
    accumulate_bs: Optional[bool] = field(
        default=False,
        metadata={"help": "evaluation setting to accumulate all turn-level bs"}
    )   
    with_slot_filtering: Optional[bool] = field(
        default=False,
        metadata={"help": "slot filtering during DST eval (filter non-existent slots)"}
    )   
    

@dataclass
class PromptingArguments(TrainingArguments):
    """
    Arguments pertraining to the prompting pipeline.
    """
    output_dir: Optional[str] = field(
        default="./out",
        metadata={"help": "Output directory"},
    )
    task: Optional[str] = field(
        default="dst",
        metadata={"help": "Task to perform"}
    )
    max_requests_per_minute: Optional[int] = field(
        default=20,
        metadata={"help": "Max number of requests for OpenAI API."}
    )
    openai_api_key_name: Optional[str] = field(
        default="OPENAI_API_KEY",
        metadata={"help": "OpenAI API key name."}
    )

class PromptConstructor():
    def __init__(self, 
                 config):
        self.config = config
        self.instructions = config["INSTRUCTIONS"]
        self.prompt_templates = config["PROMPT_TEMPLATES"]
        self.examples = config["EXAMPLES"]
        
    def _get_slots_from_domains(self, domains, ontology, with_slot_description, with_all_slots, with_slot_domain_diff):
        
        if with_all_slots:
            domains = ["restaurant", "train", "attraction", "hotel", "taxi"]
        
        slots = []
        for slot in list(ontology.keys()):
            splitted_slot = slot.split("-")
            if splitted_slot[0] in domains:
                if with_slot_domain_diff:
                    if splitted_slot[-1] not in slots:
                        slots.append(splitted_slot[-1])
                else:
                    slots.append(splitted_slot[0] + "-" + splitted_slot[-1])
        
        slots_info = []
        added_slots = []
        if with_slot_description:
            for slot in slots:
                splitted_slot = slot.split("-")
                if with_slot_domain_diff:
                    if slot in added_slots:
                        continue
                    slots_info.append(f"name: {slot}, description: {SLOTS_DESCRIPTIONS[slot.lower()]}")
                    added_slots.append(slot)
                else:
                    slots_info.append(f"name: {slot}, description: {SLOTS_DESCRIPTIONS[splitted_slot[1].lower()]}")

                    
            slots = slots_info
        
        slots_prompt = "\n".join(slots)
        if with_slot_domain_diff:
            return slots_prompt + f"\n\nDOMAINS: {', '.join(domains)}"
        else:
            return slots_prompt
            
                
                
#         if with_all_slots:
#             domains = "all"
        
#         if with_slot_description:
#             with_req_inf_differentiation = False #Slot description is the discriminator

#         if domains == "all":
#             if with_req_inf_differentiation:
#                 req_slots = ", ".join(self.config["multiwoz21"]["all_requestable_slots"])
#                 inf_slots = ", ".join(self.config["multiwoz21"]["all_informable_slots"])
#             else:
#                 slots = set(self.config["multiwoz21"]["all_requestable_slots"] + 
#                             self.config["multiwoz21"]["all_informable_slots"])
#                 slots = ", ".join(slots)
#         elif not isinstance(domains, list):
#             raise ValueError("""Provided domain should be either 'all' or list of valid domain names:
#                                 - for multiwoz2.1 and 2.4: taxi, restaurant, hotel, train, attraction""")
#         else:
#             req_slots = ""
#             inf_slots = ""
#             domain_req_slots = []
#             domain_inf_slots = []
#             for domain in domains:
#                 domain_req_slots += self.config["multiwoz21"]["requestable_slots"][domain]
#                 domain_inf_slots += self.config["multiwoz21"]["informable_slots"][domain]
#             if with_req_inf_differentiation:
#                 domain_req_slots = set(domain_req_slots)
#                 domain_inf_slots = set(domain_inf_slots)
#                 req_slots += ", ".join(domain_req_slots)
#                 inf_slots += ", ".join(domain_inf_slots)
#             else:
#                 slots = set(domain_req_slots + domain_inf_slots)
#                 slots = ", ".join(slots)

#         if with_req_inf_differentiation:
#             slots_info = f"Requestable slots: {req_slots}\nInformable slots: {inf_slots}"
#         else:
#             slots_info = f"{slots}"

#         if with_slot_description:
#             slots = slots.split(", ")
#             slots_info = ""
#             for slot in slots:
#                 if slot not in self.config["multiwoz21"]["all_informable_slots"]:
#                     continue
#                 slots_info += f"name: {slot}, description: {SLOTS_DESCRIPTIONS[slot]}\n"
#             slots_info = slots_info[:-2]
        
#         return slots_info
    
    
    def _build_prompt(self, mode="", example="", dialogue_context="", ontology="", slots="", dialogue_acts="", belief_states="", database=""):
        prompt = ""
        if mode == "dst":
            instruction = self.instructions["instruction_with_slots"]
            template_variables = self.prompt_templates["template_with_slots"]
            template = PromptTemplate(input_variables= template_variables["input_variables"],
                                      template = template_variables["template"])
            prompt = template.format(instruction=instruction,
                                     slots=slots,
                                     example=example,
                                     dialogue_context=dialogue_context)
            
        elif mode == "dst_recorrect":
            instruction = self.instructions["instruction_with_slots_recorrect"]
            template_variables = self.prompt_templates["template_with_slots_recorrect"]
            template = PromptTemplate(input_variables= template_variables["input_variables"],
                                      template = template_variables["template"])            
            prompt = template.format(instruction=instruction,
                                    slots=slots,
                                    dialogue_context=dialogue_context,
                                    belief_states=belief_states)
            
        elif mode == "database_query":
            instruction = self.instructions["instruction_query_database"]
            template_variables = self.prompt_templates["template_query_database"]
            template = PromptTemplate(input_variables= template_variables["input_variables"],
                                      template = template_variables["template"])
            prompt = template.format(instruction=instruction,
                                     belief_states=belief_states)
            
        elif mode == "response_generation":
            example = self.config["EXAMPLES"]["response_generation"]
            
            instruction = self.instructions["instruction_response_generation"]
            template_variables = self.prompt_templates["template_response_generation"]
            template = PromptTemplate(input_variables = template_variables["input_variables"],
                                      template = template_variables["template"])
            prompt = template.format(instruction=instruction,
                                     example=example,
                                     dialogue_context=dialogue_context)
        elif mode == "e2e":
            instruction = self.instructions["instruction_e2e"]
            template_variables = self.prompt_templates["template_e2e"]
            template = PromptTemplate(input_variables = template_variables["input_variables"],
                                      template = template_variables["template"])
            prompt = template.format(instruction=instruction,
                                     database=database,
                                     dialogue_context=dialogue_context)

        else:
            raise ValueError("'mode' should be one of: [dst, dst_recorrect, database_query, response_generation, e2e]")
        
        return prompt


class MWOZ_Dataset(PromptConstructor):
    def __init__(self,
                 config,
                 data_args):
        PromptConstructor.__init__(self, config)
        self.dataset = {"id":[],
                        "dialogue_id":[],
                        "dialogue_context":[],
                        "turn":[],
                        "prompt_dst":[],
                        "prompt_dst_update":[],
                        "prompt_rg":[],
                        "prompt_e2e":[],
                        "domains":[],
                        "turn_domain":[],
                        "gold_turn_bs":[],
                        "gold_bs":[],
                        "gold_act":[],
                        "gold_response":[],
                        "gold_database_result":[],
                        }
        
        print("Loading data...")
        self.all_data, self.testfiles, self.system_acts, self.ontology = self._get_mwoz_data(data_args.mwoz_path)
        print("Loading databases...")
        self.dbs_lexicalized = self._get_dbs_lexicalized(data_args.mwoz_path, data_args.db_format_type)
        self.idx = 0
        self.dialog_history_limit_dst = data_args.dialog_history_limit_dst
        self.dialog_history_limit_rg = data_args.dialog_history_limit_rg
        self.dialog_history_limit_e2e = data_args.dialog_history_limit_e2e
        self.single_domain_only = data_args.single_domain_only
        self.with_slot_description = data_args.with_slot_description
        self.with_slot_domain_diff = data_args.with_slot_domain_diff
        self.with_all_slots = data_args.with_all_slots
        self.all_domains = ["restaurant", "taxi", "hotel", "train", "attraction"]

        print("Processing mwoz...")
        for sample in tqdm(self.all_data):
            if sample in self.testfiles:
                dialogue_log = self.all_data[sample]["log"]
                self._process_dialogue_log(sample=sample,
                                           dialogue_log=dialogue_log)

        self.dataset = pd.DataFrame(self.dataset)
        if self.single_domain_only:
            for index, row in tqdm(self.dataset.iterrows()):
                if "sng" not in row["dialogue_id"].lower():
                    self.dataset.drop(index, inplace=True)

        for index, row in self.dataset.iterrows():
            if row["turn_domain"] == "":
                self.dataset.loc[index, 'turn_domain'] = row["domains"][0]

                    
    def _get_mwoz_data(self, mwoz_path):
        data_path = os.path.join(mwoz_path, "data.json")
        testListFile_path = os.path.join(mwoz_path, "testListFile.txt")
        system_acts_path = os.path.join(mwoz_path, "system_acts.json")
        ontology_path = os.path.join(mwoz_path, "ontology.json")

        with open(data_path, "r") as f:
            all_data = json.load(f)
            
        with open(testListFile_path, "r") as f:
            testfiles = f.read()
        testfiles = testfiles.split("\n")
        
        with open(system_acts_path, "r") as f:
            system_acts = json.load(f)
            
        with open(ontology_path, "r") as f:
            ontology = json.load(f)
            
        return all_data, testfiles, system_acts, ontology
    
    def _get_dbs_lexicalized(self, mwoz_path, format_type):
        domains = ["restaurant", "hotel", "train", "attraction"]
        keep_data = {"restaurant":["address", "area", "food", "name", "pricerange", "phone", "postcode"],
                    "attraction":["name", "area", "address", "type", "postcode"],
                    "hotel":["name", "address", "area", "phone", "postcode", "pricerange", "stars"],
                    "train":["departure", "destination"]}
        dbs_lexicalized = {}
        for domain in domains:
            db_path = os.path.join(mwoz_path, f"{domain}_db.json")
            with open(db_path, "r") as f:
                db_data = json.load(f)

            db_lexicalized = []
            if format_type == "1":
                for row in db_data:
                    row_keep = []
                    for key in keep_data[domain]:
                        if key in row:
                            row_keep.append(f"{key}: {row[key]}")
                    db_lexicalized.append(", ".join(row_keep))
            
            elif format_type == "2":
                #more concise db to fit in context length limit
                db_lexicalized.append(", ".join(keep_data[domain]))
                for row in db_data:
                    row_keep = []
                    for key in keep_data[domain]:
                        if key in row:
                            row_keep.append(f"{row[key]}")
                    db_lexicalized.append(", ".join(row_keep))
                    # db_lexicalized.append(", ".join([f"{row[key]}" for key in keep[domain]]))
            dbs_lexicalized[domain] = "\n".join(set(db_lexicalized))

        return dbs_lexicalized
    
    def _process_dialogue_log(self, sample, dialogue_log):

        dialog_history_memory_dst = []
        dialog_history_memory_rg = []
        dialog_history_memory_e2e = []
        dialog_history_dst = ""
        dialog_history_rg = ""
        dialog_history_e2e = ""
        turn_domain = ""
        domains = self._get_domains_from_log(dialogue_log)
        slots = self._get_slots_from_domains(domains=domains, 
                                             ontology=self.ontology,
                                             with_slot_description=self.with_slot_description,
                                             with_slot_domain_diff=self.with_slot_domain_diff,
                                             with_all_slots=self.with_all_slots) # or all
        if self.dialog_history_limit_dst == 0:
            example = self.examples["dst_dh0"]
        else:
            example = self.examples["dst_dh-1"]

        for turn_nb, turn in enumerate(dialogue_log):

            if turn_nb % 2 == 0:
                speaker = "USER"
            else:
                speaker = "SYSTEM"
            
            utterance = f"""{speaker}: {turn["text"]}\n"""
            dialog_act = turn["dialog_act"]
            cur_system_act = self.system_acts[sample.split(".")[0]][str((turn_nb//2)+1)]
            
            dialogue_context_dst = dialog_history_dst + utterance
            prompt_dst = self._build_prompt(mode="dst",
                                            slots=slots,
                                            example=example,
                                            dialogue_context=dialogue_context_dst)
            
            lexicalized_act = self._lexicalize_act(cur_system_act)
            dialogue_context_rg = dialog_history_rg + utterance + f"ACT:{lexicalized_act}\nSYSTEM:"
            prompt_rg = self._build_prompt(mode="response_generation",
                                            dialogue_context=dialogue_context_rg)
            
            dialogue_context_e2e = dialog_history_e2e + utterance + "SYSTEM:"
    
            turn_domain = self._get_domain_from_turn(turn_domain, cur_system_act)
            if turn_domain and turn_domain != "taxi":
                database = self.dbs_lexicalized[turn_domain]
            else:
                database = ""
            prompt_e2e = self._build_prompt(mode="e2e",
                                            database=database,
                                            dialogue_context=dialogue_context_e2e).replace("\n\n\n", "\n")

            dialog_history_dst, dialog_history_memory_dst = self._update_dialogue_memory(utterance, 
                                                                                         dialogue_log, 
                                                                                         self.dialog_history_limit_dst, 
                                                                                         dialog_history_memory_dst)
            dialog_history_rg, dialog_history_memory_rg = self._update_dialogue_memory(utterance, 
                                                                                       dialogue_log, 
                                                                                       self.dialog_history_limit_rg,
                                                                                       dialog_history_memory_rg)
            dialog_history_e2e, dialog_history_memory_e2e = self._update_dialogue_memory(utterance, 
                                                                                         dialogue_log, 
                                                                                         self.dialog_history_limit_e2e, 
                                                                                         dialog_history_memory_e2e) 
                
            metadata = turn["metadata"]
            bspn = {}
            if metadata:
                for domain in domains:
                    for k, v in metadata[domain].items():
                        for slot, value in v.items():
                            if isinstance(value, str) and value not in ["", "not mentioned", "none"]:
                                bspn[domain+"-"+slot] = value
            self.idx += 1
            if turn_nb % 2 == 0:
                self.dataset["gold_turn_bs"].append(dialog_act)
                self.dataset["dialogue_context"].append(dialogue_context_dst)
                self.dataset["gold_database_result"].append(None) 
                self.dataset["turn"].append(turn_nb//2)
                self.dataset["domains"].append(domains)
                self.dataset["id"].append(self.idx//2)
                self.dataset["dialogue_id"].append(sample)
                self.dataset["prompt_dst"].append(prompt_dst)
                self.dataset["prompt_dst_update"].append(prompt_dst)
                self.dataset["prompt_rg"].append(prompt_rg)
                self.dataset["prompt_e2e"].append(prompt_e2e)
                self.dataset["turn_domain"].append(turn_domain)
            else:
                self.dataset["gold_response"].append(utterance)
                self.dataset["gold_bs"].append(bspn)
                self.dataset["gold_act"].append(dialog_act)

    def _update_dialogue_memory(self, utterance, dialogue_log, dialog_history_limit, dialog_history_memory):
        if dialog_history_limit != 0:
            if dialog_history_limit == -1:
                dialog_history_limit = len(dialogue_log)
            if len(dialog_history_memory) >= dialog_history_limit:
                dialog_history_memory.pop(0)
            dialog_history_memory.append(utterance)

        dialog_history = "".join(dialog_history_memory)
        return dialog_history, dialog_history_memory
    
    def _lexicalize_act(self, act):
        if act == "No Annotation":
            return "None"
        
        lexicalized_acts = []
        lexicalize_mapping = {"leave": "leave time",
                              "arrive":"arrival time",
                              "departure":"departure place",
                              "post":"postcode",
                              "addr":"address"}

        for act, slot_values in act.items():


            if "request" in act.lower():
                requests = []
                for (slot, value) in slot_values:
                    slot = slot.lower()
                    if slot in lexicalize_mapping:
                        slot = lexicalize_mapping[slot]
                    if slot == "none":
                        break
                    else:
                        requests.append(slot)
                if requests:
                    lexicalized_act = "Request the user about " + ", ".join(requests) + "."
                    lexicalized_acts.append(lexicalized_act)

            elif "recommend" in act.lower():
                recommends = []
                for (slot, value) in slot_values:
                    slot, value = slot.lower(), value.lower()
                    if slot in lexicalize_mapping:
                        slot = lexicalize_mapping[slot]
                    if slot == "none":
                        break
                    else:
                        recommends.append(value)
                if recommends:
                    lexicalized_act = "Recommend the user for " + ", ".join(recommends) + "."
                    lexicalized_acts.append(lexicalized_act)

            elif "inform" in act.lower():
                informs = []
                for (slot, value) in slot_values:
                    slot, value = slot.lower(), value.lower()
                    if slot in lexicalize_mapping:
                        slot = lexicalize_mapping[slot]
                    if slot == "none":
                        break
                    else:
                        informs.append(f"the {slot} is {value}")
                if informs:
                    lexicalized_act = "Inform the user that " + ", ".join(informs) + "."  
                    lexicalized_acts.append(lexicalized_act)

            else:
                pass
        if lexicalized_acts:
            return " ".join(lexicalized_acts)
        else:
            return "None"
        
    def _get_domain_from_turn(self, domain, act):
        for k in act:
            turn_domain = k.lower().split("-")[0]
            if turn_domain in self.all_domains:
                return turn_domain
        return domain
            

    def _get_domains_from_log(self, dialogue_log):
        domains = []
        for log in dialogue_log:
            for domain_act in log["dialog_act"]:
                domain = domain_act.split("-")[0].lower()
                if domain in self.all_domains and domain not in domains:
                    domains.append(domain)
        return domains
                
                
def evaluate_dst(results_df, vocal=True, save_path=None):
    global_turns = 0    
    global_jga = 0
    results_single_domain = {"taxi":{"turns":0, "correct_turns_jga":0, "correct_slots":0, "total_slots":0, "slot_f1":0},
                            "restaurant":{"turns":0, "correct_turns_jga":0, "correct_slots":0, "total_slots":0, "slot_f1":0},
                            "hotel":{"turns":0, "correct_turns_jga":0, "correct_slots":0, "total_slots":0, "slot_f1":0},
                            "train":{"turns":0, "correct_turns_jga":0, "correct_slots":0, "total_slots":0, "slot_f1":0},
                            "attraction":{"turns":0, "correct_turns_jga":0, "correct_slots":0, "total_slots":0, "slot_f1":0},
                            "all":{"global_turns":0, "global_f1":0}}
    
    for _, row in results_df.iterrows():
        unpacked_gold = unpack_belief_states(row["gold_bs"], "gold")
        unpacked_pred = unpack_belief_states(row["preds"], "pred")
        domains = row["domains"]
        if isinstance(domains, str):
            domains = ast.literal_eval(domains)

        if set(unpacked_gold)==set(unpacked_pred):
            global_jga += 1
            if len(domains) == 1:
                results_single_domain[domains[0]]["correct_turns_jga"] += 1

        gold_values = [gold.split("-")[1] for gold in unpacked_gold]
        pred_values = [pred.split("-")[1] for pred in unpacked_pred]
        F1, recall, precision = compute_prf(gold_values, pred_values)
        if len(domains) == 1:
            results_single_domain[domains[0]]["slot_f1"] += F1
            results_single_domain[domains[0]]["turns"] += 1
        results_single_domain["all"]["global_f1"] += F1
        results_single_domain["all"]["global_turns"] += 1
        global_turns += 1

    total_single_domain_jga = 0
    total_single_domain_turns = 0
    for domain in results_single_domain:
        if domain == "all":
            continue
        domain_slot_f1 = results_single_domain[domain]["slot_f1"]
        domain_jga = results_single_domain[domain]["correct_turns_jga"]
        domain_turns = results_single_domain[domain]["turns"]
        total_single_domain_jga += domain_jga
        total_single_domain_turns += domain_turns
        results_single_domain[domain]["JGA"] = domain_jga/domain_turns
        results_single_domain[domain]["SLOT-F1"] = domain_slot_f1/domain_turns

        if vocal:
            print(f"""For {domain}, JGA: {results_single_domain[domain]["JGA"]} - SLOT-F1: {results_single_domain[domain]["SLOT-F1"]}""")
    jga_single_domain_average = total_single_domain_jga/total_single_domain_turns
    jga_average = global_jga/global_turns    
    slot_f1_average = results_single_domain["all"]["global_f1"] / results_single_domain["all"]["global_turns"]
    if vocal:
        print(f"""Average JGA in single domain samples only: {jga_single_domain_average}""")
        print(f"""Average JGA overall: {jga_average}""")
        print(f"""Average Slot F1 Overall: {slot_f1_average}""")

    results = results_single_domain
    results["JGA_single_domain_average"] = jga_single_domain_average
    results["JGA_average"] = jga_average

    return results


def completion(model, prompt):            
    completion = openai.ChatCompletion.create(
            model=model,
            messages=[
                {"role": "user", "content": prompt}
            ],
            temperature=0
        )
    response = completion.choices[0].message.content.strip()
    return response

# %%
model_args = ModelArguments()
data_args = DataArguments()
model_args.model_name_or_path_agent = "openai/gpt-3.5-turbo"
data_args.single_domain_only = False
data_args.dialog_history_limit_dst = 0
data_args.dialog_history_limit_e2e = -1
data_args.dialog_history_limit_rg = -1
data_args.with_slot_domain_diff = False
data_args.with_all_slots = False
data_args.with_slot_description = False

# %%
mwoz = MWOZ_Dataset(CONFIG, data_args)
dataset = mwoz.dataset
# Out:
# Loading data...
# Loading databases...
# Processing mwoz...
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 10438/10438 [00:02<00:00, 3960.57it/s]

# %%
def get_subset_multi(df):
    df['domain_length'] = df['domains'].apply(lambda x: len(x))
    filtered_df = df.loc[(df['domain_length'] == 2)].head(500).append(df.loc[(df['domain_length'] == 3)].head(500))
    return filtered_df

dataset = get_subset_multi(dataset)
# Out:
# /tmp/ipykernel_1792/3716848604.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   filtered_df = df.loc[(df['domain_length'] == 2)].head(500).append(df.loc[(df['domain_length'] == 3)].head(500))

# %%
vars(data_args)
# Out:
# {'dataset_name': None,
#  'dataset_names': None,
#  'root_data_path': './data',
#  'mwoz_path': '/home/willy/instructod/MultiWOZ_2.1/',
#  'dialog_history_limit_dst': 0,
#  'dialog_history_limit_dst_recorrect': 0,
#  'dialog_history_limit_rg': -1,
#  'dialog_history_limit_e2e': 5,
#  'single_domain_only': False,
#  'with_slot_description': False,
#  'with_req_inf_differentiation': False,
#  'with_all_slots': True,
#  'debug_mode': False,
#  'start_idx': 0,
#  'save_path': 'results/',
#  'save_every': 5,
#  'db_format_type': '1'}

# %% [markdown]
# ## Getting database as prompt

# %%
import json
domain = "attraction"
format = "1"
db = json.load(open(f"/home/willy/instructod/MultiWOZ_2.1/{domain}_db.json", "r"))
db_slots = []
for sample in db:
    for k, v in sample.items():
        if k not in db_slots:
            db_slots.append(k)

# %%
ontology = json.load(open("/home/willy/instructod/MultiWOZ_2.1/ontology.json", "r"))
slots = list(ontology.keys())
slots = [slot for slot in slots if "attraction" in slot]

# %%
slots
# Out:
# ['attraction-semi-area', 'attraction-semi-name', 'attraction-semi-type']

# %%
ontology["attraction-semi-area"]
# Out:
# ['north', 'centre|west', 'east', 'south', 'centre', 'west', 'dontcare']

# %%
print(db_slots)
# Out:
# ['address', 'area', 'entrance fee', 'id', 'location', 'name', 'openhours', 'phone', 'postcode', 'pricerange', 'type']

# %%
keep = {"restaurant":["name", "area", "food", "pricerange", "phone", "postcode"],
        "attraction":["name", "area", "type", "postcode"],
        "train":["departure", "destination", "leaveAt", "arriveBy", "day"]}
if format == "1":
    for row in db:
        row_keep = []
        for key in keep[domain]:
            if key in row:
                row_keep.append(f"{key}: {row[key]}")
        print(", ".join(row_keep))
                
elif format == "2":
    print(", ".join(keep[domain]))
    for row in db:
        row_keep = []
        for key in keep[domain]:
            if key in row:
                row_keep.append(f"{row[key]}")
        print(", ".join(row_keep))

# for row in db:
#     row_keep = []
#     for key in keep[domain]:
# Out:
# name: abbey pool and astroturf pitch, area: east, type: swimmingpool, postcode: cb58nt
# name: adc theatre, area: centre, type: theatre, postcode: cb58as
# name: all saints church, area: centre, type: architecture, postcode: cb58bs
# name: ballare, area: centre, type: nightclub, postcode: cb23na
# name: broughton house gallery, area: centre, type: museum, postcode: cb11ln
# name: byard art, area: south, type: museum, postcode: cb21sj
# name: cafe jello gallery, area: west, type: museum, postcode: cb30af
# name: camboats, area: east, type: boat, postcode: cb58sx
# name: cambridge and county folk museum, area: west, type: museum, postcode: cb30aq
# name: cambridge arts theatre, area: centre, type: theatre, postcode: cb23pj
# name: cambridge artworks, area: east, type: museum, postcode: cb13ef
# name: cambridge book and print gallery, area: west, type: museum, postcode: cb39ey
# name: cambridge contemporary art, area: centre, type: museum, postcode: cb21su
# name: cambridge museum of technology, area: east, type: museum, postcode: cb58ld
# name: cambridge university botanic gardens, area: centre, type: park, postcode: cb21jf
# name: castle galleries, area: centre, type: museum, postcode: cb23bj
# name: cherry hinton hall and grounds, area: east, type: entertainment, postcode: cb18dw
# name: cherry hinton water play, area: east, type: park, postcode: cb18dw
# name: christ's college, area: centre, type: college, postcode: cb23bu
# name: churchill college, area: west, type: college, postcode: cb30ds
# name: cineworld cinema, area: south, type: cinema, postcode: cb17dy
# name: clare college, area: west, type: college, postcode: cb21tl
# name: clare hall, area: west, type: college, postcode: cb39al
# name: club salsa, area: centre, type: nightclub, postcode: cb12jb
# name: corpus christi, area: centre, type: college, postcode: cb21rh
# name: downing college, area: centre, type: college, postcode: cb21dq
# name: emmanuel college, area: centre, type: college, postcode: cb23ap
# name: funky fun house, area: east, type: entertainment, postcode: cb58hy
# name: gallery at twelve a high street, area: east, type: museum, postcode: cb15dh
# name: gonville and caius college, area: centre, type: college, postcode: cb21ta
# name: great saint mary's church, area: centre, type: architecture, postcode: cb23pq
# name: holy trinity church, area: centre, type: architecture, postcode: cb23nz
# name: hughes hall, area: centre, type: college, postcode: cb12ew
# name: jesus college, area: centre, type: college, postcode: cb58bl
# name: jesus green outdoor pool, area: north, type: swimmingpool, postcode: cb43px
# name: kambar, area: centre, type: nightclub, postcode: cb23qb
# name: kettle's yard, area: west, type: museum, postcode: cb30aq
# name: king's college, area: centre, type: college, postcode: cb21st
# name: kings hedges learner pool, area: north, type: swimmingpool, postcode: cb42xh
# name: little saint mary's church, area: centre, type: architecture, postcode: cb21qy
# name: lynne strover gallery, area: west, type: museum, postcode: cb30aq
# name: magdalene college, area: west, type: college, postcode: cb30ag
# name: milton country park, area: north, type: park, postcode: cb46az
# name: mumford theatre, area: centre, type: theatre, postcode: cb11pt
# name: museum of archaelogy and anthropology, area: centre, type: museum, postcode: cb23dz
# name: museum of classical archaeology, area: west, type: museum, postcode: cb39da
# name: nusha, area: south, type: entertainment, postcode: cb17dy
# name: old schools, area: centre, type: architecture, postcode: cb21tt
# name: parkside pools, area: centre, type: swimmingpool, postcode: cb11ly
# name: pembroke college, area: centre, type: college, postcode: cb21rf
# name: people's portraits exhibition at girton college, area: west, type: museum, postcode: cb3ojg
# name: primavera, area: centre, type: museum, postcode: cb21sj
# name: queens' college, area: west, type: college, postcode: cb39et
# name: regency gallery, area: centre, type: museum, postcode: cb11er
# name: riverboat georgina, area: north, type: boat, postcode: cb43ax
# name: ruskin gallery, area: centre, type: museum, postcode: cb11pt
# name: saint barnabas press gallery, area: east, type: museum, postcode: cb13ew
# name: saint catharine's college, area: centre, type: college, postcode: cb21rl
# name: saint john's college, area: centre, type: college, postcode: cb21tp
# name: scott polar museum, area: centre, type: museum, postcode: cb21er
# name: scudamores punting co, area: centre, type: boat, postcode: cb21rs
# name: sheep's green and lammas land park fen causeway, area: south, type: park, postcode: cb22ad
# name: sidney sussex college, area: centre, type: college, postcode: cb23hu
# name: soul tree nightclub, area: centre, type: nightclub, postcode: cb23qf
# name: tenpin, area: south, type: entertainment, postcode: cb17dy
# name: the cambridge corn exchange, area: centre, type: theatre, postcode: cb23qe
# name: the cambridge punter, area: centre, type: boat, postcode: cb41as
# name: the cherry hinton village centre, area: east, type: mutliple sports, postcode: cb19ej
# name: the fez club, area: centre, type: nightclub, postcode: cb23hx
# name: the fitzwilliam museum, area: centre, type: museum, postcode: cb21rb
# name: the junction, area: south, type: theatre, postcode: cb17gx
# name: the man on the moon, area: centre, type: concerthall, postcode: cb12lf
# name: the place, area: south, type: nightclub, postcode: cb23hg
# name: trinity college, area: centre, type: college, postcode: cb21tq
# name: vue cinema, area: centre, type: cinema, postcode: cb11ps
# name: wandlebury country park, area: south, type: park, postcode: cb223ae
# name: whale of a time, area: west, type: entertainment, postcode: cb238el
# name: whipple museum of the history of science, area: centre, type: museum, postcode: cb23rh
# name: williams art and antiques, area: centre, type: museum, postcode: cb12lj

# %%
#Need to decide which keys per domain

# %%
file_path="/home/willy/instructod/MultiWOZ_2.1/train_db.json"
data = json.loads(Path(file_path).read_text())
df = pd.DataFrame(data)
df.head(2)
# Out:
#   arriveBy     day  departure         destination    duration leaveAt  \
# 0    05:51  monday  cambridge  london kings cross  51 minutes   05:00
# 1    07:51  monday  cambridge  london kings cross  51 minutes   07:00
#
#           price trainID
# 0  23.60 pounds  TR7075
# 1  23.60 pounds  TR2289

# %%
df["n"][0]
# Out:
# nan

# %% [markdown]
# ## Using SQL database

# %%
import sqlite3
attraction_db = json.load(open("/home/willy/instructod/MultiWOZ_2.1/attraction_db.json"))

# %%
# Connect to the database
conn = sqlite3.connect('attraction.db')
cursor = conn.cursor()

# Create the attraction table
cursor.execute("DROP TABLE IF EXISTS attraction")
cursor.execute("""CREATE TABLE attraction
                  (id INT PRIMARY KEY,
                   name TEXT,
                   address TEXT,
                   area TEXT,
                   postcode TEXT,
                   phone TEXT,
                   type TEXT,
                   entrance_fee TEXT,
                   price_range TEXT)""")

# Insert data into the table
for attraction in attraction_db:
    id = int(attraction["id"])
    name = attraction["name"]
    address = attraction["address"]
    area = attraction["area"]
    postcode = attraction["postcode"]
    phone = attraction["phone"]
    type = attraction["type"]
    entrance_fee = attraction["entrance fee"]
    price_range = attraction["pricerange"]
    
    cursor.execute("""
        INSERT INTO attraction VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (id, name, address, area, postcode, phone, type, entrance_fee, price_range))

# Commit the changes and close the connection
conn.commit()
conn.close()

# %%
from langchain.agents import create_sql_agent
from langchain.agents.agent_toolkits import SQLDatabaseToolkit
# from langchain.sql_database import SQLDatabase
from langchain import SQLDatabase
from langchain.llms.openai import OpenAI
# from langchain.chat_models import ChatOpenAI
from langchain.agents import AgentExecutor

llm = OpenAI(temperature=0)
# llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

db = SQLDatabase.from_uri("sqlite:////home/willy/instructod/attraction.db",
                         include_tables=['attraction'],
                         sample_rows_in_table_info=3)

toolkit = SQLDatabaseToolkit(db=db,
                             llm=llm)

agent_sql = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    max_iterations=5,
    verbose=True
)

# %%
print(db.table_info)
# Out:
# CREATE TABLE attraction (
# 	id INTEGER,
# 	name TEXT,
# 	address TEXT,
# 	area TEXT,
# 	postcode TEXT,
# 	phone TEXT,
# 	type TEXT,
# 	entrance_fee TEXT,
# 	price_range TEXT,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from attraction table:
# id	name	address	area	postcode	phone	type	entrance_fee	price_range
# 1	abbey pool and astroturf pitch	pool way, whitehill road, off newmarket road	east	cb58nt	01223902088	swimmingpool	?	?
# 2	adc theatre	park street	centre	cb58as	01223300085	theatre	?	?
# 3	all saints church	jesus lane	centre	cb58bs	01223452587	architecture	free	free
# */

# %% [markdown]
# ## Using dataframe agent directly

# %%
from langchain.agents import create_pandas_dataframe_agent
from langchain.llms.openai import OpenAI
from langchain.callbacks import get_openai_callback
from langchain.agents import AgentType

import json
from pathlib import Path
from pprint import pprint

from src.e2e.e2e_utils import E2E_InstrucTOD


file_path="/home/willy/instructod/MultiWOZ_2.1/restaurant_db.json"
data = json.loads(Path(file_path).read_text())
df = pd.DataFrame(data)
# df = df.drop(columns=["location"])
df = df.drop(columns=["location", "type", "introduction", "signature", "id"])


llm = OpenAI(model_name="gpt-3.5-turbo", temperature=0)
# llm = OpenAI(temperature=0)

agent_df = create_pandas_dataframe_agent(llm, df, max_iterations=5, verbose=True)
# Out:
# /home/willy/miniconda3/envs/instructod/lib/python3.9/site-packages/langchain/llms/openai.py:171: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /home/willy/miniconda3/envs/instructod/lib/python3.9/site-packages/langchain/llms/openai.py:740: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(

# %%
# Multi domain InstrucTOD
# instructod = E2E_InstrucTOD(CONFIG,
#                             model_args,
#                             data_args,
#                             dataset)
all_dbs = []
domains = ["attraction", "hotel", "restaurant", "train"]
for domain in domains:
    file_path=os.path.join(data_args.mwoz_path, f"{domain}_db.json")
    data = json.loads(Path(file_path).read_text())
    df = pd.DataFrame(data)
    if domain == "attraction":
        df = df.drop(columns=["location"])
    elif domain == "hotel":
        df = df.drop(columns=["location", "price", "n"])
        df['stars'] = df['stars'].astype(int)
        df = df[['name'] + [col for col in df.columns if col != 'name']]
    elif domain == "restaurant":
        df = df.drop(columns=["location", "type", "introduction", "signature", "id"])
        # df = df.rename(columns={'food': 'cuisine'})
        df = df[['name'] + [col for col in df.columns if col != 'name']]
    elif domain == "train":
        pass
    all_dbs.append(df)
    
agent_df = create_pandas_dataframe_agent(llm, all_dbs, max_iterations=5, verbose=True)

# %%
dummy_df = pd.DataFrame({"name":["The Inkshot", "Tattoo Party", "Pro Tattoo"],
                         "location":["123 avenue street", "92 street pop", "63 flash avenue"],
                         "colored ink":["yes", "no", "yes"],
                         "body parts":["head", "arm", "leg"],
                         "review":["good", "bad", "neutral"],
                         "laser removal":["yes", "yes", "yes"],})
agent_df = create_pandas_dataframe_agent(llm, dummy_df, max_iterations=5, verbose=False)

# %%
for idx, row in dataset.iterrows():
    if row["turn_domain"] == "attraction":
        prompt = dataset["prompt_e2e"][idx].split("\n\n")
        print(f"{prompt[0]}\n\n{prompt[-1]}")
        print("-------")
# Out:
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a place for entertainment? Something on the east side of town.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a place for entertainment? Something on the east side of town.
# SYSTEM: Cherry Hinton Hall and Grounds is on the east side of town, would you like their phone number?
# USER: Actually, can I get the address and postcode?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a place for entertainment? Something on the east side of town.
# SYSTEM: Cherry Hinton Hall and Grounds is on the east side of town, would you like their phone number?
# USER: Actually, can I get the address and postcode?
# SYSTEM: Yes, it's Cherry Hinton Road, cb18dw.
# USER: Can you tell me what the entrance fee is?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a place for entertainment? Something on the east side of town.
# SYSTEM: Cherry Hinton Hall and Grounds is on the east side of town, would you like their phone number?
# USER: Actually, can I get the address and postcode?
# SYSTEM: Yes, it's Cherry Hinton Road, cb18dw.
# USER: Can you tell me what the entrance fee is?
# SYSTEM: I'm sorry, the entrance fee isn't listed in my system.
# USER: OK, then that's all I need today. Thank you for your help!
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction called Williams Art and Antiques.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction called Williams Art and Antiques.
# SYSTEM: Williams art and antiques is at gwydir street, no. 5 dale's brewery.  Would you like me to book tickets?
# USER: No thank you. Just the area and postcode please.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction called Williams Art and Antiques.
# SYSTEM: Williams art and antiques is at gwydir street, no. 5 dale's brewery.  Would you like me to book tickets?
# USER: No thank you. Just the area and postcode please.
# SYSTEM: It is in the centre and the postcode is cb12lj.  Is there anything else you need help with today?
# USER: No that's all I needed. Thank you!
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for some info on an attraction called Kettle's Yard.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for some info on an attraction called Kettle's Yard.
# SYSTEM: Absolutely! The entrance is free! It is located in the west. The address is castle street!
# USER: Great thank you for all your help, that's all that I needed to know.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I am looking for a place to go!
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I am looking for a place to go!
# SYSTEM: I can certainly help you find something. Do you have a type of attraction in mind?
# USER: I like looking at the architecture of old buildings. I think it says a lot about how we used to live.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I am looking for a place to go!
# SYSTEM: I can certainly help you find something. Do you have a type of attraction in mind?
# USER: I like looking at the architecture of old buildings. I think it says a lot about how we used to live.
# SYSTEM: We have a lot of interesting architecture here in Cambridge. Is there a particular area of town you're interested in?
# USER: What would you suggest?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I am looking for a place to go!
# SYSTEM: I can certainly help you find something. Do you have a type of attraction in mind?
# USER: I like looking at the architecture of old buildings. I think it says a lot about how we used to live.
# SYSTEM: We have a lot of interesting architecture here in Cambridge. Is there a particular area of town you're interested in?
# USER: What would you suggest?
# SYSTEM: Here are a few suggestions from the centre: All Saint's Church and Holy Trinity Church, both are free to visit.
# USER: The Holy Trinity Church sounds lovely. Can you give me their postcode, please?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I am looking for a place to go!
# SYSTEM: I can certainly help you find something. Do you have a type of attraction in mind?
# USER: I like looking at the architecture of old buildings. I think it says a lot about how we used to live.
# SYSTEM: We have a lot of interesting architecture here in Cambridge. Is there a particular area of town you're interested in?
# USER: What would you suggest?
# SYSTEM: Here are a few suggestions from the centre: All Saint's Church and Holy Trinity Church, both are free to visit.
# USER: The Holy Trinity Church sounds lovely. Can you give me their postcode, please?
# SYSTEM: Yes, their postcode is cb23nz. Can I get any other information for you?
# USER: No that will be all. Thanks.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a boat to visit on the north side?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a boat to visit on the north side?
# SYSTEM: I have one in that area. It's called the Riverboat Georgina. It's located at Cambridge Passenger Cruisers, Jubilee House. Would you like their phone number for more information?
# USER: Yes, I want the phone number and also the entrance fee, please.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Could you help me find a boat to visit on the north side?
# SYSTEM: I have one in that area. It's called the Riverboat Georgina. It's located at Cambridge Passenger Cruisers, Jubilee House. Would you like their phone number for more information?
# USER: Yes, I want the phone number and also the entrance fee, please.
# SYSTEM: Their phone number is 01223902091 and we do not have the entrance fee in our database at this time.
# USER: Okay, that is all I need today. Thank you very much.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Can you see if there are any entertainment attractions in the centre of town?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Can you see if there are any entertainment attractions in the centre of town?
# SYSTEM: Unfortunately there are no entertainment attractions in the centre of town. Is there a different area of town that would work for you?
# USER: What about a museum?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Can you see if there are any entertainment attractions in the centre of town?
# SYSTEM: Unfortunately there are no entertainment attractions in the centre of town. Is there a different area of town that would work for you?
# USER: What about a museum?
# SYSTEM: Yes, there are 11 museums. I'd recommend Broughton House Gallery. It's at 98 King Street cb11ln and has free entrance. Would that work for you?
# USER: Yes, that will work great. Can I get their phone number please?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Can you see if there are any entertainment attractions in the centre of town?
# SYSTEM: Unfortunately there are no entertainment attractions in the centre of town. Is there a different area of town that would work for you?
# USER: What about a museum?
# SYSTEM: Yes, there are 11 museums. I'd recommend Broughton House Gallery. It's at 98 King Street cb11ln and has free entrance. Would that work for you?
# USER: Yes, that will work great. Can I get their phone number please?
# SYSTEM: Certainly. The Broughton House Gallery's phone number is 01223314960. Is there anything else I can help you with today?
# USER: No, that's all I need.  Thanks!
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello there! Can you tell me if there are any 4-star hotels or guesthouses in Cambridge that are cheap?
# SYSTEM: There are 21 locations, do you have any other requirements?
# USER: I am hoping it is a guesthouse
# SYSTEM:   There are 7 guesthouses meeting your requirements. Is there a particular area you wish to stay in?
# USER: No, as long as it's cheap and have 4 stars. Can you recommend me one and book it for 8 people and 3 nights starting Thursday?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello there! Can you tell me if there are any 4-star hotels or guesthouses in Cambridge that are cheap?
# SYSTEM: There are 21 locations, do you have any other requirements?
# USER: I am hoping it is a guesthouse
# SYSTEM:   There are 7 guesthouses meeting your requirements. Is there a particular area you wish to stay in?
# USER: No, as long as it's cheap and have 4 stars. Can you recommend me one and book it for 8 people and 3 nights starting Thursday?
# SYSTEM: Sure the Autumn House is a personal favorite. Your booking was successful.
# USER: Great. What was the reference number for the booking?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello there! Can you tell me if there are any 4-star hotels or guesthouses in Cambridge that are cheap?
# SYSTEM: There are 21 locations, do you have any other requirements?
# USER: I am hoping it is a guesthouse
# SYSTEM:   There are 7 guesthouses meeting your requirements. Is there a particular area you wish to stay in?
# USER: No, as long as it's cheap and have 4 stars. Can you recommend me one and book it for 8 people and 3 nights starting Thursday?
# SYSTEM: Sure the Autumn House is a personal favorite. Your booking was successful.
# USER: Great. What was the reference number for the booking?
# SYSTEM: Yes, it's 1GFITCAU.
# USER: OK. Thanks for your help. I look forward to the stay.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello there! Can you tell me if there are any 4-star hotels or guesthouses in Cambridge that are cheap?
# SYSTEM: There are 21 locations, do you have any other requirements?
# USER: I am hoping it is a guesthouse
# SYSTEM:   There are 7 guesthouses meeting your requirements. Is there a particular area you wish to stay in?
# USER: No, as long as it's cheap and have 4 stars. Can you recommend me one and book it for 8 people and 3 nights starting Thursday?
# SYSTEM: Sure the Autumn House is a personal favorite. Your booking was successful.
# USER: Great. What was the reference number for the booking?
# SYSTEM: Yes, it's 1GFITCAU.
# USER: OK. Thanks for your help. I look forward to the stay.
# SYSTEM: Wonderful.  Have a nice time. Can I reserve a taxi for you?
# USER: No, that is all thanks.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for a nightclub to go to. Are there any in the centre of town?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for a nightclub to go to. Are there any in the centre of town?
# SYSTEM: There are 5 nightclubs in the centre. Ballare is one of them. Would that work for you?
# USER: Is there an entrance fee for Ballare?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for a nightclub to go to. Are there any in the centre of town?
# SYSTEM: There are 5 nightclubs in the centre. Ballare is one of them. Would that work for you?
# USER: Is there an entrance fee for Ballare?
# SYSTEM: The fee is 5 pounds.
# USER: Thank you! That's all I needed.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm trying to find a concert hall in the east part of town.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm trying to find a concert hall in the east part of town.
# SYSTEM: Unfortunately, I don't have any listings for concert halls on the east side. Can I check another area of town for you?
# USER: How about an entertainment attraction instead?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm trying to find a concert hall in the east part of town.
# SYSTEM: Unfortunately, I don't have any listings for concert halls on the east side. Can I check another area of town for you?
# USER: How about an entertainment attraction instead?
# SYSTEM: There are two entertainment attractions on the east side. Would you like more information?
# USER: Yes and can I have the phone number and address of one of attraction?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm trying to find a concert hall in the east part of town.
# SYSTEM: Unfortunately, I don't have any listings for concert halls on the east side. Can I check another area of town for you?
# USER: How about an entertainment attraction instead?
# SYSTEM: There are two entertainment attractions on the east side. Would you like more information?
# USER: Yes and can I have the phone number and address of one of attraction?
# SYSTEM: Sure.  Cherry Hinton Hall and Grounds can be reached at 01223446104.  It is on Cherry Hinton Road, postcode cb18dw.  Can I help you with anything else today?
# USER: Thanks. That's all I need for now.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction to visit. Is there anything located in the west part of town?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction to visit. Is there anything located in the west part of town?
# SYSTEM: There are 13 attractions in the west part of town. Would you like to visit a college?
# USER: No, I was thinking of something fun to do. Do you have any suggestions?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction to visit. Is there anything located in the west part of town?
# SYSTEM: There are 13 attractions in the west part of town. Would you like to visit a college?
# USER: No, I was thinking of something fun to do. Do you have any suggestions?
# SYSTEM: I have several museums to choose from. I also have an entertainment attraction called Whale of a Time. Can I interest you in one of those?
# USER: Whale of a Time sounds like a whale of a time! Yes, can I have their phone number, address, and postcode please?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm looking for an attraction to visit. Is there anything located in the west part of town?
# SYSTEM: There are 13 attractions in the west part of town. Would you like to visit a college?
# USER: No, I was thinking of something fun to do. Do you have any suggestions?
# SYSTEM: I have several museums to choose from. I also have an entertainment attraction called Whale of a Time. Can I interest you in one of those?
# USER: Whale of a Time sounds like a whale of a time! Yes, can I have their phone number, address, and postcode please?
# SYSTEM: Sure, they're located at unit 8, viking way, bar hill, postcode cb238el, and their phone number is 01954781018.  May I help with anything else?
# USER: No, that's all I need. Thank you!
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm hoping to find a nightclub in town.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm hoping to find a nightclub in town.
# SYSTEM: We have 6 nightclubs. Any preference on entrance fee?
# USER: No, can you tell me what the entrance fee is?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm hoping to find a nightclub in town.
# SYSTEM: We have 6 nightclubs. Any preference on entrance fee?
# USER: No, can you tell me what the entrance fee is?
# SYSTEM: The Soul Tree Nightclub costs 4 pounds.  The others are a bit more expensive.
# USER: Can you please tell me what the phone number is for The Soul Tree?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm hoping to find a nightclub in town.
# SYSTEM: We have 6 nightclubs. Any preference on entrance fee?
# USER: No, can you tell me what the entrance fee is?
# SYSTEM: The Soul Tree Nightclub costs 4 pounds.  The others are a bit more expensive.
# USER: Can you please tell me what the phone number is for The Soul Tree?
# SYSTEM: Yes, it is 01223477900.
# USER: What is their postcode?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: I'm hoping to find a nightclub in town.
# SYSTEM: We have 6 nightclubs. Any preference on entrance fee?
# USER: No, can you tell me what the entrance fee is?
# SYSTEM: The Soul Tree Nightclub costs 4 pounds.  The others are a bit more expensive.
# USER: Can you please tell me what the phone number is for The Soul Tree?
# SYSTEM: Yes, it is 01223477900.
# USER: What is their postcode?
# SYSTEM: The Soul Tree is in postcode cb23qf. Can I help with anything else today?
# USER: No thank you. That is all the information I need.
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Do you know where I can find the Holy Trinity Church?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Do you know where I can find the Holy Trinity Church?
# SYSTEM: Absolutely. Holy Trinity Church is on Market Street in the centre of town. Their postcode is cb23nz and is free to enter. Would you need their phone number?
# USER: Great what type of attraction are they?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Do you know where I can find the Holy Trinity Church?
# SYSTEM: Absolutely. Holy Trinity Church is on Market Street in the centre of town. Their postcode is cb23nz and is free to enter. Would you need their phone number?
# USER: Great what type of attraction are they?
# SYSTEM: It is an architecture attraction.
# USER: That's all the information I need. Thanks for your help!
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello, I am trying to find an attraction in the west part of town. Can you help me?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello, I am trying to find an attraction in the west part of town. Can you help me?
# SYSTEM: Sure, there are many colleges and museums in the west, there is also some entertainment. Do you have a preference on any of these?
# USER: Not really.  Could you give me the postcode for one of the museums?
# SYSTEM:
# -------
# Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:
#
# USER: Hello, I am trying to find an attraction in the west part of town. Can you help me?
# SYSTEM: Sure, there are many colleges and museums in the west, there is also some entertainment. Do you have a preference on any of these?
# USER: Not really.  Could you give me the postcode for one of the museums?
# SYSTEM: The one I recommend is the People's Portraits Exhibition at Girton College. It's free to get in. Their postcode is cb3ojg. Is there any other information I can provide?
# USER: Thank you. That's all I need today. Goodbye.
# SYSTEM:
# -------

# %%
prompt_e2e = list(dataset[dataset["turn_domain"] == "attraction"]["prompt_e2e"])
dialogue_contexts = []
for prompt in prompt_e2e:
    prompt = prompt.split("\n\n")
    dialogue_contexts.append(f"{prompt[-1]}")
gold_responses = list(dataset[dataset["turn_domain"] == "attraction"]["gold_response"])
print(len(dialogue_contexts), len(gold_responses))
print("Dialogue context: ", dialogue_contexts[0])
print("----")
print("Gold: ", gold_responses[0])
# Out:
# 47 47
# Dialogue context:  USER: Could you help me find a place for entertainment? Something on the east side of town.
# SYSTEM:
# ----
# Gold:  SYSTEM: Cherry Hinton Hall and Grounds is on the east side of town, would you like their phone number?

# %%
dialogue_context ="""USER: Yeas, what to recommend if I want to see good architecture in the west part of town?
SYSTEM: Unfortunately there is no good architecture on the west end but I can look in other parts of town if you want
USER: What about a museum?""" #Ok

# dialogue_context = """USER: Yeah, I'm looking for an entertaining tourist attraction, can point me in the direction of some places to check out?
# SYSTEM: I have about 5 different entertainment venues if that is what you are looking for. Do you have a preference on the area its located in? 
# USER: No preference, please just pick one and give me the postcode and address.""" #good

# dialogue_context ="""USER: I am staying in Cambridge soon and would like to stay at a and b guest house.
# SYSTEM: Sure, how many days and how many people?
# USER: we are staying 6 people for 4 nights starting from Tuesday. i need the reference number
# SYSTEM: Your booking is successful! Your reference number is IIGRA0MI. Do you need anything else?
# USER: Yeas, what to recommend if I want to see good architecture in the west part of town?
# SYSTEM: Unfortunately there is no good architecture on the west end but I can look in other parts of town if you want
# USER: What about a museum? 
# SYSTEM: What part of town there are none in the west. 
# USER: There are no museums in the west at all?
# SYSTEM: sorry about that, there are actually seven in that area.
# USER: Great, can I get the postcode, entrance fee and address of one of them? """ Good

# dialogue_context = """USER: I am staying in the centre of town for the weekend, what is there to do there?
# SYSTEM: We have several things to do! Architecture, colleges, museums...What type of attraction are you most interested in?
# USER: It doesn't matter but can you recommend one and give me the entrance fee?"""

# dialogue_context = """USER: Hello, I would like to find a hotel that includes free parking. 
# SYSTEM: Most of the hotels in town offer free parking. Is there a certain area you'd like to stay in, or do you have a price range in mind?
# USER: Yes. The centre would be nice and also free wifi.
# SYSTEM: The University Arms is an expensive, 4 star hotel with free wifi. Comparatively, the Alexander Bed and Breakfast is a cheaply priced guesthouse, also 4 stars.
# USER: Please book me some rooms for The University Arms to accommodate 8 people for 3 nights starting on wednesday. Can you also provide me the reference number after you book? 
# SYSTEM: Your reference number is X5NY66ZV.
# USER: Thank you. Can you please help me find a place to go in town in the same area as the hotel? Preferably a college.
# SYSTEM: There are no colleges close to the area you are requesting, would you like to chose another destination?
# USER: I believe there are some colleges in the centre of town. Can you please check again?""" #Good

# dialogue_context = """USER: Hello, I would like to find a hotel that includes free parking. 
# SYSTEM: Most of the hotels in town offer free parking. Is there a certain area you'd like to stay in, or do you have a price range in mind?
# USER: Yes. The centre would be nice and also free wifi.
# SYSTEM: The University Arms is an expensive, 4 star hotel with free wifi. Comparatively, the Alexander Bed and Breakfast is a cheaply priced guesthouse, also 4 stars.
# USER: Please book me some rooms for The University Arms to accommodate 8 people for 3 nights starting on wednesday. Can you also provide me the reference number after you book? 
# SYSTEM: Your reference number is X5NY66ZV.
# USER: Thank you. Can you please help me find a place to go in town in the same area as the hotel? Preferably a college.
# SYSTEM: There are no colleges close to the area you are requesting, would you like to chose another destination?
# USER: I believe there are some colleges in the centre of town. Can you please check again? 
# SYSTEM: I am sorry but I rechecked and there are no colleges in that area.  Is there anything else that I can do for you?
# USER: Hmmm, I was looking for the phone number and postcode of a college in the centre area. Could you help me with that?
# SYSTEM: I have 5 colleges in the centre area. What specific college are you looking for?
# USER: I'm looking for cambridge."""


#PROMPTS
prompt_bs_template = """Suppose you have access to a database with all the information provided in INFORMATION, what do you need to query to the databse in order to reply to the user in the following conversation?
INFORMATION: address, area, name, phone, postcode, pricerange, entrance fee, food, internet, parking, stars, arriveby, day, departure, destination, leaveat, price.

You can follow these examples:
USER: I need fruits.
SYSTEM: Do you have any preferences?
USER: Yes, apples if possible. How expensive and how many are there?

Need: Information about pricerange and and count for apple

USER: Cool, that asnwers my question.
SYSTEM: I am happy to help. Anything else needed?
USER: I'm done, thanks!

Need: Information about closing the conversation

USER: I'm looking for a popular zoo around here
SYSTEM: There are multiple zoos I can recommend. Any preference on the location?
USER: I want it to be in the west part of town

Need: Information about zoo in the west

{dialogue_context} 

Need:"""

prompt_rg_template = """In a task oriented dialogue setting, generate a natural and helpful SYSTEM response to the USER query in the conversation provided in CONTEXT. You should follow the information provided in ACT to generate this answer, and do not mention that you are referring to a dataframe:

You can follow this example:
CONTEXT: 
USER: I need a place to fish
SYSTEM: Any preference in the type of fish?
USER: Preferably salmons, but sardines are also fine

ACT: blue lake, 37th avenue

SYSTEM: How about blue lake, 37th avenue in that case?


CONTEXT:
{dialogue_context}

ACT: {dialog_act}

SYSTEM: """

prompt_bs = PromptTemplate(
    input_variables=["dialogue_context"],
    template=prompt_bs_template,
)

prompt_rg = PromptTemplate(
    input_variables=["dialog_act", "dialogue_context"],
    template=prompt_rg_template,
)

# %%
import random
random_idx = random.randint(0, len(dialogue_contexts))
dialogue_context = dialogue_contexts[random_idx]
gold_response = gold_responses[random_idx]
print(dialogue_context)
print("-----")
print(gold_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 import random
# ----> 2 random_idx = random.randint(0, len(dialogue_contexts))
#       3 dialogue_context = dialogue_contexts[random_idx]
#       4 gold_response = gold_responses[random_idx]
#
# NameError: name 'dialogue_contexts' is not defined

# %% [markdown]
# ### Dataframe Agent

# %%
#Random Generation
random_idx = random.randint(0, len(dialogue_contexts))
# random_idx = 304 #Doesn't work
# random_idx = 457
# random_idx = 1232
dialogue_context = dialogue_contexts[random_idx]
gold_response = gold_responses[random_idx]
print(f"Index: {random_idx}")

print("CONTEXT: ", dialogue_context[:-9])
print("=========")
prompt = prompt_bs.format(dialogue_context=dialogue_context[:-9])
# print(prompt)
# print("=========")
output = completion("gpt-3.5-turbo", prompt)
print("User Needs to query database: ", output)

with get_openai_callback() as cb:
    try:
        # query_df = agent_df.run(f"Only give a few random suggestions maximum: {output}") #Use fake intermediary belief state
        query_df = agent_df.run(f"If there are many fitting this criteria, pick a few to propose: {output}") #Use fake intermediary belief state
    except ValueError as e:
        response = str(e)
        if not response.startswith("Could not parse LLM output: `"):
            raise e
        query_df = response.removeprefix("Could not parse LLM output: `").removesuffix("`")
    # query_df = agent({"input":f"What are some possible suggestions according to these constraints:\nNeed: {output}"})
    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Total Cost (USD): ${cb.total_cost}")

print("Information retrieved from database: ", query_df)
if query_df == "Agent stopped due to iteration limit or time limit.":
    query_df = "There is nothing that fits the criteria. Ask for more information."
prompt = prompt_rg.format(dialogue_context=dialogue_context[:-9],
                          dialog_act=query_df)
# print(prompt)
# print("=========")
response = completion("gpt-3.5-turbo", prompt)
print("-----")
print("Gold response: ", gold_response)
print("Final response: ", response)
# Out:
# Index: 7
# CONTEXT:  USER: I'm looking for some info on an attraction called Kettle's Yard
# =========
# User Needs to query database:  Information about Kettle's Yard, such as address, phone number, and entrance fee.
# Total Tokens: 2503
# Prompt Tokens: 2339
# Completion Tokens: 164
# Total Cost (USD): $0.005006
# Information retrieved from database:  There is no information about Kettle's Yard in the dataframe.
# -----
# Gold response:  SYSTEM: Absolutely! The entrance is free! It is located in the west. The address is castle street!
#
# Final response:  I'm sorry, but I couldn't find any information about Kettle's Yard in our system. Is there anything else I can help you with?

# %%
#Interaction
def interactive(domain="attraction"):
    dialogue_context = ""
    utterance = ""
    while utterance not in ["q", "quit"]:
        utterance = input("Type:")
        print(f"USER: {utterance}")
        if utterance == "quit" or utterance == "q":
            return dialogue_context
        dialogue_context += "USER: " + utterance
        prompt = prompt_bs.format(dialogue_context=dialogue_context)

        output = completion("gpt-3.5-turbo", prompt)
        print(f"Query database about: {output}")

        with get_openai_callback() as cb:
            try:
                # query_df = agent_df.run(f"Only give a few random suggestions maximum: {output}") #Use fake intermediary belief state
                query_df = agent_df.run(f"If there are many fitting this criteria, pick a few to propose: {output}") #Use fake intermediary belief state
                # query_df = agent_df.run(f"Give only one suggestion maximum: {output}") #Use fake intermediary belief state
            except ValueError as e:
                response = str(e)
                if not response.startswith("Could not parse LLM output: `"):
                    raise e
                query_df = response.removeprefix("Could not parse LLM output: `").removesuffix("`")
            # print(f"Total Tokens: {cb.total_tokens}")
            # print(f"Prompt Tokens: {cb.prompt_tokens}")
            # print(f"Completion Tokens: {cb.completion_tokens}")
            # print(f"Total Cost (USD): ${cb.total_cost}")

        # print("Information retrieved from database: ", query_df)
        if query_df == "Agent stopped due to iteration limit or time limit.":
            query_df = "There is nothing that fits the criteria. Ask for more information."
        print(f"Query database results: {query_df}")
        prompt = prompt_rg.format(dialogue_context=dialogue_context,
                                  dialog_act=query_df)

        response = completion("gpt-3.5-turbo", prompt)
        print(f"SYSTEM: {response}")
        print("-------------------")
        dialogue_context += f"\nSYSTEM: {response}\n"

# %%
dialogue_context = interactive()
# Out:
# Type: Hi, any british food?
# USER: Hi, any british food?
# Query database about: Information about food that is British
#
#
# > Entering new AgentExecutor chain...
# Thought: I need to filter the dataframe to only include rows where the food is British. Then I can select a few rows to propose.
#
# Action: Filter the dataframe to include rows where the food is British.
# Action Input: `df[df['food'] == 'british']`
# Observation: Filter the dataframe to include rows where the food is British. is not a valid tool, try another one.
# Thought:I need to use the `query` method to filter the dataframe.
# Action: Filter the dataframe to include rows where the food is British using the `query` method.
# Action Input: `df.query("food == 'british'")`
# Observation: Filter the dataframe to include rows where the food is British using the `query` method. is not a valid tool, try another one.
# Thought:I can use the `loc` method to filter the dataframe.
# Action: Filter the dataframe to include rows where the food is British using the `loc` method.
# Action Input: `df.loc[df['food'] == 'british']`
# Observation: Filter the dataframe to include rows where the food is British using the `loc` method. is not a valid tool, try another one.
# Thought:I can use the `isin` method to filter the dataframe.
# Action: Filter the dataframe to include rows where the food is British using the `isin` method.
# Action Input: `df[df['food'].isin(['british'])]`
# Observation: Filter the dataframe to include rows where the food is British using the `isin` method. is not a valid tool, try another one.
# Thought:I can use the `str.contains` method to filter the dataframe.
# Action: Filter the dataframe to include rows where the food is British using the `str.contains` method.
# Action Input: `df[df['food'].str.contains('british', case=False)]`
# Observation: Filter the dataframe to include rows where the food is British using the `str.contains` method. is not a valid tool, try another one.
# Thought:
#
# > Finished chain.
# Query database results: There is nothing that fits the criteria. Ask for more information.
# SYSTEM: I'm sorry, but there is no British food available. Can you provide more information about what you are looking for?
# -------------------

# %%
df.head(2)
# Out:
#                          address    area           food  \
# 0      Regent Street City Centre  centre        italian
# 1  Finders Corner Newmarket Road    east  international
#
#                     name        phone postcode pricerange
# 0  pizza hut city centre  01223323737   cb21ab      cheap
# 1       the missing sock  01223812660  cb259aq      cheap

# %%
dummy_df.head(4)
# Out:
#            name           location colored ink body parts   review  \
# 0   The Inkshot  123 avenue street         yes       head     good
# 1  Tattoo Party      92 street pop          no        arm      bad
# 2    Pro Tattoo    63 flash avenue         yes        leg  neutral
#
#   laser removal
# 0           yes
# 1           yes
# 2           yes

# %%
dialogue_context = interactive()
# Out:
# Type: Hi, can I get international food anywhere?
# USER: Hi, can I get international food anywhere?
# Query database about: Information about restaurants that serve international food.
#
#
# > Entering new AgentExecutor chain...
# Thought: We need to filter the dataframe containing restaurant information based on the type of food they serve.
# Action: python_repl_ast
# Action Input: df3[df3['food'] == 'international']
# Observation:                       name                               address    area  \
# 1         the missing sock         Finders Corner Newmarket Road    east
# 25  the varsity restaurant   35 Saint Andrews Street City Centre  centre
# 33   bloomsbury restaurant  Crowne Plaza Hotel 20 Downing Street  centre
#
#              food        phone postcode pricerange
# 1   international  01223812660  cb259aq      cheap
# 25  international  01223356060   cb23ar   moderate
# 33  international  08719429180   cb23dt   moderate
# Thought:Query database results: We have 3 restaurants that serve international food.
# SYSTEM: Sure, we have three restaurants that serve international cuisine. Would you like me to provide you with their names and locations?
# -------------------
# Type: Yes please
# USER: Yes please
# Query database about: Information about name and address of restaurants that serve international cuisine.
#
#
# > Entering new AgentExecutor chain...
# Thought: We need to filter the restaurant dataframe by the type of cuisine and then select the name and address columns.
# Action: python_repl_ast
# Action Input:
# ```
# df_restaurants = df3[df3['food'] == 'international']
# df_restaurants[['name', 'address']]
# ```
# Observation:                       name                               address
# 1         the missing sock         Finders Corner Newmarket Road
# 25  the varsity restaurant   35 Saint Andrews Street City Centre
# 33   bloomsbury restaurant  Crowne Plaza Hotel 20 Downing Street
# Thought:Query database results: We have successfully filtered the restaurants dataframe and selected the name and address columns.
# SYSTEM: Great! The three restaurants that serve international cuisine are: Spice World, located at 123 Main Street; La Cucina, located at 456 Elm Street; and Saffron, located at 789 Oak Street. Would you like me to provide you with more information about any of these restaurants?
# -------------------
# Type: That's enough thanks, are there any museum around here?
# USER: That's enough thanks, are there any museum around here?
# Query database about: Information about museums in the area.
#
#
# > Entering new AgentExecutor chain...
# Thought: We need to filter the dataframe by the type column to only include museums, and then select the relevant columns to display.
# Action: python_repl_ast
# Action Input:
# museums = df1[df1['type'] == 'museum']
# museums[['name', 'address', 'postcode', 'phone', 'openhours']]
#
# Observation:                                                name  \
# 4                           broughton house gallery
# 5                                         byard art
# 6                                cafe jello gallery
# 8                  cambridge and county folk museum
# 10                               cambridge artworks
# 11                 cambridge book and print gallery
# 12                       cambridge contemporary art
# 13                   cambridge museum of technology
# 15                                 castle galleries
# 28                  gallery at twelve a high street
# 36                                    kettle's yard
# 40                            lynne strover gallery
# 44            museum of archaelogy and anthropology
# 45                  museum of classical archaeology
# 50  people's portraits exhibition at girton college
# 51                                        primavera
# 53                                  regency gallery
# 55                                   ruskin gallery
# 56                     saint barnabas press gallery
# 59                               scott polar museum
# 69                           the fitzwilliam museum
# 77         whipple museum of the history of science
# 78                        williams art and antiques
#
#                                            address postcode        phone  \
# 4                                   98 king street   cb11ln  01223314960
# 5                                 14 king's parade   cb21sj  01223464646
# 6          cafe jello gallery, 13 magdalene street   cb30af  01223312112
# 8                                2-3 castle street   cb30aq  01223355159
# 10                                   5 greens road   cb13ef  01223902168
# 11                                 49 newnham road   cb39ey  01223694264
# 12                                6 trinity street   cb21su  01223324222
# 13          the old pumping station, cheddars lane   cb58ld  01223368650
# 15  unit su43, grande arcade, saint andrews street   cb23bj  01223307402
# 28                                        fulbourn   cb15dh  01223295264
# 36                                   castle street   cb30aq  01223748100
# 40                      23 high street, fen ditton   cb30aq  01223295264
# 44         university of cambridge, downing street   cb23dz  01223333516
# 45                                 sidgwick avenue   cb39da  01223335153
# 50                 girton college, huntingdon road   cb3ojg  01223338901
# 51                                10 king s parade   cb21sj  01223357708
# 53                               39 fitzroy street   cb11er  01223365454
# 55             anglia ruskin university, east road   cb11pt  01245493131
# 56                the belfast yard, coldham's road   cb13ew  01223902116
# 59                                  lensfield road   cb21er  01223336540
# 69                              trumpington street   cb21rb  01223332900
# 77                                free school lane   cb23rh  01223330906
# 78             gwydir street, no. 5 dale's brewery   cb12lj  01223311687
#
#                                                                                                                                                              openhours
# 4                                                                                                                                                                    ?
# 5                                                            it opens from 09:30 a.m. to 5:30 p.m. from monday to saturday, and from 11:00 a.m. to 4:00 p.m. on sunday
# 6                                                                                                           it opens from 10:30 a.m. to 5:30 p.m. thursday to saturday
# 8                                                                   it opens from monday to saturday, 10 a.m. to 5 p.m. while on sunday it opens from 2 p.m. to 5 p.m.
# 10                                                                                                                                                                   ?
# 11                                                                                                      it opens from 10:00 a.m. to 5:00 p.m. from tuesday to saturday
# 12                                                           it opens from 11:00 a.m. to 4:00 p.m. on sunday, and from 09:00 a.m. to 5:30 p.m. from monday to saturday
# 13                                                                                                                      it opens on sunday from 2:00 p.m. to 5:00 p.m.
# 15  it opens from 09:00 a.m. to 6:00 p.m. every day except wednesday when it opens from 09:00 a.m. to 8:00 p.m., and sunday when it opens from 11:00 a.m. to 5:00 p.m.
# 28                                                                                                                                                                   ?
# 36                                                                                                             it opens from 11:30 a.m. to 5:00 p.m. tuesday to sunday
# 40                                                                                                          it opens from 10:00 a.m. to 5:00 p.m. thursday to saturday
# 44                                                                                                           it opens from 10:30 a.m. to 4:30 p.m. tuesday to saturday
# 45                                                                                                              it opens from 10:00 a.m. to 5:00 p.m. monday to friday
# 50                                                                                                    it opens from 2:00 p.m. to 4:00 p.m. daily from february to july
# 51                   it opens from 11:00 a.m. to 4:30 p.m. on sunday, from 10:00 a.m. to 5:00 p.m. from monday to friday, and from 10:00 a.m. to 5:30 p.m. on saturday
# 53                                                                                                                                                                   ?
# 55                                                                                                                                                                   ?
# 56                                                                                                                                                                   ?
# 59                                                                                                      it opens from 10:00 a.m. to 4:00 p.m. from tuesday to saturday
# 69                                       from tuesday to saturday it opens from 10 a.m. to 5 p.m. while on sunday, monday and bank holidays it opens from 12 to 5 p.m.
# 77                                                                                                         it opens from 12:30 p.m. to 4:30 p.m. from monday to friday
# 78                       it opens from 11:00 a.m. to 6:00 p.m. from tuesday to friday, from 11:00 a.m. to 5:00 p.m. on saturday and sunday, and it is closed on monday
# Thought:Query database results: We have successfully filtered the museums from df1 and displayed the relevant columns. We can propose the following museums: Cambridge Museum of Technology, Fitzwilliam Museum, Museum of Archaeology and Anthropology, Museum of Classical Archaeology, and Scott Polar Museum.
# SYSTEM: Yes, there are several museums in the area. Based on your preferences, we can recommend the Cambridge Museum of Technology, Fitzwilliam Museum, Museum of Archaeology and Anthropology, Museum of Classical Archaeology, and Scott Polar Museum. Would you like more information about any of these museums?
# -------------------
# Type: how about the fitzwilliam one?
# USER: how about the fitzwilliam one?
# Query database about: Information about Fitzwilliam Museum
#
#
# > Entering new AgentExecutor chain...
# Thought: We need to find the row(s) in the dataframe that contain information about Fitzwilliam Museum
# Action: python_repl_ast
# Action Input: df[df['name'].str.contains('fitzwilliam museum', case=False)]
# Observation: NameError: name 'df' is not defined
# Thought:We need to define the dataframes before we can use them
# Action: python_repl_ast
# Action Input: import pandas as pd
# Observation:
# Thought:Now we can define the dataframes
# Action: python_repl_ast
# Action Input: df1 = pd.read_csv('data/df1.csv')
# df2 = pd.read_csv('data/df2.csv')
# df3 = pd.read_csv('data/df3.csv')
# df4 = pd.read_csv('data/df4.csv')
# Observation: FileNotFoundError: [Errno 2] No such file or directory: 'data/df1.csv'
# Thought:We need to make sure that the csv files are in the correct directory
# Action: python_repl_ast
# Action Input: import os
# os.getcwd()
# Observation: /home/willy/instructod
# Thought:The csv files are not in the current working directory, we need to change the directory to where the csv files are located
# Action: python_repl_ast
# Action Input: os.chdir('/path/to/csv/files')
# Observation: FileNotFoundError: [Errno 2] No such file or directory: '/path/to/csv/files'
# Thought:
#
# > Finished chain.
# Query database results: There is nothing that fits the criteria. Ask for more information.
# SYSTEM: I'm sorry, but I don't have any information on the Fitzwilliam Museum at the moment. Would you like me to look up more information for you?
# -------------------
# Type: I mean the Fitzwilliam museum that you just recommended me
# USER: I mean the Fitzwilliam museum that you just recommended me
# Query database about: Information about the Fitzwilliam Museum
#
#
# > Entering new AgentExecutor chain...
# Thought: We need to find the row(s) in the dataframe that contain information about the Fitzwilliam Museum.
# Action: python_repl_ast
# Action Input: df1[df1['name'].str.contains('fitzwilliam', case=False)]
# Observation:                address    area entrance fee  id                    name  \
# 69  trumpington street  centre         free  70  the fitzwilliam museum
#
#                                                                                                                         openhours  \
# 69  from tuesday to saturday it opens from 10 a.m. to 5 p.m. while on sunday, monday and bank holidays it opens from 12 to 5 p.m.
#
#           phone postcode pricerange    type
# 69  01223332900   cb21rb       free  museum
# Thought:We found the row that contains information about the Fitzwilliam Museum.
# Final Answer: The Fitzwilliam Museum is located at Trumpington Street, has free entrance fee, and is open from Tuesday to Saturday from 10 a.m. to 5 p.m. and on Sunday, Monday, and bank holidays from 12 to 5 p.m. Its phone number is 01223332900 and its postcode is cb21rb. It is classified as a museum.
#
# > Finished chain.
# Query database results: The Fitzwilliam Museum is located at Trumpington Street, has free entrance fee, and is open from Tuesday to Saturday from 10 a.m. to 5 p.m. and on Sunday, Monday, and bank holidays from 12 to 5 p.m. Its phone number is 01223332900 and its postcode is cb21rb. It is classified as a museum.
# SYSTEM: Great! The Fitzwilliam Museum is located at Trumpington Street, has free entrance fee, and is open from Tuesday to Saturday from 10 a.m. to 5 p.m. and on Sunday, Monday, and bank holidays from 12 to 5 p.m. Its phone number is 01223332900 and its postcode is cb21rb. It is classified as a museum. Is there anything else I can help you with?
# -------------------
# Type: q
# USER: q

# %%
print(dialogue_context)
# Out:
# USER: Hi, can I get international food anywhere?
# SYSTEM: Sure, we have three restaurants that serve international cuisine. Would you like me to provide you with their names and locations?
# USER: Yes please
# SYSTEM: Great! The three restaurants that serve international cuisine are: Spice World, located at 123 Main Street; La Cucina, located at 456 Elm Street; and Saffron, located at 789 Oak Street. Would you like me to provide you with more information about any of these restaurants?
# USER: That's enough thanks, are there any museum around here?
# SYSTEM: Yes, there are several museums in the area. Based on your preferences, we can recommend the Cambridge Museum of Technology, Fitzwilliam Museum, Museum of Archaeology and Anthropology, Museum of Classical Archaeology, and Scott Polar Museum. Would you like more information about any of these museums?
# USER: how about the fitzwilliam one?
# SYSTEM: I'm sorry, but I don't have any information on the Fitzwilliam Museum at the moment. Would you like me to look up more information for you?
# USER: I mean the Fitzwilliam museum that you just recommended me
# SYSTEM: Great! The Fitzwilliam Museum is located at Trumpington Street, has free entrance fee, and is open from Tuesday to Saturday from 10 a.m. to 5 p.m. and on Sunday, Monday, and bank holidays from 12 to 5 p.m. Its phone number is 01223332900 and its postcode is cb21rb. It is classified as a museum. Is there anything else I can help you with?

# %% [markdown]
# ### SQL Agent

# %%
#Random Generation
# random_idx = random.randint(0, len(dialogue_contexts))
# random_idx = 304 #Doesn't work
# random_idx = 1099
dialogue_context = dialogue_contexts[random_idx]
gold_response = gold_responses[random_idx]
print(f"Index: {random_idx}")

print("CONTEXT: ", dialogue_context[:-9])
print("=========")
prompt = prompt_bs.format(dialogue_context=dialogue_context[:-9])
# print(prompt)
# print("=========")
output = completion(model_args, prompt)
print("User Needs to query database: ", output)

with get_openai_callback() as cb:
    # try:
    #     query_df = agent_sql.run(f"Only give one or two maximum: {output}") #Use fake intermediary belief state
    # except ValueError as e:
    #     response = str(e)
    #     if not response.startswith("Could not parse LLM output: `"):
    #         raise e
    #     query_df = response.removeprefix("Could not parse LLM output: `").removesuffix("`")
    query_df = agent_sql({"input":f"What are some possible suggestions according to these constraints:\nNeed: {output}"})
    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Total Cost (USD): ${cb.total_cost}")

print("Information retrieved from database: ", query_df)
if query_df == "Agent stopped due to iteration limit or time limit.":
    query_df = "There is nothing that fits the criteria. Ask for more information."
prompt = prompt_rg.format(dialogue_context=dialogue_context,
                          dialog_act=query_df)
# print(prompt)
# print("=========")
response = completion(model_args, prompt)
print("-----")
print("Gold response: ", gold_response)
print("Final response: ", response)
# Out:
# Index: 304
# CONTEXT:  SYSTEM: The only listing we have is for Bedouin in the city centre. Would you like to try a different type of cuisine?
# USER: Yeah, how about a gastropub then?
# SYSTEM: Yes I have several in the city center. What price range are you ideally looking for?
# USER: Moderate. Please give me a phone number, address, and postcode for the restaurant you find. Thanks!
# SYSTEM: I have the cow pizza kitchen and bar located at corn exchange street cb23qf, phone number 01223308871.
# USER: Cow Pizza Kitchen? That is great. lol. Can you help me find a certain attraction now? I believe it's called Gallery at Twelve
# =========
# User Needs to query database:  Information on the Gallery at Twelve attraction.
#
#
# > Entering new AgentExecutor chain...
# Action: list_tables_sql_db
# Action Input:
# Observation: attraction
# Thought: I should query the schema of the attraction table to see what information I can get.
# Action: schema_sql_db
# Action Input: attraction
# Observation:
# CREATE TABLE attraction (
# 	id INTEGER,
# 	name TEXT,
# 	address TEXT,
# 	area TEXT,
# 	postcode TEXT,
# 	phone TEXT,
# 	type TEXT,
# 	entrance_fee TEXT,
# 	price_range TEXT,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from attraction table:
# id	name	address	area	postcode	phone	type	entrance_fee	price_range
# 1	abbey pool and astroturf pitch	pool way, whitehill road, off newmarket road	east	cb58nt	01223902088	swimmingpool	?	?
# 2	adc theatre	park street	centre	cb58as	01223300085	theatre	?	?
# 3	all saints church	jesus lane	centre	cb58bs	01223452587	architecture	free	free
# */
# Thought: I should query the attraction table for information on the Gallery at Twelve.
# Action: query_sql_db
# Action Input: SELECT name, address, area, postcode, phone, type, entrance_fee, price_range FROM attraction WHERE name = 'Gallery at Twelve';
# Observation: []
# Thought: I should query the attraction table for information on attractions in the area.
# Action: query_sql_db
# Action Input: SELECT name, address, area, postcode, phone, type, entrance_fee, price_range FROM attraction WHERE area = 'east' LIMIT 10;
# Observation: [('abbey pool and astroturf pitch', 'pool way, whitehill road, off newmarket road', 'east', 'cb58nt', '01223902088', 'swimmingpool', '?', '?'), ('camboats', 'the plough, green end, fen ditton,', 'east', 'cb58sx', '01223902112', 'boat', '?', '?'), ('cambridge artworks', '5 greens road', 'east', 'cb13ef', '01223902168', 'museum', 'free', 'free'), ('cambridge museum of technology', 'the old pumping station, cheddars lane', 'east', 'cb58ld', '01223368650', 'museum', '5 pounds', 'expensive'), ('cherry hinton hall and grounds', 'cherry hinton road', 'east', 'cb18dw', '01223446104', 'entertainment', '?', '?'), ('cherry hinton water play', 'cherry hinton hall, cherry hinton road', 'east', 'cb18dw', '01223446100', 'park', 'free', 'free'), ('funky fun house', '8 mercers row, mercers row industrial estate', 'east', 'cb58hy', '01223304705', 'entertainment', '?', '?'), ('gallery at twelve a high street', 'fulbourn', 'east', 'cb15dh', '01223295264', 'museum', 'free', 'free'), ('saint barnabas press gallery', "the belfast yard, coldham's road", 'east', 'cb13ew', '01223902116', 'museum', 'free', 'free'), ('the cherry hinton village centre', 'colville road, cherry hinton', 'east', 'cb19ej', '01223576412', 'mutliple sports', '?', '?')]
# Thought: I now know the final answer.
# Final Answer: The Gallery at Twelve is a museum located in Fulbourn, East, with a postcode of CB15DH. It is free to enter and has a price range of free. The phone number is 01223295264.
#
# > Finished chain.
# Total Tokens: 4951
# Prompt Tokens: 4733
# Completion Tokens: 218
# Total Cost (USD): $0.09902
# Information retrieved from database:  {'input': 'What are some possible suggestions according to these constraints:\nNeed: Information on the Gallery at Twelve attraction.', 'output': 'The Gallery at Twelve is a museum located in Fulbourn, East, with a postcode of CB15DH. It is free to enter and has a price range of free. The phone number is 01223295264.'}
# -----
# Gold response:  SYSTEM: Yes I have located The Gallery at Twelve. The address is listed as fulbourn and their telephone number is: 01223295264.
#
# Final response:  Sure, the Gallery at Twelve is a museum located in Fulbourn, East with a postcode of CB15DH. It is free to enter and has a price range of free. The phone number is 01223295264.

# %%
dataset.head(2)
# Out:
#    id   dialogue_id  \
# 0   0  SNG0073.json
# 1   1  SNG0073.json
#
#                                                                  dialogue_context  \
# 0  USER: I would like a taxi from Saint John's college to Pizza Hut Fen Ditton.\n
# 1                                            USER: I want to leave after 17:15.\n
#
#    turn  \
# 0     0
# 1     1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             prompt_dst  \
# 0  Generate the belief state of the very last dialogue turn in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. The results should be in json format following this format: {'slot1':'value1', 'slot2':'value2', etc...}. Use the slot from SLOTS to generate the belief state:\n\nSLOTS:\nleaveat, pricerange, stars, phone, postcode, id, reference, parking, address, car, price, people, name, arriveby, type, area, time, departure, food, day, internet, stay, des...
# 1  Generate the belief state of the very last dialogue turn in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. The results should be in json format following this format: {'slot1':'value1', 'slot2':'value2', etc...}. Use the slot from SLOTS to generate the belief state:\n\nSLOTS:\nleaveat, pricerange, stars, phone, postcode, id, reference, parking, address, car, price, people, name, arriveby, type, area, time, departure, food, day, internet, stay, des...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      prompt_dst_update  \
# 0  Generate the belief state of the very last dialogue turn in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. The results should be in json format following this format: {'slot1':'value1', 'slot2':'value2', etc...}. Use the slot from SLOTS to generate the belief state:\n\nSLOTS:\nleaveat, pricerange, stars, phone, postcode, id, reference, parking, address, car, price, people, name, arriveby, type, area, time, departure, food, day, internet, stay, des...
# 1  Generate the belief state of the very last dialogue turn in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. The results should be in json format following this format: {'slot1':'value1', 'slot2':'value2', etc...}. Use the slot from SLOTS to generate the belief state:\n\nSLOTS:\nleaveat, pricerange, stars, phone, postcode, id, reference, parking, address, car, price, people, name, arriveby, type, area, time, departure, food, day, internet, stay, des...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              prompt_rg  \
# 0  In a task oriented dialogue setting, generate a SYSTEM response to the USER query in the conversation provided in CONTEXT. You should follow the information provided in ACT to generate this answer. Do not answer with anything other than what is provided in the dialogue act:\n\nYou can follow this example:\nUSER: How much does the banana cost?\nACT: Inform the user that the price is 10$, the promotion is 80%, and the choice is 5, and request the amount that user wants.\nSYSTEM: There are 5 to...
# 1  In a task oriented dialogue setting, generate a SYSTEM response to the USER query in the conversation provided in CONTEXT. You should follow the information provided in ACT to generate this answer. Do not answer with anything other than what is provided in the dialogue act:\n\nYou can follow this example:\nUSER: How much does the banana cost?\nACT: Inform the user that the price is 10$, the promotion is 80%, and the choice is 5, and request the amount that user wants.\nSYSTEM: There are 5 to...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             prompt_e2e  \
# 0  Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:\n\nUSER: I would like a taxi from S...
# 1  Generate the answer of the SYSTEM in the following conversation between a USER and a SYSTEM in a task-oriented dialogue setting. You can either request more details to the user that is available in the knowledge base to complete the goal, or simply answer the user's request. Do not provide multiple choice for the user to choose, just recommend one, and generate nothing other that the SYSTEM reply. Use the following knowledge base to interact with the user:\n\nUSER: I would like a taxi from S...
#
#   domains turn_domain  \
# 0  [taxi]        taxi
# 1  [taxi]        taxi
#
#                                                                                gold_turn_bs  \
# 0  {'Taxi-Inform': [['Dest', 'pizza hut fen ditton'], ['Depart', 'saint john 's college']]}
# 1                                                     {'Taxi-Inform': [['Leave', '17:15']]}
#
#                                                                   gold_bs  \
# 0              [taxi] dest pizza hut fenditton depart saint johns college
# 1  [taxi] leave 17:15 dest pizza hut fenditton depart saint johns college
#
#                                                              gold_act  \
# 0                 {'Taxi-Request': [['Leave', '?'], ['Arrive', '?']]}
# 1  {'Taxi-Inform': [['Car', 'blue honda'], ['Phone', '07218068540']]}
#
#                                                                                gold_response  \
# 0           SYSTEM: What time do you want to leave and what time do you want to arrive by?\n
# 1  SYSTEM: \nBooking completed! your taxi will be blue honda Contact number is 07218068540\n
#
#   gold_database_result
# 0                 None
# 1                 None

# %% [markdown]
# ## Notes:
#
# Current e2e setting:
#
# Encode knowledge base in a vector base, then:
# 1) Extract how to interact with the knowledge base (mix of belief state - system action): e.g. "Entertainment venue information including postcode and address for one venue."
# 2) Query the knowledge base with extracted information: e.g. "Entertainment venue information including postcode and address for adc theatre: address - park street, postcode - cb58as."
# 3) Use the extracted knowledge to generate a response: e.g. "Sure, how about the ADC Theatre? It's located at Park Street and the postcode is CB5 8AS."

# %%
import pandas as pd
df_results = pd.read_csv("src/e2e/results/gpt-3.5-turbo_e2e_agents_full_output.csv")

# %%
count = 0
for idx, row in df_results.iterrows():
    if "none" in row["preds_e2e_dialog_acts"]:
        count += 1

# %%
count
# Out:
# 660

# %%
for idx, row in df_results.iterrows():
    dialogue_context = row["prompts_e2e_query_db"].split("\n\n")[-2]
    # print("dialogue context:", dialogue_context)
    print("Act: ", row["preds_e2e_dialog_acts"] + "\n")
    print("gold: ", row["gold_response"])
    print("pred: ",row["preds"])
    print("-----")
# Out:
# Act:  none
#
# gold:  SYSTEM: What time do you want to leave and what time do you want to arrive by?
#
# pred:  Sure, I can help you with that. Would you like me to confirm the booking for you?
# -----
# Act:  none
#
# gold:  SYSTEM:
# Booking completed! your taxi will be blue honda Contact number is 07218068540
#
# pred:  Sure, I can arrange a taxi for you to leave after 17:15. What time would you like to arrive at Pizza Hut Fen Ditton?
# -----
# Act:  none
#
# gold:  SYSTEM: You are welcome.  Is there anything else I can help you with today?
#
# pred:  You're welcome! Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: you too! thank you
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes there is a Portuguese restaurant in Cambridge  with two different locations, would you like the addresses?
#
# pred:  I'm sorry, I couldn't find any Portuguese restaurants in Cambridge. Would you like me to search for other types of restaurants in the area?
# -----
# Act:  There are no Portuguese or Turkish restaurants in the dataframe.
#
# gold:  SYSTEM: I have two Turkish restuarants, both in the centre and both expensive. May I recommend anatolia?
#
# pred:  I'm sorry, but there are no Portuguese or Turkish restaurants in our system. Would you like me to search for other types of restaurants in Cambridge?
# -----
# Act:  none.
#
# gold:  SYSTEM: I am sorry. I mistook that price range. The Anatolia is in the moderate range. Would that work for you?
#
# pred:  How about the Portuguese restaurant at 123 Main Street? It has a moderate price range and good reviews. Would you like me to make a reservation for you?
# -----
# Act:  I cannot provide reservation information for Anatolia Restaurant as it is not present in the dataframe.
#
# gold:  SYSTEM:
# Booking was successful. The table will be reserved for 15 minutes.
# Reference number is : 96ZYHLN1.
#
# pred:  I apologize, but I am unable to make a reservation for Anatolia Restaurant at this time. However, I can suggest other moderately priced Turkish restaurants in the area. Would you like me to provide some options for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: You are more than welcome!
#
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  The first two guesthouses with moderate prices are "a and b guest house" located at 124 Tenison Road and "acorn guest house" located at 154 Chesterton Road.
#
# gold:  SYSTEM: I can help you with that.  Do you have any special area you would like to stay?  Or possibly a star request for the guesthouse?
#
# pred:  I found two guesthouses with moderate prices that might interest you. The first one is "a and b guest house" located at 124 Tenison Road and the second one is "acorn guest house" located at 154 Chesterton Road. Which one would you like me to book for you?
# -----
# Act:  The two moderate priced guesthouses with a 3-star rating are "alpha-milton guest house" and "bridge guest house".
#
# gold:  SYSTEM: The Bridge Guest House is a 3 star guesthouse. It is in the south area. Would you like to book a room?
#
# pred:  I found two guesthouses that match your criteria: "alpha-milton guest house" and "bridge guest house". Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: How many people is the reservation for?
#
# pred:  Great! I can confirm your booking for four people at The Bridge Guest House. Can you please provide me with the dates you would like to stay?
# -----
# Act:  none.
#
# gold:  SYSTEM: I am afraid that booking is unsuccessful. Would you like a different day or amount of days?
#
# pred:  Great, I can confirm a reservation for four people at The Bridge Guest House for two nights starting on Saturday. Would you like me to proceed with the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: This booking is successful for 1 night. Your reference number is 85BGKWO4. Is there anything else I can assist you with?
#
# pred:  Great, I can confirm a reservation for four people at our available location for one night beginning on Saturday. Can you please confirm the name on the reservation and a contact number?
# -----
# Act:  none.
#
# gold:  SYSTEM: Great, have a pleasant stay.  Bye.
#
# pred:  Thank you for choosing our service. Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: I have found the guesthouse you were wanting. Would you like me to book this for you?
#
# pred:  Sure, I can help you with that. Would you like me to confirm a booking for you at City Centre North B&B?
# -----
# Act:  none
#
# gold:  SYSTEM: Your booking was successful. The reference number is : BE1VD9EH.
#
# pred:  Great, I can confirm your booking for City Centre North B&B for 1 person starting Friday for 5 nights. Is there anything else I can assist you with?
# -----
# Act:  none
#
# gold:  SYSTEM: You are very welcome!
#
# pred:  You're welcome! Is there anything else I can assist you with?
# -----
# Act:  none.
#
# gold:  SYSTEM: Oh yes quite a few. Which part of town will you be dining in?
#
# pred:  Yes, there is a restaurant called The Queen's Table that serves traditional British cuisine. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: We have three: Graffiti, Saint John's Chop House, and Traveller's Rest.
#
# pred:  There is a restaurant called The Churchill Arms in West town that serves traditional British cuisine. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes, the phone number is 01223277977. The address is Hotel Felix Whitehouse Lane Huntingdon Road, and the post code is cb30lx. Want to book?
#
# pred:  Sure, I can confirm a booking for you at Graffiti. Can you please provide me with the date and time you would like to dine?
# -----
# Act:  There is no "graffiti zoo" in the west part of town.
#
# gold:  SYSTEM: You're welcome, glad to help. Have a nice day!
#
# pred:  Alright, let me know if you need any further assistance. Have a great day!
# -----
# Act:  none.
#
# gold:  SYSTEM: The next train leaving from Cambridge for Birmingham New Street departs Friday at 5:01, and will arrive by 7:44.
#
# pred:  Sure, I can help you with that. What date and time are you looking to travel?
# -----
# Act:  none.
#
# gold:  SYSTEM: I have a train leaving Cambridge arriving at Birmingham New Street on Friday at 9:01.  Would you like me to book this for you?
#
# pred:  I found a train leaving from Cambridge for Birmingham New Street on Friday at 9:01 AM, arriving at 11:44 AM. Would you like me to confirm the booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: And how many tickets will you need for your trip?
#
# pred:  Great, I have confirmed your booking for the train leaving Cambridge at 9:01 on Friday, arriving at Birmingham New Street. Enjoy your trip!
# -----
# Act:  none.
#
# gold:  SYSTEM: The travel time is 163 minutes, and the price is 75.10 pounds.  How else can I help?
#
# pred:  Sure, the travel time for the train leaving Cambridge and arriving at Birmingham New Street on Friday at 9:01 is approximately 1 hour and 31 minutes. The price for a one-way ticket is £25.50.
# -----
# Act:  The first two train travel times and prices are 51 minutes and 23.60 pounds.
#
# gold:  SYSTEM: Glad to be of help.  Have a nice day.  Bye.
#
# pred:  Just to confirm, you don't need any bookings at this time, correct? Let me know if you need any further assistance.
# -----
# Act:  There are two restaurants in the city centre with price information:
# 1. Pizza Hut City Centre - Address: Regent Street City Centre, Area: Centre, Food: Italian, Phone: 01223323737, Postcode: CB21AB, Price Range: Cheap
# 2. La Margherita - Address: 15 Magdalene Street City Centre, Area: West, Food: Italian, Phone: 01223315232, Postcode: CB30AF, Price Range: Cheap
#
# gold:  SYSTEM: I have found many possibilities. Golden house is chinese and the river bar steakhouse and grill serves modern european. Are either of those of interest for you?
#
# pred:  Based on your criteria, I recommend Pizza Hut City Centre on Regent Street. It's a cheap Italian restaurant located in the city centre. Would you like me to make a reservation for you?
# -----
# Act:  The "golden house restaurant" is not in the dataframe.
#
# gold:  SYSTEM: They are located at 12 Lensfield Road City Centre, postcode cb21eg, and phone number 01842753771.
#
# pred:  I'm sorry, but I couldn't find the Golden House restaurant in our database. Would you like me to suggest some other cheap restaurants in the center that I have available? Or would you like me to help you find the contact information for Golden House through an online search?
# -----
# Act:  The "golden house restaurant" is not in the dataframe.
#
# gold:  SYSTEM: Thank you for using our service. Have a great day.
#
# pred:  I'm sorry, but it seems that the Golden House restaurant is not available for booking through our system. Is there anything else I can help you with?
# -----
# Act:  The "a and b guest house" takes bookings and has a moderate price range.
#
# gold:  SYSTEM: It is in the east, and moderately priced. Would you like to book a room?
#
# pred:  Sure, I can help you with that. Would you like me to confirm a booking for you at the "a and b guest house"?
# -----
# Act:  The address for a and b guest house is 124 Tenison Road, and the phone number is 01223315702.
#
# gold:  SYSTEM: The address is 124 tenison road, postcode cb12dp. The phone number is 01223315702. Anything else?
#
# pred:  Here is the address and phone number for a and b guest house: 124 Tenison Road, 01223315702. Would you like me to confirm a booking for you?
# -----
# Act:  The address for a and b guest house is 124 tenison road and the phone number is 01223315702.
#
# gold:  SYSTEM: You're welcome have a great day.
#
# pred:  Would you like me to confirm a booking for you at a and b guest house?
# -----
# Act:  none.
#
# gold:  SYSTEM: Sure, I can help you with that. I have 21 restaurants available. Would you like a certain type of food?
#
# pred:  How about La Trattoria on Main Street? It's located in the centre and has moderate prices. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I was able to book Yippee Noodle Bar and your reference is 7J4EXP7M.
#
# pred:  I have found a few options for you. How about La Trattoria or The Bistro? Both have availability for 5 people at 13:45 on Saturday and are located in the city center with moderate prices. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Is there anything else I can help you with?
#
# pred:  You're welcome! Your booking is confirmed for Yippee Noodle Bar at 13:45 on Saturday for 5 people. Enjoy your meal!
# -----
# Act:  none.
#
# gold:  SYSTEM: Thank you for using our system!
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  none.
#
# gold:  SYSTEM: There are many options for expensive food in West Cambridge. Is there a specific type of food you would like?
#
# pred:  How about checking out the Michelin-starred restaurant on Main Street? It's known for its high-end cuisine and elegant atmosphere. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I'm sorry, there is nothing showing for Chicken Tikka Masala. There are however 5 expensive Indian restaurants in the west part of Cambridge. I would recommend the Rice Boat.
#
# pred:  I recommend trying out the restaurant "Taj Mahal" in West Cambridge. They have a great Chicken Tikka Masala dish and are known for their upscale atmosphere. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: You are booked for the Rice Boat on Monday at 11:45. Your reference number is S224QQ91. May I help you with anything else?
#
# pred:  Great, I can confirm your booking at the Rice Boat for 1 person at 11:45 on Monday. Is there anything else I can assist you with?
# -----
# Act:  none.
#
# gold:  SYSTEM: Thank you for using Cambridge TownInfo centre. Have a great day.
#
# pred:  You're welcome! Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: Okay, and where do you want to be picked up from and what is your destination?
#
# pred:  Sure, I can help you with that. Can you please provide me with your pickup location and destination?
# -----
# Act:  none
#
# gold:  SYSTEM: Your car will be a white volkswagen and the contact number is 07814597280. Thank you, and have a great day.
#
# pred:  Great, I can confirm a taxi booking for you from Wagamama to Mumford Theatre at 9:00am. Is that okay?
# -----
# Act:  The first two accommodations with price and wifi availability are:
# 1. Name: a and b guest house, Price Range: moderate, Internet: yes
# 2. Name: acorn guest house, Price Range: moderate, Internet: yes
#
# gold:  SYSTEM: I have ten entries that meet your requirements! What area of town would you like?
#
# pred:  I found a couple of options for you. The first two accommodations with both a moderate price range and free wifi are a and b guest house and acorn guest house. Would you like me to confirm a booking for you at either of these places?
# -----
# Act:  none.
#
# gold:  SYSTEM: Unfortunately, I don't show any cheap hotels that have a 3-star rating. Can I look in a different price range or star rating for you?
#
# pred:  Sure, I found a few options with 3 stars and free wifi. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: We have 3 moderately priced 3 star guesthouses.
#
# pred:  I found a few options in the moderate price range with free wifi. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Which are would you like to stay in?
#
# pred:  Based on your preferences, I would recommend the Green Garden Guesthouse. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I'm going to book you for bridge guest house, but I need to know the number of days you plan to stay and the number of people with you.
#
# pred:  Sure, I can confirm a booking for you. The best option for you would be the 3 star guesthouse located in the city center. Would you like me to proceed with the booking for Thursday?
# -----
# Act:  none.
#
# gold:  SYSTEM: Your booking is successful! Your reference number is IZE1WK61. Can I help you with anything else?
#
# pred:  Great, I have confirmed your booking for Bridge Guest House for 2 people checking in on Thursday for 3 nights. Enjoy your stay!
# -----
# Act:  none.
#
# gold:  SYSTEM: You're welcome. Thank you for calling. Enjoy your trip!
#
# pred:  Thank you for using our booking service. Have a great stay at Bridge Guest House!
# -----
# Act:  The booking information for 2 people checking in on Thursday for 3 nights is as follows:
#
# 1. Name: a and b guest house
#    Address: 124 tenison road
#    Area: east
#    Internet: yes
#    Parking: no
#    Postcode: cb12dp
#    Price Range: moderate
#    Stars: 4
#    Type: guesthouse
#
# 2. Name: acorn guest house
#    Address: 154 chesterton road
#    Area: north
#    Internet: yes
#    Parking: yes
#    Postcode: cb41da
#    Price Range: moderate
#    Stars: 4
#    Type: guesthouse
#
# gold:  SYSTEM: Thank you for using our service. It was a pleasure assisting you. Goodbye.
#
# pred:  Thank you for choosing our booking service. Your reservation for 2 people checking in on Thursday for 3 nights at a and b guest house in the east area has been confirmed with reference number IZE1WK61. Enjoy your stay!
# -----
# Act:  none.
#
# gold:  SYSTEM: I found 2 that matches your criteria. Would you prefer a moderate or cheap pricing?
#
# pred:  Sure, I can help you with that. Can you please provide me with a specific location or area in the north where you would like to go?
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes The Nirala's address is 7 Milton Road Chesterton and their postcode is cb41uy. Is there anything else I can help you with today?
#
# pred:  Sure, I can confirm a booking for you at the moderate Indian restaurant in the north. Can you please provide me with your preferred date and time?
# -----
# Act:  none.
#
# gold:  SYSTEM: So glad we could help you out. Thanks for using the Cambridge TownInfo centre, and have a glorious day!
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: What time would you like to arrive there by?
#
# pred:  Sure, I can help you with that. What time would you like to be picked up at Regency Gallery?
# -----
# Act:  none
#
# gold:  SYSTEM: Okay, you're all set. Be on the look out for a blue tesla. You can reach the taxi at 07814723348. Can I do anything more for you?
#
# pred:  Sure, I can arrange a taxi for you to pick you up at Regency Gallery at 19:30 to ensure you arrive at Don Pasquale Pizzeria by 20:00. Would you like me to confirm the booking for you?
# -----
# Act:  none
#
# gold:  SYSTEM: Have a great day!
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: Okay, what is your destination?
#
# pred:  Sure, I can help you with that. Would you like me to confirm the booking for you?
# -----
# Act:  none
#
# gold:  SYSTEM: Have you in a white Honda, 07040297067 is the phone number.
#
# pred:  Sure, I can help you with that. Your taxi will be booked to pick you up at Ian Hong House at 14:45 and take you to Leicester Train Station. Is that okay with you?
# -----
# Act:  none
#
# gold:  SYSTEM: Have a great day!
#
# pred:  Great, I have confirmed your booking for a taxi to pick you up at Ian Hong House at 14:45 and take you to Leicester Train Station. You will receive a confirmation message shortly. Thank you for using our service.
# -----
# Act:  Here are one or two hotels with at least a three-star rating:
#
# 1. Name: a and b guest house
#    Address: 124 tenison road
#    Area: east
#    Internet: yes
#    Parking: no
#    Price Range: moderate
#    Stars: 4
#    Takes Bookings: yes
#    Type: guesthouse
#
# 2. Name: acorn guest house
#    Address: 154 chesterton road
#    Area: north
#    Internet: yes
#    Parking: yes
#    Price Range: moderate
#    Stars: 4
#    Takes Bookings: yes
#    Type: guesthouse
#
# gold:  SYSTEM: We have 6 hotels and guesthouses that have 3 star ratings. Is there a particular part of town, or a particular price range that you're interested in?
#
# pred:  Here are two options for you with at least a three-star rating: a and b guest house on Tenison Road in the east, and acorn guest house on Chesterton Road in the north. Both have internet and take bookings. Would you like me to confirm a booking for you?
# -----
# Act:  There are two hotels that meet the criteria: Bridge Guest House and Gonville Hotel.
#
# gold:  SYSTEM: The gonville hotel is in the centre and the lensfield hotel is in the south.They both have free wifi. Would you like me to book one for you?
#
# pred:  Great! I found two hotels that meet your criteria: Bridge Guest House and Gonville Hotel. Both have a three-star rating and offer free wifi. Would you like me to confirm a booking for you at either of these hotels?
# -----
# Act:  The two hotels with at least a three-star rating and free wifi are "a and b guest house" and "acorn guest house".
#
# gold:  SYSTEM: Understood.  Do you need anything else then?
#
# pred:  If you're still looking for options, we have two guest houses with at least a three-star rating and free wifi: "a and b guest house" and "acorn guest house". Let me know if you'd like me to book a room for you at either of these locations.
# -----
# Act:  There are two hotels with moderate price range and free wifi: "a and b guest house" located at 124 Tenison Road, and "acorn guest house" located at 154 Chesterton Road.
#
# gold:  SYSTEM: We have 4 to choose from now. Any other preferences?
#
# pred:  I have found two options for you that fit your criteria. The "a and b guest house" located at 124 Tenison Road and the "acorn guest house" located at 154 Chesterton Road both have moderate prices and free wifi. Would you like me to book one of these for you?
# -----
# Act:  Both of the first two options are guesthouses.
#
# gold:  SYSTEM: Yes, they are all guesthouses. Can I suggest the hamilton lodge, a 3 star, moderately priced guesthouse with wifi, in the north area?
#
# pred:  Both of the first two options are guesthouses. Would you like me to confirm a booking for you at one of them?
# -----
# Act:  none.
#
# gold:  SYSTEM: Certainly. It's 01223365664. Would you like me to book it for you?
#
# pred:  Sure, I can confirm your booking for the Hamilton Lodge. Would you like me to proceed with that?
# -----
# Act:  There is no "hamilton lodge guesthouse" in the dataset.
#
# gold:  SYSTEM: Sure,  it is at 156 chesterton road.  Do you need any other information today?
#
# pred:  I'm sorry, but I couldn't find any information on a guesthouse called "Hamilton Lodge" in our database. Is there anything else I can help you with?
# -----
# Act:  Hamilton Lodge is located at 156 Chesterton Road, and its phone number is 01223365664.
#
# gold:  SYSTEM: You are welcome.  Bye.
#
# pred:  You're welcome! If you need any further assistance, don't hesitate to ask.
# -----
# Act:  none
#
# gold:  SYSTEM: From where will you be picked up?
#
# pred:  Sure, I can help you with that. Would you like me to confirm the booking for you?
# -----
# Act:  none
#
# gold:  SYSTEM: Booking completed!
# Booked car type	:	red tesla
# Contact number	:	07644470752
#
# pred:  Sure, I can arrange a taxi for you. What time would you like to be picked up from Ballare?
# -----
# Act:  none
#
# gold:  SYSTEM: I'll need a destination to give them before I can book that for you.
#
# pred:  Sure, I can help you with that. Would you like me to confirm a booking for you?
# -----
# Act:  none
#
# gold:  SYSTEM: The car that is reserved for you is a grey Toyota, and the contact number is 07997985529.  Can I do anything else for you?
#
# pred:  Sure, I can book a taxi for you from Yu Garden to Holy Trinity Church at 14:30. What type of car would you prefer and what's the best contact number to reach you?
# -----
# Act:  none
#
# gold:  SYSTEM: Alright, enjoy your trip!
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  none.
#
# gold:  SYSTEM: There are quite a few options in the centre of town. There's Chinese, Italian, Spanish, Turkish and British food just to name a few. What would you like?
#
# pred:  Sure, I can definitely help you with that. How about I suggest a few options for you to choose from?
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes! Ali Baba is a great Lebanese restaurant that would suit your needs. It's located at 59 Hills Road City Centre. What other information do you need?
#
# pred:  Sure, I can help you find a Lebanese restaurant in the centre of town. Would you like me to make a reservation for you as well?
# -----
# Act:  none.
#
# gold:  SYSTEM: Certainly, how many people will be in your party total?
#
# pred:  Sure, I can help you with that. How many people will be in your party?
# -----
# Act:  There is no address information for ali baba restaurant in the dataframe.
#
# gold:  SYSTEM: The Ali Baba is located at 59 Hills Road City Centre. Would you like any other information?
#
# pred:  I'm sorry, but I don't have the address information for Ali Baba restaurant in my database. Is there anything else I can help you with?
# -----
# Act:  The address for Ali Baba restaurant is 59 Hills Road City Centre.
#
# gold:  SYSTEM: You have a nice triip and thank you for contacting us. Have a great day!
#
# pred:  You're welcome! Let me know if you need any further assistance.
# -----
# Act:  There are two train schedules available for trains departing from Cambridge at or after 13:30. The first train (TR6028) leaves at 15:00 and arrives at London Kings Cross at 15:51. The second train (TR7786) leaves at 17:00 and arrives at London Kings Cross at 17:51.
#
# gold:  SYSTEM: On what day will you be travelling?
#
# pred:  I found two train schedules that match your request. The first train (TR6028) departs from Cambridge at 15:00 and arrives at London Kings Cross at 15:51. The second train (TR7786) departs from Cambridge at 17:00 and arrives at London Kings Cross at 17:51. Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: TR1159 will arrive by 12:07 would that work for you?
#
# pred:  I found a train departing from Cambridge at 13:30 on Sunday that arrives in Ely. Would you like me to confirm the booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Booked! You will pay 28.16 at the station, your reference number is FN62T8MF. Is there anything else you need?
#
# pred:  Sure, I can help you with that. Can you please confirm the names of the passengers and their ages?
# -----
# Act:  none.
#
# gold:  SYSTEM: Is there anything else I can do for you before we go?
#
# pred:  You're welcome! Have a great day and safe travels to Ely!
# -----
# Act:  none.
#
# gold:  SYSTEM: Okay, enjoy your trip!
#
# pred:  Thank you for using our booking service. Have a great day!
# -----
# Act:  none.
#
# gold:  SYSTEM: We have 5 places that offer all of that. Any preference on star rating or area?
#
# pred:  I can help you find an expensive hotel with free parking. Can you please provide me with the location you are interested in?
# -----
# Act:  The two guesthouses with free parking are "acorn guest house" located at 154 chesterton road, north area and "alexander bed and breakfast" located at 56 saint barnabas road, centre area.
#
# gold:  SYSTEM: Sorry, there are no guesthouse type expensive places with free parking. Perhaps you'd  prefer a different type or price range?
#
# pred:  Great! We have two options for you. The first is the Acorn Guest House located at 154 Chesterton Road in the North area, and the second is the Alexander Bed and Breakfast located at 56 Saint Barnabas Road in the Centre area. Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Sure, the Allenbell is a 4 star guesthouse.  Does that sound good?
#
# pred:  I can confirm a booking for you at the Budget Inn which offers free parking. Would you like me to proceed with the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: I've made your reservation. The reference number is E8NPWA4B. What else can I help you with?
#
# pred:  Certainly, I can confirm a reservation for 5 people at the Allenbell guesthouse starting Wednesday for 4 nights. Would you like me to proceed with the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: You're welcome, enjoy your stay!
#
# pred:  You're welcome! Enjoy your stay at the Allenbell. Let me know if you need any further assistance.
# -----
# Act:  The two hotels with moderate prices and free parking are Acorn Guest House (located at 154 Chesterton Road, North) and Arbury Lodge Guesthouse (located at 82 Arbury Road, North).
#
# gold:  SYSTEM: Acorn guest house has free parking and is moderately priced. Would you like more information?
#
# pred:  I can confirm a booking for you at either Acorn Guest House or Arbury Lodge Guesthouse. Which one would you prefer?
# -----
# Act:  Acorn Guest House has free wifi but it is not a 2-star rating, it has a 4-star rating.
#
# gold:  SYSTEM: No it doesn't.  But the Ashley Hotel has 2 stars and free parking.  It is a moderate also.
#
# pred:  Acorn Guest House has free wifi, but it is actually a 4-star rated accommodation. Would you like me to confirm a booking for you?
# -----
# Act:  The two hotels with both free wifi and parking are Acorn Guest House and Alexander Bed and Breakfast.
#
# gold:  SYSTEM: Yes. The Ashley Hotel has both free wifi and parking. Would you like to make a reservation?
#
# pred:  Both Acorn Guest House and Alexander Bed and Breakfast offer both free wifi and parking. Would you like me to confirm a booking for you at either of these options?
# -----
# Act:  The address for the ashley hotel is 74 Chesterton Road.
#
# gold:  SYSTEM: The ashley hotel is located at 74 chesterton road. Would you like any other information about it?
#
# pred:  The address for the Ashley Hotel is 74 Chesterton Road. Let me know if you need any further assistance with your reservation.
# -----
# Act:  The postcode for the Ashley Hotel is CB41ER.
#
# gold:  SYSTEM: The postcode is cb41er. Can I help you with anything else?
#
# pred:  The postcode for the Ashley Hotel is CB41ER. Is there anything else I can help you with?
# -----
# Act:  none.
#
# gold:  SYSTEM: They are located in the north.
#
# pred:  The Ashley Hotel is located on Chesterton Road, which is in the north part of town. Is there anything else I can assist you with?
# -----
# Act:  There is no information available for Ashley Zoo in the dataframe.
#
# gold:  SYSTEM: Thank you, have a great day, Goodbye.
#
# pred:  I'm sorry, but I don't have any information on the Ashley Zoo in my system. Is there anything else I can help you with?
# -----
# Act:  There is only one hotel that is expensive and located on the east side: Express by Holiday Inn Cambridge, located at 15-17 Norman Way, Coldhams Business Park.
#
# gold:  SYSTEM: express by holiday inn cambridge is on the east side and expensive.
#
# pred:  Express by Holiday Inn Cambridge, located at 15-17 Norman Way, Coldhams Business Park, is the only hotel that meets your criteria. Would you like me to confirm a booking for you?
# -----
# Act:  The Express by Holiday Inn Cambridge hotel includes free wifi.
#
# gold:  SYSTEM: Yes it does would you like me to book that for you?
#
# pred:  Yes, the Express by Holiday Inn Cambridge hotel includes free wifi. Would you like me to confirm your booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: Okay, you're all set! Your reference number is 7A2J5S4U.
#
# pred:  Great, I have confirmed your booking at express by holiday inn cambridge for 1 person starting on Monday, 2 days from now. Enjoy your stay!
# -----
# Act:  There are no zoos with free wifi and booking capabilities.
#
# gold:  SYSTEM: Thank you for contacting us. Have a wonderful visit.
#
# pred:  I'm sorry, but there are no zoos in the area that offer free wifi and booking capabilities. Is there anything else I can help you with?
# -----
# Act:  none
#
# gold:  SYSTEM: I can, would you like to take a taxi and from where?
#
# pred:  Sure, I can help you with that. Would you like me to confirm a booking for you at Michaelhouse Cafe for 12:45?
# -----
# Act:  none
#
# gold:  SYSTEM: I have you booked in a grey Volkswagen, 07828883795 is their number.
#
# pred:  I have confirmed a taxi booking for you departing from Williams Art and Antiques to Michaelhouse Cafe at 12:45. Your driver's name is John and his contact number is 555-1234. Enjoy your ride!
# -----
# Act:  none
#
# gold:  SYSTEM: Can I help you with anything else?
#
# pred:  Great, your taxi is confirmed for pickup at Williams Art and Antiques at 12:30 PM. You will be dropped off at Michaelhouse Cafe by 12:45 PM. Is there anything else I can assist you with?
# -----
# Act:  none
#
# gold:  SYSTEM: You're welcome and have a nice day.
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  There are two entertainment options on the east side of town: a swimming pool located at "pool way, whitehill road, off newmarket road" and a boat located at "the plough, green end, fen ditton".
#
# gold:  SYSTEM: Cherry Hinton Hall and Grounds is on the east side of town, would you like their phone number?
#
# pred:  Sure, I can help you with that. There are two options on the east side of town: a swimming pool located at "pool way, whitehill road, off newmarket road" and a boat located at "the plough, green end, fen ditton". Which one would you like me to book for you?
# -----
# Act:  The address and postcode for Cherry Hinton Hall and Grounds are "cherry hinton road" and "cb18dw".
#
# gold:  SYSTEM: Yes, it's Cherry Hinton Road, cb18dw.
#
# pred:  Sure, the address and postcode for Cherry Hinton Hall and Grounds are "Cherry Hinton Road" and "CB1 8DW". Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I'm sorry, the entrance fee isn't listed in my system.
#
# pred:  Sure, I can help you confirm your booking and provide you with the entrance fee. Would you like me to proceed with the booking?
# -----
# Act:  There is no zoo in the given dataframe.
#
# gold:  SYSTEM: Thank you, if you need anything else let me know.Good Bye.
#
# pred:  You're welcome! Let me know if you need help with anything else.
# -----
# Act:  none.
#
# gold:  SYSTEM: Unfortunately, there are no eastern European restuarants in the south part of the city. Is there anything else you want?
#
# pred:  Yes, there is a great Eastern European restaurant called "Balkan Bites" located in the south part of the city. Would you like me to make a reservation for you?
# -----
# Act:  There are no Eastern European restaurants in the south in the dataframe.
#
# gold:  SYSTEM: Unfortunately, I don't happen to have any listing that meets what you were looking for. Would you like me to try either a different area or type of restaurant?
#
# pred:  I'm sorry, but there are no Eastern European restaurants in the south part of the city. Would you like me to suggest some other types of restaurants in the area?
# -----
# Act:  none.
#
# gold:  SYSTEM: Certainly, we have two expensive Chinese restaurants the good luck chinese food takeaway, and peking restaurant. Would you like a reservation at one, if so for how many?
#
# pred:  Sure, I can help you find a Chinese restaurant in the south part of the city. Do you have any specific preferences or dietary restrictions?
# -----
# Act:  none.
#
# gold:  SYSTEM: OK, and what day and time would you like that reservation?
#
# pred:  Great, I can confirm a reservation for 2 at the Peking Restaurant. What date and time would you like the reservation for?
# -----
# Act:  Address: 10 Homerton Street City Centre, Phone: 01223354755, Price Range: expensive
#
# gold:  SYSTEM: Your reservation is complete. Would you like anything else?
#
# pred:  No problem, I have updated your reservation to be for one person at the Peking Restaurant on Saturday at 11:45. Would you like me to confirm the reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes, the reference number is KNL2J63Q.
#
# pred:  Sure, your reference number for the reservation at Peking Restaurant on Saturday at 11:45 is 123456. Enjoy your meal!
# -----
# Act:  none.
#
# gold:  SYSTEM: Awesome. Enjoy your meal.
#
# pred:  Thank you for choosing our service. Have a great day!
# -----
# Act:  There are two hotels in the north with a cheap price range: City Centre North B and B located at 328a Histon Road and Worth House located at 152 Chesterton Road.
#
# gold:  SYSTEM: Okay. There is a 0 star place, and a 4 star place. Which do you prefer?
#
# pred:  I found two hotels in the north with a cheap price range: City Centre North B and B located at 328a Histon Road and Worth House located at 152 Chesterton Road. Which one would you like me to book for you?
# -----
# Act:  There are two hotels with cheap price range and in the north area:
# 1. City Centre North B and B located at 328a Histon Road, with 0 stars, internet and parking available, and takes bookings.
# 2. Worth House located at 152 Chesterton Road, with 4 stars, internet and parking available, and takes bookings.
#
# gold:  SYSTEM: I think the Worth House is your best bet!
#
# pred:  Great, I found two options for you. City Centre North B and B is a 0 star hotel located at 328a Histon Road, and Worth House is a 4 star hotel located at 152 Chesterton Road. Both hotels are in the north and have cheap prices. Which one would you like me to book for you?
# -----
# Act:  There are two hotels in the cheap price range and in the north with booking functionality:
#
# 1. City Centre North B and B: Located at 328a Histon Road, North, with internet and parking available. It has 0 stars.
# 2. Worth House: Located at 152 Chesterton Road, North, with internet and parking available. It has 4 stars.
#
# gold:  SYSTEM: Are you booking for one person? When is your arrival and how long is your stay, please.
#
# pred:  Great choice! I have confirmed your booking at Worth House. Enjoy your stay!
# -----
# Act:  Worth House has a price range of "cheap", 4 stars, and accepts bookings.
#
# gold:  SYSTEM: I'm sorry I don't have anything for Sunday night. Would you like to try a different hotel?
#
# pred:  Great! I can confirm your booking at Worth House for one person arriving on Sunday for one night. Would you like me to proceed with the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes, there i the worth house and also city centre north b and b. Would you like me to book you a room at either one?
#
# pred:  Sure, I can help you find a cheap guesthouse in the north with free wifi. Can you please provide me with your preferred location and dates of stay?
# -----
# Act:  The star rating is 4 and the postcode is cb12dp for the chosen guesthouse.
#
# gold:  SYSTEM: I have booked you at worth house. It is a 4 star accommodation, and the postcode is cb41da.  Do you have any further questions?
#
# pred:  The guesthouse you requested has a 4-star rating and its postcode is cb12dp. Would you like me to confirm your booking now?
# -----
# Act:  none.
#
# gold:  SYSTEM: You're welcome. Have a good time.
#
# pred:  You're welcome! Enjoy your stay at Worth House.
# -----
# Act:  The first two hotels in the north part of town are Acorn Guest House (located at 154 Chesterton Road) and Alpha-Milton Guest House (located at 63 Milton Road).
#
# gold:  SYSTEM: There are two hotels in the north part of town in the moderate price range, does that price range work for you?
#
# pred:  I found two options for you in the north part of town: Acorn Guest House on Chesterton Road and Alpha-Milton Guest House on Milton Road. Which one would you like me to book for you?
# -----
# Act:  1. Acorn Guest House: Address - 154 Chesterton Road, Internet - Yes, Parking - Yes, Price Range - Moderate, Takes Bookings - Yes, Type - Guesthouse
# 2. Arbury Lodge Guesthouse: Address - 82 Arbury Road, Internet - Yes, Parking - Yes, Price Range - Moderate, Takes Bookings - Yes, Type - Guesthouse
#
# gold:  SYSTEM: I'm sorry, they are both 2 star hotels. Would you like to try a different area or star number?
#
# pred:  Yes, both Acorn Guest House and Arbury Lodge Guesthouse have 4 stars. Would you like me to confirm a booking for you at either of these hotels?
# -----
# Act:  none.
#
# gold:  SYSTEM: There are several in the moderate price range and one that is cheap.  Does price matter?
#
# pred:  I have found a 4 star guesthouse in the north part of town. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I recommend Worth House because it is in the cheap price range and has a high rating. Do you want me to book Worth House for you?
#
# pred:  Based on your preferences, I would recommend the North Star Guesthouse. It has a 4-star rating and falls within your preferred price range. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I have made reservations for 3 starting on Sunday for 3 nights.
#
# pred:  Great! I can confirm a reservation for Worth House for 3 nights starting Sunday for a party of 3. Is there anything else you need help with?
# -----
# Act:  I cannot provide the reservation reference number as the dataframe does not have information about availability or reservation reference numbers.
#
# gold:  SYSTEM: All set! Your reference number is 7PUKE6MS. Do you need any more help?
#
# pred:  I apologize, but I am unable to provide a reservation reference number at this time. Is there anything else I can assist you with?
# -----
# Act:  I'm sorry, but the given dataframe does not contain any columns related to reservation information or reference number. The available columns are: name, address, area, internet, parking, price, pricerange, stars, takesbookings, and type. Please provide more information or a different dataframe with the required columns.
#
# gold:  SYSTEM: great to hear that bye
#
# pred:  I'm sorry, but I am not able to provide a reference number as I do not have access to your reservation information. Is there anything else I can assist you with?
# -----
# Act:  There are two train schedules for Saturday after 16:30:
# 1. Train ID TR8134 leaves at 17:00 and arrives at 17:51 with a duration of 51 minutes and a price of 18.88 pounds.
# 2. Train ID TR0427 leaves at 19:00 and arrives at 19:51 with a duration of 51 minutes and a price of 18.88 pounds.
#
# gold:  SYSTEM: From where and to where will you travel?
#
# pred:  I found two train schedules for Saturday after 16:30. Train ID TR8134 leaves at 17:00 and arrives at 17:51 with a duration of 51 minutes and a price of 18.88 pounds. Alternatively, Train ID TR0427 leaves at 19:00 and arrives at 19:51 with a duration of 51 minutes and a price of 18.88 pounds. Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I have one leaving at 17:29, arriving in Bishop's Stortford at 18:07. Does that work?
#
# pred:  I found a train leaving Cambridge for Bishops Stortford at 17:05 on Saturday. Would you like me to confirm the booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Great. I have booked those seats for you and your reference number is JAVMFJGM. Is there anything else I can do for you?
#
# pred:  Great, I can confirm your booking for three tickets on the 17:29 train from Cambridge to Bishop's Stortford on Saturday. Can I have your payment information to complete the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: Thank you for using our service. Have all of your needs been met?
#
# pred:  Thank you for using our booking service. Have a great day!
# -----
# Act:  You have booked 3 tickets for the following trains:
#
# 1. Train ID: TR7075, Departure: Cambridge, Destination: London Kings Cross, Leave At: 05:00, Arrive By: 05:51, Duration: 51 minutes, Price: 23.60 pounds
# 2. Train ID: TR2289, Departure: Cambridge, Destination: London Kings Cross, Leave At: 07:00, Arrive By: 07:51, Duration: 51 minutes, Price: 23.60 pounds
#
# Your booking reference number is: 70acafa9-0201-4a8d-90b2-10e0e34f3ad1
#
# gold:  SYSTEM: You're welcome, enjoy your trip.
#
# pred:  Great, I have successfully booked your tickets for trains TR7075 and TR2289. Your booking reference number is 70acafa9-0201-4a8d-90b2-10e0e34f3ad1. Is there anything else I can assist you with?
# -----
# Act:  none
#
# gold:  SYSTEM: What time frame would you like this to happen in?
#
# pred:  Sure, I can help you with that. What date and time would you like the taxi to pick you up?
# -----
# Act:  none
#
# gold:  SYSTEM: Booking completed!
# Booked car type	:	yellow toyota
# Contact number	:	07598718295
#
#
# pred:  Sure, I can confirm a taxi booking for you to arrive at Cineworld Cinema from Gonville Hotel at 15:45. Is that okay?
# -----
# Act:  none
#
# gold:  SYSTEM: Can I do anything else for you today?
#
# pred:  Great, happy fishing! Let me know if you need any further assistance.
# -----
# Act:  none
#
# gold:  SYSTEM: You're welcome, have a great day. Bye!
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  Here are one or two hotels with free wifi and parking:
#
# 1. Acorn Guest House - 154 Chesterton Road, North - Moderate price range, 4 stars, Guesthouse
# 2. Alexander Bed and Breakfast - 56 Saint Barnabas Road, Centre - Cheap price range, 4 stars, Guesthouse
#
# gold:  SYSTEM: Yes there are plenty. What area would you like to stay in?
#
# pred:  Yes, there are hotels with free wifi and parking. Here are a couple of options that match your criteria:
# 1. Acorn Guest House - 154 Chesterton Road, North - Moderate price range, 4 stars, Guesthouse
# 2. Alexander Bed and Breakfast - 56 Saint Barnabas Road, Centre - Cheap price range, 4 stars, Guesthouse
# Would you like me to confirm a booking for you at one of these hotels?
# -----
# Act:  There are two guesthouses in the centre with free wifi and parking: Alexander Bed and Breakfast (address: 56 Saint Barnabas Road) and El Shaddai (address: 41 Warkworth Street).
#
# gold:  SYSTEM: There are two hotels that fit that criteria. I would recommend Alexander Bed and Breakfast, it has four stars.
#
# pred:  Great! I found two guesthouses in the centre that offer free wifi and parking: Alexander Bed and Breakfast (address: 56 Saint Barnabas Road) and El Shaddai (address: 41 Warkworth Street). Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I'm sorry, your booking was unsuccessful. Would you like to book another day or a shorter stay?
#
# pred:  Great, I can confirm your booking at Alexander Bed and Breakfast for 1 person for 4 nights starting from Tuesday. Would you like me to proceed with the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: Booking was successful.
# Reference number is : QHR6UO6I.
#
# pred:  Great, I have successfully booked Alexander Bed and Breakfast for 1 person for 4 nights starting from Wednesday. Is there anything else I can assist you with?
# -----
# Act:  The top 2 guesthouses that accept bookings are "a and b guest house" located at 124 Tenison Road and "acorn guest house" located at 154 Chesterton Road.
#
# gold:  SYSTEM: You are more than welcome!
#
#
# pred:  You're welcome! By the way, if you're interested, I can also help you confirm a booking at one of the top 2 guesthouses that accept bookings: "a and b guest house" located at 124 Tenison Road or "acorn guest house" located at 154 Chesterton Road. Let me know if you'd like me to proceed with the booking.
# -----
# Act:  none.
#
# gold:  SYSTEM: There are 133 trains making that trip, do you have a day and time you want to travel?
#
# pred:  Sure, I can help you with that. When would you like to travel and what time?
# -----
# Act:  none.
#
# gold:  SYSTEM: TR0672 departs at 22:11. Can you tell me how many tickets you need?
#
# pred:  Sure, I can confirm a reservation for you on the 21:15 train from King's Lynn to Cambridge on Friday. Can I have your name and payment information to complete the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: Booking was successful, the total fee is 19.6 GBP payable at the station. Reference number is : 4J73XCBG. Is there anything else I can help with?
#
# pred:  Great, I have booked 2 tickets for TR0672 departing from King's Lynn to Cambridge on Friday at 22:11. Your reservation details will be sent to your email shortly. Is there anything else I can assist you with?
# -----
# Act:  Train Schedule and Availability Information:
# 1. Train ID: TR7075
#    Day: Monday
#    Departure: Cambridge
#    Destination: London Kings Cross
#    Duration: 51 minutes
#    Leave At: 05:00
#    Arrive By: 05:51
#
# 2. Train ID: TR2289
#    Day: Monday
#    Departure: Cambridge
#    Destination: London Kings Cross
#    Duration: 51 minutes
#    Leave At: 07:00
#    Arrive By: 07:51
#
# Booking System Access: Please visit our website or use our mobile app to book your tickets and check the availability of the trains.
#
# gold:  SYSTEM: Have a great day!
#
# pred:  Thank you for using our booking system. Have a great day!
# -----
# Act:  The top two accommodation options in the centre of town are "Alexander Bed and Breakfast" and "Cityroomz".
#
# gold:  SYSTEM: I can definitely help with that. I have about 5 different hotels and guesthouses that are in the centre of town. Do you prefer a hotel or guesthouse?
#
# pred:  Sure, I can definitely help you with that. Based on your location, the top two accommodation options in the centre of town are "Alexander Bed and Breakfast" and "Cityroomz". Would you like me to confirm a booking for you at either of these options?
# -----
# Act:  none.
#
# gold:  SYSTEM: The University Arms Hotel is in the centre of town, falls in the expensive price range, and has 4 stars. Would you like to book a room?
#
# pred:  Sure, I can help you find a 4-star rated hotel in the centre of town. Can you please provide me with your preferred dates of stay?
# -----
# Act:  none.
#
# gold:  SYSTEM: It is available for four nights for five people!  I've taken the liberty of booking these rooms for you.  Is that agreeable to you?
#
# pred:  Sure, I can check availability for you. Would you like me to confirm the booking for you?
# -----
# Act:  bookingref
#
# gold:  SYSTEM: Can you also give me the address for the hotel
#
# pred:  Your booking reference number is bookingref. Please keep this number handy for any future inquiries or changes to your reservation. Thank you for choosing our service!
# -----
# Act:  none.
#
# gold:  SYSTEM: 8L6LVYYT is your reference number.
#
# pred:  Sure, your reference number for the booking is 123456. And no worries, I'll look up the address for you. The hotel is located at 123 Main Street. Is there anything else I can assist you with?
# -----
# Act:  none.
#
# gold:  SYSTEM: Perfect. You've made an excellent choice. Enjoy!
#
# pred:  Glad to have been of help! Don't hesitate to reach out if you need anything else in the future. Have a great day!
# -----
# Act:  The two expensive restaurants in the center of town are "curry garden" and "stazione restaurant and coffee bar".
#
# gold:  SYSTEM: What type of food would you like to eat?
#
# ...
#
# gold:  SYSTEM: How about a and b guest house?
#
# pred:  Great, I found two options that meet your criteria. A and B Guest House located at 124 Tenison Road, East, and Acorn Guest House located at 154 Chesterton Road, North. Which one would you like me to book for you?
# -----
# Act:  0
#
# gold:  SYSTEM: When would you like to book this for?
#
# pred:  Great, I can confirm your booking for a and b guest house. Can you please provide me with your preferred dates and number of guests?
# -----
# Act:  none.
#
# gold:  SYSTEM: Sorry, the hotel can't accommodate you for that time frame? Want to try a different date?
#
# pred:  Great, I can confirm your booking for a and b guest house for Sunday, 3 nights and 6 people. Can you please provide me with your contact information and payment details to complete the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: I can try for the Acorn Guest House, if you'd like. They're on Chesterton Road.
#
# pred:  Sure, I can help you find a different hotel. Can you please provide me with your preferred location and budget?
# -----
# Act:  none.
#
# gold:  SYSTEM: Sorry, the Acorn Guest house is not able to accomodate you either. I checked with the other moderately priced 4 star lodgings with free wifi, and none have those dates available. Will any other stay work for you?
#
# pred:  Sure, I can confirm a booking for the Acorn Guest House on Chesterton Road for Sunday for 3 nights and 6 people. Is there anything else you need help with?
# -----
# Act:  The Acorn Guest House and A and B Guest House are both moderately priced 4-star lodgings with free wifi. They both accept bookings.
#
# gold:  SYSTEM: I've booked that for you. The reference number is 3CRY3DDP. May I help with anything else?
#
# pred:  Great, I can confirm a booking for you at either the Acorn Guest House or A and B Guest House for 2 nights. Which one would you prefer?
# -----
# Act:  Here are two options for moderately priced 4-star lodgings with free wifi for 2 nights:
#
# 1. Name: A and B Guest House
#    Address: 124 Tenison Road, East
#    Type: Guesthouse
#    Takes Bookings: Yes
#
# 2. Name: Acorn Guest House
#    Address: 154 Chesterton Road, North
#    Type: Guesthouse
#    Takes Bookings: Yes
#
# gold:  SYSTEM: You're welcome. Have a great day.
#
# pred:  Great, I have found two options for you. A and B Guest House on Tenison Road and Acorn Guest House on Chesterton Road. Both are moderately priced 4-star lodgings with free wifi and have availability for 2 nights. Which one would you like me to book for you?
# -----
# Act:  none
#
# gold:  SYSTEM: Easy enough. What time would you like to leave by as well as arrive to?
#
# pred:  Sure, I can help you with that. What date and time would you like the taxi to arrive?
# -----
# Act:  none
#
# gold:  SYSTEM: I booked that for you. The car will be a white honda and the contact number is 07804995392.
#
# pred:  Great, I have booked a taxi for you to leave Avalon at 7:00am to arrive at De Luca Cucina and Bar by 7:30am. Your confirmation number is 123456. Is there anything else I can assist you with?
# -----
# Act:  none
#
# gold:  SYSTEM: You are very welcome, have a great day!
#
# pred:  You're welcome! Have a great day and enjoy your ride to De Luca Cucina and Bar.
# -----
# Act:  There are two train schedules that match the criteria:
# 1. Train ID: TR3929, Departure: Cambridge, Destination: London Liverpool Street, Leave at: 05:59, Arrive by: 07:27, Duration: 88 minutes, Price: 16.60 pounds
# 2. Train ID: TR1992, Departure: Cambridge, Destination: London Liverpool Street, Leave at: 07:59, Arrive by: 09:27, Duration: 88 minutes, Price: 16.60 pounds
#
# gold:  SYSTEM: Which day will you be traveling?
#
# pred:  Here are two train schedules that match your criteria:
# 1. Train ID: TR3929, Departure: Cambridge, Destination: London Liverpool Street, Leave at: 05:59, Arrive by: 07:27, Duration: 88 minutes, Price: 16.60 pounds
# 2. Train ID: TR1992, Departure: Cambridge, Destination: London Liverpool Street, Leave at: 07:59, Arrive by: 09:27, Duration: 88 minutes, Price: 16.60 pounds
# Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Ok, I should be able to do that for you.
#
# pred:  I found a train leaving from London Liverpool Street at 7:45am and arriving at 9:30am on Thursday. Would you like me to confirm the booking for you?
# -----
# Act:  1. Train ID: TR3839, Leave at: 05:39, Arrive by: 07:07, Duration: 88 minutes, Price: 16.60 pounds
# 2. Train ID: TR4204, Leave at: 07:39, Arrive by: 09:07, Duration: 88 minutes, Price: 16.60 pounds
#
# gold:  SYSTEM: There are three trains that will fit your needs, and the tickets are 16.60 pounds each. Would you like me to purchase tickets for you?
#
# pred:  I found two options for you. Train ID TR3839 leaves at 05:39 and arrives at 07:07, while train ID TR4204 leaves at 07:39 and arrives at 09:07. Both take 88 minutes and cost 16.60 pounds. Which one would you like me to book for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Would you like me to book that for you?
#
# pred:  Great! I have confirmed your booking for the train to Cambridge on Thursday. Your tickets will be sent to your email shortly. Is there anything else I can assist you with?
# -----
# Act:  The train ticket costs for Cambridge are 23.60 pounds and 18.88 pounds.
#
# gold:  SYSTEM: Yes, there are 3 that cost 16.60 pounds.  You could leave at 5:39 if you'd like.  Can I book that for you?
#
# pred:  The train ticket costs for Cambridge range from 18.88 to 23.60 pounds. Would you like me to book the tickets for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: It's my pleasure. Goodbye!
#
# pred:  You're welcome! Have a great day!
# -----
# Act:  The first two train schedules departing from Cambridge are:
# 1. Train ID: TR7075, Departure: 05:00, Arrival: 05:51, Duration: 51 minutes, Price: 23.60 pounds, Destination: London Kings Cross
# 2. Train ID: TR2289, Departure: 07:00, Arrival: 07:51, Duration: 51 minutes, Price: 23.60 pounds, Destination: London Kings Cross
#
# gold:  SYSTEM: Certainly! Where would you like to go?
#
# pred:  Here are the first two train schedules departing from Cambridge:
# 1. Train ID: TR7075, Departure: 05:00, Arrival: 05:51, Duration: 51 minutes, Price: 23.60 pounds, Destination: London Kings Cross
# 2. Train ID: TR2289, Departure: 07:00, Arrival: 07:51, Duration: 51 minutes, Price: 23.60 pounds, Destination: London Kings Cross
# Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: There are plenty of trains going there.  What day and time would you like to travel?
#
# pred:  I found a train departing from Cambridge to Birmingham New Street at 10:15am. Would you like me to confirm the booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I have a train leaving Cambridge at 15:01, and arriving on Birmingham new street at 17:44.
#
# pred:  Great, I found a train departing from Cambridge to Birmingham New Street on Sunday at 15:30. Would you like me to confirm the booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: The price is 60.08 pounds, payable at the station. May I help with anything else?
#
# pred:  The price for that train is £35. Would you like me to confirm the booking for you?
# -----
# Act:  Here are one or two maximum train schedule and price information for the specified time and route:
#
# 1. Train ID: TR7409
#    Departure: Cambridge
#    Destination: London Kings Cross
#    Leave At: 09:00
#    Arrive By: 09:51
#    Duration: 51 minutes
#    Price: 23.60 pounds
#    Day: Monday
#
# 2. Train ID: TR3371
#    Departure: Cambridge
#    Destination: London Kings Cross
#    Leave At: 09:00
#    Arrive By: 09:51
#    Duration: 51 minutes
#    Price: 23.60 pounds
#    Day: Tuesday
#
# gold:  SYSTEM: Thank you for contacting us. You have a great trip in cambridge.
#
# pred:  Glad to be of help! Let me know if you need anything else.
# -----
# Act:  The top 1 or 2 restaurants in the centre that serve Chinese food are Charlie Chan and Jinling Noodle Bar.
#
# gold:  SYSTEM: Chinese sounds great. I have a variety of restaurants. Which price range do you prefer?
#
# pred:  How about trying Charlie Chan or Jinling Noodle Bar? They are the top 1 or 2 restaurants in the centre that serve Chinese food. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: The lan hong house is a moderately priced chinese restaurant in the centre area at 12 Norfolk Street city centre. The phone number is 01223350420 and the postcode is cb12lf.
#
# pred:  Great! I found a moderate Chinese restaurant in the center called "Golden Wok". Their phone number is 555-1234, and their address is 123 Main Street, postcode 12345. Would you like me to make a reservation for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: I'm happy we could help you today! Enjoy your meal!
#
# pred:  Great! Would you like me to make a reservation for you at Lan Hong House?
# -----
# Act:  Here are two affordable accommodations:
#
# 1. Alexander Bed and Breakfast: Located at 56 Saint Barnabas Road, Centre area. It has internet, 4 stars, and takes bookings. It is a guesthouse.
#
# 2. Allenbell: Located at 517a Coldham Lane, East area. It has internet, 4 stars, and booking information is not available. It is a guesthouse.
#
# gold:  SYSTEM: I can certainly help you with that. We have 10 listings for cheap lodgings. Do you have any other requirements?
#
# pred:  Based on your preferences, I recommend Alexander Bed and Breakfast. It's located at 56 Saint Barnabas Road in the Centre area and has internet, 4 stars, and takes bookings. Would you like me to confirm a booking for you?
# -----
# Act:  none.
#
# gold:  SYSTEM: Sure.  I found 2 guesthouses.  One with 4 stars and one with 0 stars.  Do you have a preference?
#
# pred:  Sure, I can confirm a booking for you at one of our cheap lodgings located in the center of town. Would you like me to proceed with the booking?
# -----
# Act:  none.
#
# gold:  SYSTEM: Yes, they both do. The Alexander B&B is our inexpensive 4 star guesthouse. Would you like me to see if I could book you room?
#
# pred:  Both guesthouses offer free wi-fi for their guests. Would you like me to confirm a booking for you at one of them?
# -----
# Act:  The availability of Wi-Fi in the guesthouses can be either 'yes' or 'no'.
#
# gold:  SYSTEM: You are very welcome! Is there anything else I can assist you with?
#
# pred:  Just let me know if you change your mind and would like me to book a room for you at the Alexander B&B.
# -----
# Act:  The Alexander B&B has Wi-Fi availability (yes) and takes bookings (yes).
#
# gold:  SYSTEM: Have a great day!
#
# pred:  Great! Don't hesitate to reach out if you need any further assistance in the future. Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: Where will you be heading to ?
#
# pred:  Sure, we can arrange a pick-up for you from Pizza Hut City Centre at 04:30. Can you please confirm the date and time of your booking?
# -----
# Act:  none
#
# gold:  SYSTEM: Great. Your booking is complete. A yellow ford will pick you up and can be reached by dialing 07017220129
#
#
# pred:  I can confirm a booking for a ride from Pizza Hut City Centre to Gonville Hotel at 4:30 PM. Would you like me to proceed with the booking?
# -----
# Act:  none
#
# gold:  SYSTEM: Have a great day and thank you for contacting us.
#
# pred:  Thank you for using our service. Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: What is your destination and when would you like to depart?
#
# pred:  Sure, I can help you with that. Where would you like to go?
# -----
# Act:  none
#
# gold:  SYSTEM: I have you in a Red Lexus, 07595414661 is the number to call if you need to speak to them.
#
# pred:  I can confirm a booking for you departing from Gandhi to Broxbourne train station, arriving by 02:00. Is that okay for you?
# -----
# Act:  none
#
# gold:  SYSTEM: My pleasure. Do you need any other assistance while in town?
#
# pred:  Your booking has been confirmed for a Red Lexus departing from Gandhi to Broxbourne train station, arriving by 02:00. If you need to speak to the driver, their number is 07595414661. Thank you for choosing our service.
# -----
# Act:  none
#
# gold:  SYSTEM: Okay. Please let us know if there's anything else we can do for you during your visit to Cambridge.
#
# pred:  Alright, have a safe trip!
# -----
# Act:  The two hotels with free wifi and free parking are Acorn Guest House (located at 154 Chesterton Road, North) and Alexander Bed and Breakfast (located at 56 Saint Barnabas Road, Centre).
#
# gold:  SYSTEM: There are 29 places with free internet and parking. Do you have an area, price, star, or hotel type preference?
#
# pred:  I can confirm a booking for you at either Acorn Guest House or Alexander Bed and Breakfast. Which one would you prefer?
# -----
# Act:  none.
#
# gold:  SYSTEM: Unfortunately, I don't happen to have any guesthouses that are in the expensive range. Can I look in another price range perhaps?
#
# pred:  Sure, I can help you with that. I found a guesthouse called "The Luxe Guesthouse" that has free wifi and parking. It's a bit on the expensive side, but it's definitely worth it. Would you like me to confirm the booking for you?
# -----
# Act:  The top one or two hotels with free wifi, parking, and in the moderate price range are:
# 1. Acorn Guest House, located at 154 Chesterton Road, North area.
# 2. Arbury Lodge Guesthouse, located at 82 Arbury Road, North area.
#
# gold:  SYSTEM: I have 12 guesthouses that match your needs. Do you have additional requirements to narrow down the search?
#
# pred:  Great, I can confirm a booking for you at either the Acorn Guest House or the Arbury Lodge Guesthouse. Which one would you prefer?
# -----
# Act:  none.
#
# gold:  SYSTEM: Acorn Guest House is a 4 star place that meets your requirements. The phone number is 01223353888.
#
# pred:  Sure, I can confirm a booking for you at the "Cozy Guesthouse" which has a 3-star rating, free wifi, and free parking. The phone number is 555-1234. Would you like me to proceed with the booking?
# -----
# Act:  There are two guest houses that meet the criteria:
#
# 1. Acorn Guest House
#    Address: 154 Chesterton Road
#    Stars: 4
#    Phone: 01223353888
#
# 2. Arbury Lodge Guesthouse
#    Address: 82 Arbury Road
#    Stars: 4
#    Phone: 01223364319
#
# gold:  SYSTEM: Enjoy! Goodbye!
#
# pred:  Great! I can confirm a booking for you at Acorn Guest House. Would you like me to proceed with the booking?
# -----
# Act:  none
#
# gold:  SYSTEM: I'd be happy to help. What time do you want to leave and/or arrive by?
#
# pred:  Sure, I can help you with that. Can you please provide me with your current location and the desired time of arrival at the museum?
# -----
# Act:  none
#
# gold:  SYSTEM: What is your departure site?
#
# pred:  Great, I can confirm a taxi booking for you at 3:00 PM to the Scott Polar Museum. Is there anything else I can assist you with?
# -----
# Act:  none
#
# gold:  SYSTEM: Okay I have a grey lexus and the contact number is 07089138985. Anything else I can do for you?
#
# pred:  Great, I can confirm your booking for a taxi from London Kings Cross train station to the Scott Polar Museum at 3:00 PM. Can you please provide me with a contact phone number and your preferred car type?
# -----
# Act:  none
#
# gold:  SYSTEM: I need a taxi to the Scott polar museum.
#
# pred:  Thank you for choosing our service. Your booking has been confirmed for 3:00 PM pickup from London Kings Cross train station. Our driver will be in a grey Lexus and you can expect a call from 07089138985. Have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: Thank you for using Cambridge TownInfo centre, have a nice day.
#
# pred:  No problem, have a great day!
# -----
# Act:  none
#
# gold:  SYSTEM: Where are you departing from?
#
# pred:  Sure, I can help you with that. Can you please confirm the date and time of your departure?
# -----
# Act:  none
#
# gold:  SYSTEM: All right, a red skoda will pick you up. The contact number is 07278222346.
#
#
# pred:  Great, I can confirm a taxi booking for you to leave from Gardenia to Arbury Lodge Guesthouse after 11:00. Is that okay?
# -----
# Act:  none
#
# gold:  SYSTEM: You're welcome! What else can I do for you?
#
# pred:  You're welcome! Is there anything else I can assist you with today?
# -----
# Act:  none
#
# gold:  SYSTEM: Let us know if you need anything else, bye.
#
# pred:  Thank you for using our service. Have a great day!
# -----

# %%
restaurant_db = json.load(open("MultiWOZ_2.1/hotel_db.json", "r"))

# %%
df = pd.DataFrame(restaurant_db)

# %%
df.head(2)
# Out:
#   arriveBy     day  departure         destination    duration leaveAt  \
# 0    05:51  monday  cambridge  london kings cross  51 minutes   05:00
# 1    07:51  monday  cambridge  london kings cross  51 minutes   07:00
#
#           price trainID
# 0  23.60 pounds  TR7075
# 1  23.60 pounds  TR2289

# %%
df = df[['name'] + [col for col in df.columns if col != 'name']]
df.head(2)
# Out:
#                     name                        address    area  \
# 0  pizza hut city centre      Regent Street City Centre  centre
# 1       the missing sock  Finders Corner Newmarket Road    east
#
#          cuisine     id  \
# 0        italian  19210
# 1  international  30650
#
#                                                                                                                  introduction  \
# 0  Pizza hut is a large chain with restaurants nationwide offering convenience pizzas pasta and salads to eat in or take away
# 1
#
#                location        phone postcode pricerange        type  \
# 0  [52.20103, 0.126023]  01223323737   cb21ab      cheap  restaurant
# 1  [52.21768, 0.224907]  01223812660  cb259aq      cheap  restaurant
#
#          signature
# 0              NaN
# 1  african babooti

# %%
df.loc[(df['type'] == 'restaurant') & (df['cuisine'] == 'british') & (df['area'] == 'west')][['name', 'address']]
# Out:
#                       name                                      address
# 53  saint johns chop house                   21 - 24 Northampton Street
# 81                graffiti  Hotel Felix Whitehouse Lane Huntingdon Road
# 93         travellers rest                  Huntingdon Road City Centre

# %%
file_path="MultiWOZ_2.1/restaurant_db.json"
data = json.loads(Path(file_path).read_text())
df = pd.DataFrame(data)

# %%
df = df.drop(columns=["location", "introduction", "signature", "id"])
df = df.rename(columns={'food': 'cuisine'})
df = df[['name'] + [col for col in df.columns if col != 'name']]

# %%
df.query("type == 'restaurant' and cuisine == 'british' and area == 'west'").head(2)
# Out:
#                       name                                      address  area  \
# 53  saint johns chop house                   21 - 24 Northampton Street  west
# 81                graffiti  Hotel Felix Whitehouse Lane Huntingdon Road  west
#
#     cuisine        phone postcode pricerange        type
# 53  british  01223353110   cb30ad   moderate  restaurant
# 81  british  01223277977   cb30lx  expensive  restaurant

# %%
df_e2e_agent = pd.read_csv("/home/willy/instructod/src/e2e/results/gpt-3.5-turbo_e2e_agents_full_output.csv")

# %%
df_e2e_agent["preds_e2e_dialog_acts"].count
# Out:
# <bound method Series.count of 0        none
# 1        none
# 2        none
# 3        none
# 4       none.
#         ...
# 1054     none
# 1055     none
# 1056     none
# 1057     none
# 1058     none
# Name: preds_e2e_dialog_acts, Length: 1059, dtype: object>

# %%
df_e2e_agent["preds_e2e_dialog_acts"][0] == "none"
# Out:
# True

# %% [markdown]
# ## Comparison

# %%
df_rg = pd.read_csv("/home/willy/instructod/src/RG/results/gpt-4_rg_full_output.csv")
df_e2e = pd.read_csv("/home/willy/instructod/src/e2e/results/gpt-3.5-turbo_e2e_full_output.csv")
df_e2e = pd.merge(dataset, df_e2e[["id", "preds"]], on=["id"], how="right")
df_e2e_agent = pd.read_csv("/home/willy/instructod/src/e2e/results/gpt-3.5+4-turbo_e2e_agents_full_output.csv")
df_e2e_agent = pd.merge(dataset, df_e2e_agent[["id", "preds", "preds_e2e_dialog_acts"]], on=["id"], how="right")
pptod_e2e = json.load(open("/home/willy/instructod/pptod/E2E_TOD/inference_result/base/full_training/inference_result_e2e_evaluation_inform_89.2_success_79.4_bleu_18.62_combine_score_102.92.json", "r"))
pptod_e2e = pd.DataFrame([dict(item, **{"id":idx}) for idx, item in enumerate(pptod_e2e)])
pptod_e2e = pptod_e2e.rename(columns={"resp_gen":"preds"})
# df_e2e_agent_gpt3 = pd.read_csv("/home/willy/instructod/src/e2e/results/gpt-3.5-turbo_e2e_agents_full_output.csv")
# df_e2e_agent_gpt3 = pd.merge(dataset, df_e2e_agent[["id", "preds", "preds_e2e_dialog_acts"]], on=["id"], how="right")

# %%
count = 0
for idx, row in df_e2e_agent.iterrows():
    sample_id = row["id"]
    row_e2e = df_e2e.loc[df_e2e["id"] == sample_id]
    row_rg = df_rg.loc[df_rg["id"] == sample_id]
    row_pptod_e2e = pptod_e2e.loc[pptod_e2e["id"] == sample_id]
    if "none" in str(row["preds_e2e_dialog_acts"]):
        continue
    print("context        :", row["dialogue_context"])
    print("gold           :", row["gold_response"])
    print("pptod          :", row_pptod_e2e["preds"].item())
    print("rg             :", row_rg["preds"].item())
    print("e2e_single     :", row_e2e["preds"].item())
    print("e2e_multi      :", row["preds"])
    print("----------")
    count += 1
print(f"Printed {count} results")
# Out:
# context        : USER: If one of them has a moderate price range please give me that address. If not tell me about Turkish restaurants instead.
#
# gold           : SYSTEM: I have two Turkish restuarants, both in the centre and both expensive. May I recommend anatolia?
#
# pptod          : [value_name] is a [value_price] [value_food] restaurant in the [value_area] . it is located at [value_address] .
# rg             : I recommend Anatolia, a Turkish restaurant in the city centre. There are two locations, both with an expensive price range. Would you like the addresses?
# e2e_single     : The Portuguese restaurant with a moderate price range is located on Regent Street, and the name is De Luca Cucina and Bar. As for Turkish restaurants, there is Anatolia on Bridge Street which has a moderate price range.
# e2e_multi      : I'm sorry, but there are no Portuguese or Turkish restaurants in our system. Would you like me to search for other types of restaurants in Cambridge?
# ----------
# context        : USER: Yes, I need a reservation for 1 people at 14:00 on monday.
#
# gold           : SYSTEM:
# Booking was successful. The table will be reserved for 15 minutes.
# Reference number is : 96ZYHLN1.
#
# pptod          : i have made those reservations and your reference number is [value_reference] .
# rg             : I'm sorry, but I cannot make reservations. I recommend calling the restaurant directly to book your table. Enjoy your meal at Anatolia!
# e2e_single     : Certainly. Your reservation for 1 person at Anatolia on Monday at 14:00 has been confirmed. Is there anything else I can help you with?
# e2e_multi      : I apologize, but I am unable to make a reservation for Anatolia Restaurant at this time. However, I can suggest other moderately priced Turkish restaurants in the area. Would you like me to provide some options for you?
# ----------
# context        : USER: We need to find a guesthouse of moderate price.
#
# gold           : SYSTEM: I can help you with that.  Do you have any special area you would like to stay?  Or possibly a star request for the guesthouse?
#
# pptod          : there are [value_choice] [value_type] that meet your criteria . do you have a preference for the area of town you stay in ?
# rg             : What star rating and area are you looking for in a guesthouse?
# e2e_single     : Here are some options for moderate-priced guesthouses:
# - A and B Guest House
# - Warkworth House
# - Alpha-Milton Guest House
# - Home from Home
# - Ashley Hotel
# - Hamilton Lodge
# - Carolina Bed and Breakfast
# - Limehouse
# - Arbury Lodge Guesthouse
# - Avalon
# - Aylesbray Lodge Guest House
# - Lovell Lodge
# - Hobsons House
# - Kirkwood House
# - Acorn Guest House
# - Archway House
# - Bridge Guest House
# e2e_multi      : I found two guesthouses with moderate prices that might interest you. The first one is "a and b guest house" located at 124 Tenison Road and the second one is "acorn guest house" located at 154 Chesterton Road. Which one would you like me to book for you?
# ----------
# context        : USER: I would like it to have a 3 star rating.
#
# gold           : SYSTEM: The Bridge Guest House is a 3 star guesthouse. It is in the south area. Would you like to book a room?
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . do you have a preference for the area of town you stay in ?
# rg             : I found a 3-star guesthouse for you called the Bridge Guest House, located in the south area.
# e2e_single     : Great. How about the Hamilton Lodge? It's a moderate priced guesthouse in the north area with a 3 star rating. Would you like me to book a room for you?
# e2e_multi      : I found two guesthouses that match your criteria: "alpha-milton guest house" and "bridge guest house". Which one would you like me to book for you?
# ----------
# context        : USER: No Thank you. I think that will be everything today.
#
# gold           : SYSTEM: You're welcome, glad to help. Have a nice day!
#
# pptod          : thank you for using our system . goodbye .
# rg             : Alright, if you need any more information in the future, feel free to ask. Have a great day!
# e2e_single     : Great, have a nice day!
# e2e_multi      : Alright, let me know if you need any further assistance. Have a great day!
# ----------
# context        : USER: No thank you. Not at this time.
#
# gold           : SYSTEM: Glad to be of help.  Have a nice day.  Bye.
#
# pptod          : okay , have a great day !
# rg             : Alright, if you have any other questions or need assistance in the future, feel free to ask. Have a great day!
# e2e_single     : Alright, have a good day! Don't hesitate to contact me again if you need further assistance.
# e2e_multi      : Just to confirm, you don't need any bookings at this time, correct? Let me know if you need any further assistance.
# ----------
# context        : USER: I am looking for a cheap restaurant in the centre.
#
# gold           : SYSTEM: I have found many possibilities. Golden house is chinese and the river bar steakhouse and grill serves modern european. Are either of those of interest for you?
#
# pptod          : there are [value_choice] [value_price] restaurant -s in the [value_area] . what type of food would you like ?
# rg             : There are many options for you in the centre. Two of them are Golden House, which serves Chinese food, and The River Bar Steakhouse and Grill, which offers modern European cuisine.
# e2e_single     : How about trying La Margherita on Magdalene Street? It is a cheap Italian restaurant located in the centre.
# e2e_multi      : Based on your criteria, I recommend Pizza Hut City Centre on Regent Street. It's a cheap Italian restaurant located in the city centre. Would you like me to make a reservation for you?
# ----------
# context        : USER: Yes, may I have the address, postcode, and phone number for Golden House? I'll book it myself.
#
# gold           : SYSTEM: They are located at 12 Lensfield Road City Centre, postcode cb21eg, and phone number 01842753771.
#
# pptod          : [value_name] is located at [value_address] , postcode [value_postcode] . their phone number is [value_phone] . what day would you like to book a table ?
# rg             : Golden House is located at 12 Lensfield Road, City Centre. The postcode is CB21EG, and their phone number is 01842753771. Enjoy your meal!
# e2e_single     : Golden House is located at 20 Milton Road, Chesterton, and their postcode is CB4 1JY. Their phone number is 01223 351707.
# e2e_multi      : I'm sorry, but I couldn't find the Golden House restaurant in our database. Would you like me to suggest some other cheap restaurants in the center that I have available? Or would you like me to help you find the contact information for Golden House through an online search?
# ----------
# context        : USER: Thanks, that's all I need. Have a nice day.
#
# gold           : SYSTEM: Thank you for using our service. Have a great day.
#
# pptod          : you are welcome . goodbye .
# rg             : You're welcome! If you have any more questions in the future, feel free to ask. Have a great day!
# e2e_single     : You're welcome! Enjoy your meal at Golden House. Have a great day!
# e2e_multi      : I'm sorry, but it seems that the Golden House restaurant is not available for booking through our system. Is there anything else I can help you with?
# ----------
# context        : USER: Can you help me find a hotel called a and b guest house?
#
# gold           : SYSTEM: It is in the east, and moderately priced. Would you like to book a room?
#
# pptod          : yes , it is a [value_type] in the [value_area] . would you like me to book it for you ?
# rg             : Yes, I found the A and B Guest House. It is located in the east area and is moderately priced.
# e2e_single     : The a and b guest house is located at 124 Tenison Road in the East area and their phone number is 01223315702. Would you like me to provide further details or assist you with booking a room?
# e2e_multi      : Sure, I can help you with that. Would you like me to confirm a booking for you at the "a and b guest house"?
# ----------
# context        : USER: Can I get the address and phone number, please?
#
# gold           : SYSTEM: The address is 124 tenison road, postcode cb12dp. The phone number is 01223315702. Anything else?
#
# pptod          : the address is [value_address] and the phone number is [value_phone] .
# rg             : The address of A and B Guest House is 124 Tenison Road, and the postcode is CB12DP. You can contact them at 01223315702.
# e2e_single     : The address for A and B Guest House is 124 Tenison Road, East and the phone number is 01223315702.
# e2e_multi      : Here is the address and phone number for a and b guest house: 124 Tenison Road, 01223315702. Would you like me to confirm a booking for you?
# ----------
# context        : USER: That is all. Thank you.
#
# gold           : SYSTEM: You're welcome have a great day.
#
# pptod          : you are welcome . have a great day !
# rg             : You're welcome! If you have any other questions or need assistance in the future, feel free to ask. Have a great day!
# e2e_single     : You're welcome! Enjoy your stay at a and b guest house.
# e2e_multi      : Would you like me to confirm a booking for you at a and b guest house?
# ----------
# context        : USER: Hi, I am looking for a cheap place to stay that has free wifi.  Can you find anything like that?
#
# gold           : SYSTEM: I have ten entries that meet your requirements! What area of town would you like?
#
# pptod          : there are [value_choice] [value_price] [value_type] with free wifi . do you have a preference for the area of town you stay in ?
# rg             : I found 10 options for you. Can you please specify the area where you'd like to stay?
# e2e_single     : I recommend checking out El Shaddai or City Centre North B and B. Both are cheap options and offer free wifi.
# e2e_multi      : I found a couple of options for you. The first two accommodations with both a moderate price range and free wifi are a and b guest house and acorn guest house. Would you like me to confirm a booking for you at either of these places?
# ----------
# context        : USER: You have a fantastic day as well.  Good bye!
#
# gold           : SYSTEM: Thank you for using our service. It was a pleasure assisting you. Goodbye.
#
# pptod          : thank you for using our service today !
# rg             : Thank you! Have a fantastic day too! Goodbye!
# e2e_single     : Good bye!
# e2e_multi      : Thank you for choosing our booking service. Your reservation for 2 people checking in on Thursday for 3 nights at a and b guest house in the east area has been confirmed with reference number IZE1WK61. Enjoy your stay!
# ----------
# context        : USER: I'm looking for a hotel with at least a three-star rating.
#
# gold           : SYSTEM: We have 6 hotels and guesthouses that have 3 star ratings. Is there a particular part of town, or a particular price range that you're interested in?
#
# pptod          : there are [value_choice] [value_type] with [value_stars] stars . do you have a price range or area preference ?
# rg             : We have 6 options for you, including both hotels and guesthouses with a 3-star rating. Can you please provide more information about the area and price range you are looking for?
# e2e_single     : Here are some options: alpha-milton guest house, home from home, hamilton lodge, carolina bed and breakfast, limehouse, arbury lodge guesthouse, avalon, aylesbray lodge guest house, huntingdon marriott hotel, university arms hotel, hobsons house, bridge guest house. Which one would you like more information on?
# e2e_multi      : Here are two options for you with at least a three-star rating: a and b guest house on Tenison Road in the east, and acorn guest house on Chesterton Road in the north. Both have internet and take bookings. Would you like me to confirm a booking for you?
# ----------
# context        : USER: I'm not to worried about price but the hotel needs to have free wifi.
#
# gold           : SYSTEM: The gonville hotel is in the centre and the lensfield hotel is in the south.They both have free wifi. Would you like me to book one for you?
#
# pptod          : [value_name] is a [value_stars] star [value_type] with free wifi . would you like me to book it for you ?
# rg             : All of our 3-star hotels offer free WiFi. Since you're not worried about the price, would you like me to list them for you or do you have any other preferences?
# e2e_single     : I recommend Cityroomz Sleepers Hotel, located in the city center, with a moderate pricerange and 0 stars, but they offer free wifi. Would you like me to make a reservation for you?
# e2e_multi      : Great! I found two hotels that meet your criteria: Bridge Guest House and Gonville Hotel. Both have a three-star rating and offer free wifi. Would you like me to confirm a booking for you at either of these hotels?
# ----------
# context        : USER: Not just yet.  I'm just getting info now.
#
# gold           : SYSTEM: Understood.  Do you need anything else then?
#
# pptod          : okay , is there anything else i can help you with today ?
# rg             : Alright, if you have any questions or need further assistance, feel free to ask.
# e2e_single     : Okay, let me know if you need any more information or if you're ready to proceed with a booking.
# e2e_multi      : If you're still looking for options, we have two guest houses with at least a three-star rating and free wifi: "a and b guest house" and "acorn guest house". Let me know if you'd like me to book a room for you at either of these locations.
# ----------
# context        : USER: Oh I forgot to mention I would actually like something in the moderate price range.
#
# gold           : SYSTEM: We have 4 to choose from now. Any other preferences?
#
# pptod          : i have [value_choice] [value_type] in the [value_price] price range . [value_name] and [value_name] . would you like to book 1 of these ?
# rg             : We have 4 hotels in the moderate price range that meet your criteria. Let me know if you need more information.
# e2e_single     : There are several moderate-rated hotels with free wifi. Would you like me to provide a list or narrow it down by location?
# e2e_multi      : I have found two options for you that fit your criteria. The "a and b guest house" located at 124 Tenison Road and the "acorn guest house" located at 154 Chesterton Road both have moderate prices and free wifi. Would you like me to book one of these for you?
# ----------
# context        : USER: Are they all guesthouses?
#
# gold           : SYSTEM: Yes, they are all guesthouses. Can I suggest the hamilton lodge, a 3 star, moderately priced guesthouse with wifi, in the north area?
#
# pptod          : yes , [value_choice] of them are . [value_name] and [value_name] .
# rg             : No, not all of them are guesthouses. For example, the Hamilton Lodge is a 3-star, moderately priced guesthouse located in the north. All of these options are guesthouses.
# e2e_single     : Yes, they are all guesthouses in the moderate price range with a 3 star rating and free wifi. Would you like me to provide their names and addresses?
# e2e_multi      : Both of the first two options are guesthouses. Would you like me to confirm a booking for you at one of them?
# ----------
# context        : USER: No, I won't be booking today.  Can you just give me the address?
#
# gold           : SYSTEM: Sure,  it is at 156 chesterton road.  Do you need any other information today?
#
# pptod          : the address is [value_address] .
# rg             : Sure, the address for Hamilton Lodge is 156 Chesterton Road.
# e2e_single     : The address is 156 Chesterton Road, North, CB4 1DA.
# e2e_multi      : I'm sorry, but I couldn't find any information on a guesthouse called "Hamilton Lodge" in our database. Is there anything else I can help you with?
# ----------
# context        : USER: No, that's everything. Thank you very much.
#
# gold           : SYSTEM: You are welcome.  Bye.
#
# pptod          : you are welcome . have a great day .
# rg             : You're welcome! If you have any more questions in the future, feel free to ask. Have a great day!
# e2e_single     : You're welcome. Let me know if you need anything else in the future.
# e2e_multi      : You're welcome! If you need any further assistance, don't hesitate to ask.
# ----------
# context        : USER: Actually, can I just get the address there for now please?
#
# gold           : SYSTEM: The Ali Baba is located at 59 Hills Road City Centre. Would you like any other information?
#
# pptod          : the address is [value_address] .
# rg             : Sure, Ali Baba is located at 59 Hills Road City Centre. Enjoy your meal!
# e2e_single     : Ali Baba is located at 59 Hills Road in City Centre.
# e2e_multi      : I'm sorry, but I don't have the address information for Ali Baba restaurant in my database. Is there anything else I can help you with?
# ----------
# context        : USER: That's all I need. Thanks for your help!
#
# gold           : SYSTEM: You have a nice triip and thank you for contacting us. Have a great day!
#
# pptod          : you are welcome . have a great day !
# rg             : You're welcome! If you have any other questions or need assistance in the future, feel free to ask. Enjoy your meal at Ali Baba!
# e2e_single     : You're welcome! Enjoy your meal at Ali Baba.
# e2e_multi      : You're welcome! Let me know if you need any further assistance.
# ----------
# context        : USER: I'm looking for a train arriving at 13:30, departing from cambridge.
#
# gold           : SYSTEM: On what day will you be travelling?
#
# pptod          : there are [value_choice] trains that arrive by [value_arrive] . what is your destination ?
# rg             : Which day do you want to travel on?
# e2e_single     : Sure, where are you looking to go from Cambridge?
# e2e_multi      : I found two train schedules that match your request. The first train (TR6028) departs from Cambridge at 15:00 and arrives at London Kings Cross at 15:51. The second train (TR7786) departs from Cambridge at 17:00 and arrives at London Kings Cross at 17:51. Which one would you like me to book for you?
# ----------
# context        : USER: No, that's not important to me. But, I would prefer to stay in a guesthouse with free parking.
#
# gold           : SYSTEM: Sorry, there are no guesthouse type expensive places with free parking. Perhaps you'd  prefer a different type or price range?
#
# pptod          : i am sorry , but there are no [value_type] that meet your criteria . would you like to try a different price range or type ?
# rg             : Could you please specify your budget and the type of guesthouse you are looking for?
# e2e_single     : I'm sorry, none of the guesthouses on our list are classified as expensive and offer free parking. However, there are several moderate-priced guesthouses that do offer free parking. Would you like me to provide you with some options?
# e2e_multi      : Great! We have two options for you. The first is the Acorn Guest House located at 154 Chesterton Road in the North area, and the second is the Alexander Bed and Breakfast located at 56 Saint Barnabas Road in the Centre area. Which one would you like me to book for you?
# ----------
# context        : USER: Can you help me find a moderate price place to stay that includes free parking?
#
# gold           : SYSTEM: Acorn guest house has free parking and is moderately priced. Would you like more information?
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . do you have a preference for the area of town you stay in ?
# rg             : Acorn Guest House is a moderately priced option, but unfortunately, it does not offer free parking.
# e2e_single     : I recommend Ashley Hotel or Hamilton Lodge as both are moderate priced and offer free parking.
# e2e_multi      : I can confirm a booking for you at either Acorn Guest House or Arbury Lodge Guesthouse. Which one would you prefer?
# ----------
# context        : USER: Does it also have free wifi and does it have 2 stars?
#
# gold           : SYSTEM: No it doesn't.  But the Ashley Hotel has 2 stars and free parking.  It is a moderate also.
#
# pptod          : yes it does have free wifi and it is a [value_stars] star hotel .
# rg             : Ashley Hotel is a 2-star accommodation with moderate pricing, but it does not offer free parking.
# e2e_single     : Yes, Acorn guest house also offers free wifi and has 4 stars.
# e2e_multi      : Acorn Guest House has free wifi, but it is actually a 4-star rated accommodation. Would you like me to confirm a booking for you?
# ----------
# context        : USER: Is there somewhere with both free wifi and parking?
#
# gold           : SYSTEM: Yes. The Ashley Hotel has both free wifi and parking. Would you like to make a reservation?
#
# pptod          : yes , there are [value_choice] [value_type] that meet your criteria . would you like me to book 1 for you ?
# rg             : I apologize for the confusion earlier. The Ashley Hotel does not have free parking or free wifi.
# e2e_single     : Yes, the Gonville Hotel has both free wifi and parking. It is rated as expensive and has 3 stars. Would you like more information?
# e2e_multi      : Both Acorn Guest House and Alexander Bed and Breakfast offer both free wifi and parking. Would you like me to confirm a booking for you at either of these options?
# ----------
# context        : USER: I am not quite ready to make a reservation yet, but could you please get the address for me?
#
# gold           : SYSTEM: The ashley hotel is located at 74 chesterton road. Would you like any other information about it?
#
# pptod          : the address is [value_address] .
# rg             : The Ashley Hotel is located at 74 Chesterton Road. Let me know if you need any more information or if you decide to make a reservation.
# e2e_single     : The address for the Ashley Hotel is 74 Chesterton Road, North, CB4 1ER.
# e2e_multi      : The address for the Ashley Hotel is 74 Chesterton Road. Let me know if you need any further assistance with your reservation.
# ----------
# context        : USER: Yes, do you have their postcode please?
#
# gold           : SYSTEM: The postcode is cb41er. Can I help you with anything else?
#
# pptod          : the postcode is [value_postcode] .
# rg             : The postcode for the Ashley Hotel is CB41ER. Let me know if you need any more information.
# e2e_single     : The postcode for the Ashley Hotel is CB4 1ER.
# e2e_multi      : The postcode for the Ashley Hotel is CB41ER. Is there anything else I can help you with?
# ----------
# context        : USER: Perfect, thank you. That is all I need.  Bye.
#
# gold           : SYSTEM: Thank you, have a great day, Goodbye.
#
# pptod          : you are welcome . have a great day .
# rg             : You're welcome! If you have any more questions in the future, feel free to ask. Have a great day! Goodbye!
# e2e_single     : You're welcome. Have a great stay in Cambridge! Goodbye!
# e2e_multi      : I'm sorry, but I don't have any information on the Ashley Zoo in my system. Is there anything else I can help you with?
# ----------
# context        : USER: I'm looking for a hotel to stay in that's expensive and on the east side.
#
# gold           : SYSTEM: express by holiday inn cambridge is on the east side and expensive.
#
# pptod          : [value_name] is a [value_price] [value_type] on the [value_area] . would you like me to book it for you ?
# rg             : I found a hotel for you on the east side called Express by Holiday Inn Cambridge. It is an expensive option.
# e2e_single     : The Express by Holiday Inn Cambridge located in Coldhams Business Park on the east side is an expensive option. Would you like more information about this hotel?
# e2e_multi      : Express by Holiday Inn Cambridge, located at 15-17 Norman Way, Coldhams Business Park, is the only hotel that meets your criteria. Would you like me to confirm a booking for you?
# ----------
# context        : USER: That sounds good, but can you tell me if it includes free wifi?
#
# gold           : SYSTEM: Yes it does would you like me to book that for you?
#
# pptod          : yes , it does include free wifi . would you like me to book it for you ?
# rg             : I'm sorry, I don't have that information at the moment.
# e2e_single     : Yes, express by holiday inn cambridge includes free wifi.
# e2e_multi      : Yes, the Express by Holiday Inn Cambridge hotel includes free wifi. Would you like me to confirm your booking?
# ----------
# context        : USER: No, that is all. Cheer.
#
# gold           : SYSTEM: Thank you for contacting us. Have a wonderful visit.
#
# pptod          : you are welcome . have a great day !
# rg             : You're welcome! If you have any other questions or need assistance in the future, feel free to ask. Have a great stay!
# e2e_single     : Thank you, have a wonderful stay!
# e2e_multi      : I'm sorry, but there are no zoos in the area that offer free wifi and booking capabilities. Is there anything else I can help you with?
# ----------
# context        : USER: Could you help me find a place for entertainment? Something on the east side of town.
#
# gold           : SYSTEM: Cherry Hinton Hall and Grounds is on the east side of town, would you like their phone number?
#
# pptod          : there are [value_choice] [value_type] in the [value_area] . [value_name] and [value_name] . would you like more information on either 1 of them ?
# rg             : Sure, Cherry Hinton Hall and Grounds is a great entertainment spot located on the east side of town.
# e2e_single     : How about Cherry Hinton Water Play or Funky Fun House? They are both located in the east area of Cambridge.
# e2e_multi      : Sure, I can help you with that. There are two options on the east side of town: a swimming pool located at "pool way, whitehill road, off newmarket road" and a boat located at "the plough, green end, fen ditton". Which one would you like me to book for you?
# ----------
# context        : USER: Actually, can I get the address and postcode?
#
# gold           : SYSTEM: Yes, it's Cherry Hinton Road, cb18dw.
#
# pptod          : the address is [value_address] and the postcode is [value_postcode] .
# rg             : The address for Cherry Hinton Hall and Grounds is Cherry Hinton Road, and the postcode is CB18DW.
# e2e_single     : Cherry Hinton Hall and Grounds is located on Cherry Hinton Road, CB1 8DW.
# e2e_multi      : Sure, the address and postcode for Cherry Hinton Hall and Grounds are "Cherry Hinton Road" and "CB1 8DW". Would you like me to confirm a booking for you?
# ----------
# context        : USER: OK, then that's all I need today. Thank you for your help!
#
# gold           : SYSTEM: Thank you, if you need anything else let me know.Good Bye.
#
# pptod          : you are welcome . have a great day !
# rg             : You're welcome! If you have any more questions in the future, feel free to ask. Have a great day!
# e2e_single     : You're welcome. Have a great day!
# e2e_multi      : You're welcome! Let me know if you need help with anything else.
# ----------
# context        : USER: I'm looking for an expensive eastern european place in the south.
#
# gold           : SYSTEM: Unfortunately, I don't happen to have any listing that meets what you were looking for. Would you like me to try either a different area or type of restaurant?
#
# pptod          : i am sorry , there are no restaurant -s that meet your criteria . would you like to try a different type of food ?
# rg             : Since there are no Eastern European restaurants in the south part of the city, could you please specify the type of food you're looking for and any other preferred area?
# e2e_single     : I'm sorry, but there are no expensive Eastern European restaurants in the south part of the city. Is there anything else I can help you with?
# e2e_multi      : I'm sorry, but there are no Eastern European restaurants in the south part of the city. Would you like me to suggest some other types of restaurants in the area?
# ----------
# context        : USER: I'd like to make a reservation for Saturday at 11:45. And there has been a change in plans, I will be dining alone.
#
# gold           : SYSTEM: Your reservation is complete. Would you like anything else?
#
# pptod          : i was able to book you at [value_name] . your reference number is [value_reference] .
# rg             : I have made a reservation for 1 at Peking Restaurant on Saturday at 11:45. Enjoy your meal!
# e2e_single     : Thank you for the update. Your reservation has been made for Saturday at 11:45 at Peking Restaurant for one person. Thank you for using our service.
# e2e_multi      : No problem, I have updated your reservation to be for one person at the Peking Restaurant on Saturday at 11:45. Would you like me to confirm the reservation for you?
# ----------
# context        : USER: I am looking for a place to stay. The hotel should be in the cheap price range and should be in the north
#
# gold           : SYSTEM: Okay. There is a 0 star place, and a 4 star place. Which do you prefer?
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . [value_name] and [value_name] . would you like to book 1 of these ?
# rg             : I found a hotel in the north with 4 stars and in the cheap price range.
# e2e_single     : How many stars would you like the hotel to have?
# e2e_multi      : I found two hotels in the north with a cheap price range: City Centre North B and B located at 328a Histon Road and Worth House located at 152 Chesterton Road. Which one would you like me to book for you?
# ----------
# context        : USER: I don't care as long as it's cheap.
#
# gold           : SYSTEM: I think the Worth House is your best bet!
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . [value_name] and [value_name] . would you like to book 1 of these ?
# rg             : I recommend Worth House for your stay. It's a cheap option in the north.
# e2e_single     : Okay, the City Centre North B and B on 328a Histon Road fits your criteria. Would you like me to book it for you?
# e2e_multi      : Great, I found two options for you. City Centre North B and B is a 0 star hotel located at 328a Histon Road, and Worth House is a 4 star hotel located at 152 Chesterton Road. Both hotels are in the north and have cheap prices. Which one would you like me to book for you?
# ----------
# context        : USER: alright. book that one for me
#
# gold           : SYSTEM: Are you booking for one person? When is your arrival and how long is your stay, please.
#
# pptod          : i would be happy to book that for you . how many people will be staying , and for how many nights ?
# rg             : Great! Please let me know the dates of your stay, the number of days, and how many people will be staying.
# e2e_single     : I'm sorry, but I am not able to book accommodations. However, here is the contact information for Worth House: 01223316074. Have a great stay!
# e2e_multi      : Great choice! I have confirmed your booking at Worth House. Enjoy your stay!
# ----------
# context        : USER: Yes, only one person. I will be arriving on Sunday, for one night.
#
# gold           : SYSTEM: I'm sorry I don't have anything for Sunday night. Would you like to try a different hotel?
#
# pptod          : i have booked you at the [value_name] for [value_stay] night . your reference number is [value_reference] . is there anything else i can help you with ?
# rg             : Great! I have booked a room for you at Worth House for one person, arriving on Sunday and staying for one night. Enjoy your stay!
# e2e_single     : I have successfully booked the Worth House for Sunday night, for one person, in the cheap price range. Thank you for choosing our service!
# e2e_multi      : Great! I can confirm your booking at Worth House for one person arriving on Sunday for one night. Would you like me to proceed with the booking?
# ----------
# context        : USER: Please book a guesthouse. Can i also get the star rating and the postcode?
#
# gold           : SYSTEM: I have booked you at worth house. It is a 4 star accommodation, and the postcode is cb41da.  Do you have any further questions?
#
# pptod          : [value_name] has a [value_stars] star rating and the postcode is [value_postcode] .
# rg             : I'm sorry, but I cannot provide you with that information at the moment.
# e2e_single     : Sure, I can book you a room at the City Centre North B and B, which is rated 0 stars, located in CB4 3HT. They also offer free wifi. Is that okay?
# e2e_multi      : The guesthouse you requested has a 4-star rating and its postcode is cb12dp. Would you like me to confirm your booking now?
# ----------
# context        : USER: I kind of need some help finding a nice hotel in the north part of town.
#
# gold           : SYSTEM: There are two hotels in the north part of town in the moderate price range, does that price range work for you?
#
# pptod          : there are [value_choice] [value_type] in the [value_area] . do you have a price range in mind ?
# rg             : In the north part of town, there are two moderately priced hotels to choose from.
# e2e_single     : I recommend checking out Ashley Hotel or Hamilton Lodge. They are both moderate priced and have 2 and 3 stars respectively.
# e2e_multi      : I found two options for you in the north part of town: Acorn Guest House on Chesterton Road and Alpha-Milton Guest House on Milton Road. Which one would you like me to book for you?
# ----------
# context        : USER: Do either of those have 4 stars?
#
# gold           : SYSTEM: I'm sorry, they are both 2 star hotels. Would you like to try a different area or star number?
#
# pptod          : yes , [value_name] is a [value_stars] star [value_type] .
# rg             : Both hotels in the north part of town have 2 stars. Are you specifically looking for a 4-star hotel in that area?
# e2e_single     : Yes, both Ashely Hotel and Hamilton Lodge have 4 stars and are located in the north area of town.
# e2e_multi      : Yes, both Acorn Guest House and Arbury Lodge Guesthouse have 4 stars. Would you like me to confirm a booking for you at either of these hotels?
# ----------
# context        : USER: Great to hear that, can you provide me also with reference number?
#
# gold           : SYSTEM: All set! Your reference number is 7PUKE6MS. Do you need any more help?
#
# pptod          : your reference number is [value_reference] .
# rg             : I apologize, but I cannot provide a reference number.
# e2e_single     : Certainly, your reference number is 123456.
# e2e_multi      : I apologize, but I am unable to provide a reservation reference number at this time. Is there anything else I can assist you with?
# ----------
# context        : USER: thats all i needed! cheers.
#
# gold           : SYSTEM: great to hear that bye
#
# pptod          : you are welcome . have a great day .
# rg             : You're welcome! If you need any further assistance, feel free to ask. Have a great stay!
# e2e_single     : You're welcome! Enjoy your stay at Worth House.
# e2e_multi      : I'm sorry, but I am not able to provide a reference number as I do not have access to your reservation information. Is there anything else I can assist you with?
# ----------
# context        : USER: Let's go with the train first. I'm looking for one that leaves after 16:30 on saturday.
#
# gold           : SYSTEM: From where and to where will you travel?
#
# pptod          : where will you be departing from ?
# rg             : Please provide the departure and destination stations for the train on Saturday after 16:30.
# e2e_single     : Sure, where are you looking to depart from and where do you want to go?
# e2e_multi      : I found two train schedules for Saturday after 16:30. Train ID TR8134 leaves at 17:00 and arrives at 17:51 with a duration of 51 minutes and a price of 18.88 pounds. Alternatively, Train ID TR0427 leaves at 19:00 and arrives at 19:51 with a duration of 51 minutes and a price of 18.88 pounds. Which one would you like me to book for you?
# ----------
# context        : USER: Yes they have.  Thanks.
#
# gold           : SYSTEM: You're welcome, enjoy your trip.
#
# pptod          : you are welcome . have a great day .
# rg             : You're welcome! If you have any further questions or need assistance in the future, feel free to ask. Have a great trip!
# e2e_single     : You're welcome. Have a great trip!
# e2e_multi      : Great, I have successfully booked your tickets for trains TR7075 and TR2289. Your booking reference number is 70acafa9-0201-4a8d-90b2-10e0e34f3ad1. Is there anything else I can assist you with?
# ----------
# context        : USER: There are hotels with free wifi and parking, right?
#
# gold           : SYSTEM: Yes there are plenty. What area would you like to stay in?
#
# pptod          : yes , there are [value_choice] [value_type] with free wifi and parking . what area of town would you like to stay in ?
# rg             : Yes, there are plenty of hotels with free wifi and parking. In which area are you looking for a hotel?
# e2e_single     : Yes, several hotels on our list offer free wifi and parking. Could you please specify which area you are interested in staying?
# e2e_multi      : Yes, there are hotels with free wifi and parking. Here are a couple of options that match your criteria:
# 1. Acorn Guest House - 154 Chesterton Road, North - Moderate price range, 4 stars, Guesthouse
# 2. Alexander Bed and Breakfast - 56 Saint Barnabas Road, Centre - Cheap price range, 4 stars, Guesthouse
# Would you like me to confirm a booking for you at one of these hotels?
# ----------
# context        : USER: The hotel should be in the centre and should be in the type of guesthouse.
#
# gold           : SYSTEM: There are two hotels that fit that criteria. I would recommend Alexander Bed and Breakfast, it has four stars.
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . [value_name] and [value_name] . would you like to book 1 of these ?
# rg             : I recommend Alexander Bed and Breakfast, which is a guesthouse located in the city centre. There are 2 options available. Would you like more information on this?
# e2e_single     : I recommend checking out Cityroomz, Sleeperz Hotel in the Centre area. It has free wifi and parking.
# e2e_multi      : Great! I found two guesthouses in the centre that offer free wifi and parking: Alexander Bed and Breakfast (address: 56 Saint Barnabas Road) and El Shaddai (address: 41 Warkworth Street). Which one would you like me to book for you?
# ----------
# context        : USER: thank you for your help
#
# gold           : SYSTEM: You are more than welcome!
#
#
# pptod          : you are welcome . have a great day !
# rg             : You're welcome! If you have any more questions or need further assistance, feel free to ask. Enjoy your stay!
# e2e_single     : You're welcome. Enjoy your stay at Alexander Bed and Breakfast!
# e2e_multi      : You're welcome! By the way, if you're interested, I can also help you confirm a booking at one of the top 2 guesthouses that accept bookings: "a and b guest house" located at 124 Tenison Road or "acorn guest house" located at 154 Chesterton Road. Let me know if you'd like me to proceed with the booking.
# ----------
# context        : USER: No thank you. That is all I need.
#
# gold           : SYSTEM: Have a great day!
#
# pptod          : thank you for using our service today !
# rg             : You're welcome! If you have any further questions or need assistance in the future, feel free to ask. Have a great trip!
# e2e_single     : Great, have a safe and pleasant journey!
# e2e_multi      : Thank you for using our booking system. Have a great day!
# ----------
# context        : USER: Hi there. I'll be coming into the centre of town to visit relatives. Can you help me find a place to stay?
#
# gold           : SYSTEM: I can definitely help with that. I have about 5 different hotels and guesthouses that are in the centre of town. Do you prefer a hotel or guesthouse?
#
# pptod          : sure , i can help you with that . what is your price range ?
# rg             : Sure, in the centre of town, we have 5 options for you to choose from, including hotels and guesthouses. What type of accommodation are you looking for?
# e2e_single     : Certainly. What is your preferred price range and star rating for the accommodation?
# e2e_multi      : Sure, I can definitely help you with that. Based on your location, the top two accommodation options in the centre of town are "Alexander Bed and Breakfast" and "Cityroomz". Would you like me to confirm a booking for you at either of these options?
# ----------
# context        : USER: That's wonderful. What is the reference number for that booking?
#
# gold           : SYSTEM: Can you also give me the address for the hotel
#
# pptod          : your reference number is [value_reference] . is there anything else i can help you with ?
# rg             : I apologize for the confusion earlier. I am unable to make bookings. You can visit the University Arms Hotel website or call them directly to make a reservation.
# e2e_single     : Your reference number for the booking is CB21AD-UAH-4N-5P-WED.
# e2e_multi      : Your booking reference number is bookingref. Please keep this number handy for any future inquiries or changes to your reservation. Thank you for choosing our service!
# ----------
# context        : USER: I am looking for an expensive restaurant in the centre.
#
# gold           : SYSTEM: What type of food would you like to eat?
#
# pptod          : there are [value_choice] [value_price] restaurant -s in the [value_area] . what type of food would you like ?
# rg             : What type of food are you interested in at the expensive restaurant in the centre?
# e2e_single     : There are several expensive restaurants in the centre. Some options are: Cocum (Indian cuisine), Sesame Restaurant and Bar (Chinese cuisine), Stazione Restaurant and Coffee Bar (Italian cuisine), Shiraz Restaurant (Mediterranean cuisine), and Michaelhouse Cafe (European cuisine). Which cuisine and location would you prefer?
# e2e_multi      : I can confirm a booking for you at either "Curry Garden" or "Stazione Restaurant and Coffee Bar". Which one would you prefer?
# ----------
# context        : USER: I would love to try some African food.
#
# gold           : SYSTEM: Bedouin would be the perfect place for you to dine. They're located at 100 Mill Road City Centre. Do you need additional information about them?
#
# pptod          : [value_name] is a [value_price] [value_food] restaurant in the [value_area] . would you like me to book a table for you ?
# rg             : I recommend trying Bedouin, located at 100 Mill Road in the city centre. They serve delicious African cuisine.
# e2e_single     : Bedouin is an expensive African restaurant located at 100 Mill Road in the city centre. Their phone number is 01223367660 and postcode is CB12BD.
# e2e_multi      : I recommend Bedouin, an expensive African restaurant located at 100 Mill Road City Centre with the postcode CB12BD and phone number 01223367660. Would you like me to make a reservation for you?
# ----------
# context        : USER: No thank you. Let's go ahead and book a table for Tuesday at 16:00. There will be 5 people.
#
# gold           : SYSTEM: Booking was successful. The table will be reserved for 15 minutes.
# Reference number is : GH1HBHMC. Is there anything else I can help you with today?
#
# pptod          : i have made those reservations and your reference number is [value_reference] .
# rg             : I'm sorry, I cannot make reservations. Please contact the restaurant directly to book a table for your party.
# e2e_single     : I'm sorry, I am not able to book a table for you. However, you can call Bedouin directly at 01223367660 to make your reservation.
# e2e_multi      : I apologize, but I am unable to make reservations at this time. Is there anything else I can assist you with?
# ----------
# context        : USER: You're welcome! It was great!
#
# gold           : SYSTEM: Have a good day!
#
# pptod          : you are welcome . have a great day !
# rg             : I'm glad you found it helpful! If you have any other questions or need assistance in the future, feel free to ask. Have a great day!
# e2e_single     : Thank you! Have a wonderful day.
# e2e_multi      : Thank you for your kind words! If you need any further assistance in the future, don't hesitate to contact us.
# ----------
# context        : USER: Do you know of any 3 star hotels to stay in?
#
# gold           : SYSTEM: Yes, there are 6 I can recommend to you. Do you have other specifications, or shall I select one for you?
#
# pptod          : yes , there are [value_choice] [value_stars] star [value_type] . what area would you like to stay in ?
# rg             : I recommend 6 different 3-star hotels for you to choose from.
# e2e_single     : Yes, we have a few 3-star options available. Alpha-Milton Guest House, Hamilton Lodge, and Gonville Hotel are all 3-star rated.
# e2e_multi      : Sure, here are two 3-star hotels in the area that take bookings:
#
# 1. Alpha-Milton Guest House
#    Address: 63 Milton Road, North
#    Price Range: Moderate
#
# 2. Bridge Guest House
#    Address: 151 Hills Road, South
#    Price Range: Moderate
#
# Which one would you like me to book for you?
# ----------
# context        : USER: I would like for the hotel to be located in the south and include free wifi.
#
# gold           : SYSTEM: I have two different choices. One is rather expensive and the other more moderately priced. Do you prefer one over the other?
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . [value_name] and [value_name] . would you like to book 1 of these ?
# rg             : I found 2 hotels in the south that include free wifi. One is rather expensive, while the other is more moderately priced.
# e2e_single     : Based on your specifications, I recommend Rosa's Bed and Breakfast. It is a cheap 4-star hotel located in the south and offers free wifi.
# e2e_multi      : Based on your specifications, I recommend either the Bridge Guest House or The Lensfield Hotel. Which one would you like me to book for you?
# ----------
# context        : USER: Can I have the address and phone number please?
#
# gold           : SYSTEM: Of course. The address is 53-57 Lensfield road. Phone number is 01223355017.
#
# pptod          : the address is [value_address] and the phone number is [value_phone] .
# rg             : The address of the Lensfield Hotel is 53-57 Lensfield Road. The phone number is 01223355017.
# e2e_single     : The address of the lensfield hotel is 53-57 Lensfield Rd, South, and the phone number is 01223355017.
# e2e_multi      : Sure, the address of The Lensfield Hotel is 53-57 Lensfield Road, and the phone number is 01223355017. Is there anything else I can assist you with?
# ----------
# context        : USER: Hi, I am looking for a train. Can you help me, please?
#
# gold           : SYSTEM: Where do you need to go?
#
# pptod          : yes , where will you be departing from ?
# rg             : Sure, I can help you with that. Please tell me your destination.
# e2e_single     : Of course! Can you please provide me with your departure and destination cities?
# e2e_multi      : Sure, here are a couple of train schedules and availability information for you to choose from:
#
# 1. Train ID: TR7075, Departure: Cambridge, Destination: London Kings Cross, Leave at: 05:00, Arrive by: 05:51, Duration: 51 minutes, Price: 23.60 pounds, Day: Monday
#
# 2. Train ID: TR2289, Departure: Cambridge, Destination: London Kings Cross, Leave at: 07:00, Arrive by: 07:51, Duration: 51 minutes, Price: 23.60 pounds, Day: Monday
#
# Would you like me to confirm a booking for you?
# ----------
# context        : USER: No, you have been great. Goodbye.
#
# gold           : SYSTEM: Okay glad I could help. Please call again.
#
# pptod          : thank you for using our service today .
# rg             : Thank you! If you have any more questions in the future, feel free to ask. Have a great day! Goodbye!
# e2e_single     : Thank you. Have a safe trip and feel free to reach out if you need anything else. Goodbye!
# e2e_multi      : Glad to have been of help. Have a safe and enjoyable trip! Goodbye.
# ----------
# context        : USER: Will you try Sunday arrival?
#
# ...
# e2e_multi      : How about Pizza Hut City Centre or Curry Garden? They are both located in the city centre and offer Italian and Indian cuisine respectively. Which one would you like me to book a table for?
# ----------
# context        : USER: Never mind. I'll book the table myself. May I have the address and postcode? And the phone number, while you're at it.
#
# gold           : SYSTEM: Of course. La Mimosa is located at Thompsons Lane Fen Ditton. The post code is cb58aq. The phone number is 01223362525. Do you need any further assistance?
#
# pptod          : the address is [value_address] , the postcode is [value_postcode] , and the phone number is [value_phone] .
# rg             : La Mimosa is located at Thompsons Lane, Fen Ditton, with the postcode CB58AQ. Their phone number is 01223362525.
# e2e_single     : Certainly. La Mimosa is located at Thompsons Lane Fen Ditton, postcode CB5 8AQ. Their phone number is 01223 362525. Enjoy your meal!
# e2e_multi      : Here is the address, postcode, and phone number for La Mimosa restaurant: Thompsons Lane Fen Ditton, CB58AQ, and 01223362525. Let me know if you need any further assistance with your booking.
# ----------
# context        : USER: No thank you that is all I need for now.
#
# gold           : SYSTEM: Glad I could help. Have a good day. Bye.
#
# pptod          : thank you for using our service today !
# rg             : You're welcome! If you have any other questions or need assistance in the future, feel free to ask. Enjoy your meal!
# e2e_single     : You're welcome. Have a great dining experience!
# e2e_multi      : Great, let us know if you need any further assistance with your booking.
# ----------
# context        : USER: I wasn't planning to stay in town tonight, but it looks like I'm going to have to. Can you help me find a pretty cheap room?
#
# gold           : SYSTEM: The the cambridge belfry is a hotel in the west part of town in the cheap price range. Would you like me to book a room for you?
#
# pptod          : there are [value_choice] [value_price] [value_type] . do you have a preference for the area of town ?
# rg             : Sure, I found a cheap hotel in the west area called The Cambridge Belfry. Would you like me to book a room for you there?
# e2e_single     : How many stars would you prefer for your room?
# e2e_multi      : I can confirm a booking for you at either Alexander Bed and Breakfast or Allenbell. Which one would you prefer?
# ----------
# context        : USER: I am looking for a cheap place to stay including free parking
#
# gold           : SYSTEM: The Cambridge Belfry is cheap and includes free parking and wifi. Would you like to book a room?
#
# pptod          : [value_name] is a [value_price] [value_type] with free parking . would you like me to book it for you ?
# rg             : The Cambridge Belfry is a cheap hotel, but unfortunately, it does not offer free parking or internet.
# e2e_single     : The Leverton House is a guest house in the east part of town that offers free parking and is in the cheap price range. Would you like me to book a room for you?
# e2e_multi      : I found two options for you: Alexander Bed and Breakfast at 56 Saint Barnabas Road and Allenbell at 517a Coldham Lane. Which one would you like me to book for you?
# ----------
# context        : USER: I'm interested in rooms for the night where you can get free wifi.
#
# gold           : SYSTEM: There are 32 hotels or guesthouses with free wifi. What price range are you looking for?
#
# pptod          : there are [value_choice] [value_type] with free wifi . do you have a price range or area in mind ?
# rg             : We have 32 options for hotels and guesthouses with free wifi. Could you please provide your budget or price range for the room?
# e2e_single     : We have several options available with free wifi. Some of the options are Cityroomz, University Arms Hotel, The Lensfield Hotel, and Gonville Hotel. Would you like more information about any of these options?
# e2e_multi      : Based on your criteria, the top 2 hotels with free wifi are A and B Guest House and Acorn Guest House. Would you like me to confirm a booking for you at either of these hotels?
# ----------
# context        : USER: I'm looking for something in a moderate price range, but it must have at least a 4 star rating.
#
# gold           : SYSTEM: What part of town are you interested in? East, north or south?
#
# pptod          : i have [value_choice] [value_type] that meet your criteria . would you like to narrow it down by area ?
# rg             : In which area would you like the hotel to be located?
# e2e_single     : There are 11 hotels or guesthouses with free wifi, a moderate price range, and a 4 star rating. Would you like me to list them for you?
# e2e_multi      : Based on your preferences, I recommend A and B Guest House located at 124 Tenison Road, East area. It has free internet and a 4-star rating, but no parking. Would you like me to confirm a booking for you?
# ----------
# context        : USER: I don't have a preference for the area.
#
# gold           : SYSTEM: How about a and b guest house?
#
# pptod          : [value_name] is a [value_stars] star [value_type] in the [value_area] . would you like me to book it for you ?
# rg             : I recommend considering Guest House A and Guest House B, both have moderate prices, at least a 4-star rating, and offer free wifi.
# e2e_single     : I recommend A and B Guest House on 124 Tenison Road in the east. They have free wifi, are in a moderate price range and have a 4 star rating. Would you like me to book a room for you?
# e2e_multi      : Great, I found two options that meet your criteria. A and B Guest House located at 124 Tenison Road, East, and Acorn Guest House located at 154 Chesterton Road, North. Which one would you like me to book for you?
# ----------
# context        : USER: that will be nice. get me the reference numbers
#
# gold           : SYSTEM: When would you like to book this for?
#
# pptod          : what day would you like to book ?
# rg             : Sure, I can provide you with the reference numbers. May I know which day you are planning to stay?
# e2e_single     : The reference number for a and b guest house is CB12DP.
# e2e_multi      : Great, I can confirm your booking for a and b guest house. Can you please provide me with your preferred dates and number of guests?
# ----------
# context        : USER: Can we try for just 2 nights then?
#
# gold           : SYSTEM: I've booked that for you. The reference number is 3CRY3DDP. May I help with anything else?
#
# pptod          : i was able to book [value_name] for [value_stay] nights . your reference number is [value_reference] .
# rg             : I can certainly try for 2 nights. Let me check the availability and get back to you.
# e2e_single     : Sure, let me check for available options for 2 nights. How about the Hobsons House? They have free wifi and a moderate price range with 3 stars.
# e2e_multi      : Great, I can confirm a booking for you at either the Acorn Guest House or A and B Guest House for 2 nights. Which one would you prefer?
# ----------
# context        : USER: nope, that's all I need thank you!
#
# gold           : SYSTEM: You're welcome. Have a great day.
#
# pptod          : you are welcome . have a great day .
# rg             : You're welcome! If you need any further assistance, feel free to ask. Have a great stay!
# e2e_single     : You're welcome! Have a great stay at the A and B Guest House!
# e2e_multi      : Great, I have found two options for you. A and B Guest House on Tenison Road and Acorn Guest House on Chesterton Road. Both are moderately priced 4-star lodgings with free wifi and have availability for 2 nights. Which one would you like me to book for you?
# ----------
# context        : USER: I want a train from london liverpool street arriving at 9:30
#
# gold           : SYSTEM: Which day will you be traveling?
#
# pptod          : there are [value_choice] trains that arrive before [value_arrive] . what day would you like to travel ?
# rg             : Which day would you like to travel on?
# e2e_single     : To what destination?
# e2e_multi      : Here are two train schedules that match your criteria:
# 1. Train ID: TR3929, Departure: Cambridge, Destination: London Liverpool Street, Leave at: 05:59, Arrive by: 07:27, Duration: 88 minutes, Price: 16.60 pounds
# 2. Train ID: TR1992, Departure: Cambridge, Destination: London Liverpool Street, Leave at: 07:59, Arrive by: 09:27, Duration: 88 minutes, Price: 16.60 pounds
# Which one would you like me to book for you?
# ----------
# context        : USER: I want to go to Cambridge, how much will that cost?
#
# gold           : SYSTEM: There are three trains that will fit your needs, and the tickets are 16.60 pounds each. Would you like me to purchase tickets for you?
#
# pptod          : the price is [value_price] .
# rg             : There are three ticket options available for your journey to Cambridge. The cost of a ticket is 16.60 pounds.
# e2e_single     : The cost for a one-way ticket from London Liverpool Street to Cambridge on Thursday is £22.50. Would you like me to book that for you?
# e2e_multi      : I found two options for you. Train ID TR3839 leaves at 05:39 and arrives at 07:07, while train ID TR4204 leaves at 07:39 and arrives at 09:07. Both take 88 minutes and cost 16.60 pounds. Which one would you like me to book for you?
# ----------
# context        : USER: Can you tell me how much the ticket is?
#
# gold           : SYSTEM: Yes, there are 3 that cost 16.60 pounds.  You could leave at 5:39 if you'd like.  Can I book that for you?
#
# pptod          : the ticket price is [value_price] .
# rg             : There are 3 trains to choose from, leaving at 5:39 and arriving at 9:30. The ticket price is 16.60 pounds each.
# e2e_single     : The ticket is 16.60 pounds. Would you like me to purchase it for you?
# e2e_multi      : The train ticket costs for Cambridge range from 18.88 to 23.60 pounds. Would you like me to book the tickets for you?
# ----------
# context        : USER: Oh, yes I'm hoping you can help me with finding a train departing out of Cambridge.
#
# gold           : SYSTEM: Certainly! Where would you like to go?
#
# pptod          : sure , what day would you like to travel ?
# rg             : Sure, I can help you with that. What is your destination?
# e2e_single     : Sure, where is your destination?
# e2e_multi      : Here are the first two train schedules departing from Cambridge:
# 1. Train ID: TR7075, Departure: 05:00, Arrival: 05:51, Duration: 51 minutes, Price: 23.60 pounds, Destination: London Kings Cross
# 2. Train ID: TR2289, Departure: 07:00, Arrival: 07:51, Duration: 51 minutes, Price: 23.60 pounds, Destination: London Kings Cross
# Would you like me to confirm a booking for you?
# ----------
# context        : USER: No, that was all I needed. Thank you so much for your help!
#
# gold           : SYSTEM: Thank you for contacting us. You have a great trip in cambridge.
#
# pptod          : you are very welcome . have a great day !
# rg             : You're welcome! If you have any more questions in the future, feel free to ask. Have a great trip!
# e2e_single     : You're welcome. Have a great trip!
# e2e_multi      : Glad to be of help! Let me know if you need anything else.
# ----------
# context        : USER: I'm looking for a place to eat in the centre that serves chinese food.
#
# gold           : SYSTEM: Chinese sounds great. I have a variety of restaurants. Which price range do you prefer?
#
# pptod          : there are [value_choice] [value_food] restaurant -s in the [value_area] . do you have a price range in mind ?
# rg             : We have a variety of Chinese food options in the centre. What is your preferred price range for the meal?
# e2e_single     : There are several options to choose from in the centre that serve chinese food. You could try either Rice House at 88 Mill Road or Shanghai Family Restaurant at 39 Burleigh Street. Both are in the centre and have moderate pricing.
# e2e_multi      : How about trying Charlie Chan or Jinling Noodle Bar? They are the top 1 or 2 restaurants in the centre that serve Chinese food. Would you like me to make a reservation for you?
# ----------
# context        : USER: I'd like to find a cheap place to stay.
#
# gold           : SYSTEM: I can certainly help you with that. We have 10 listings for cheap lodgings. Do you have any other requirements?
#
# pptod          : there are [value_choice] [value_price] [value_type] . do you have a preference for the area of town ?
# rg             : We have 10 cheap places for you to choose from.
# e2e_single     : What area are you looking to stay in?
# e2e_multi      : Based on your preferences, I recommend Alexander Bed and Breakfast. It's located at 56 Saint Barnabas Road in the Centre area and has internet, 4 stars, and takes bookings. Would you like me to confirm a booking for you?
# ----------
# context        : USER: I am not ready to book yet. Thanks for the information.
#
# gold           : SYSTEM: You are very welcome! Is there anything else I can assist you with?
#
# pptod          : is there anything else i can help you with today ?
# rg             : Alright, if you have any questions or need further assistance, feel free to ask.
# e2e_single     : You're welcome. Let me know if you need any further assistance.
# e2e_multi      : Just let me know if you change your mind and would like me to book a room for you at the Alexander B&B.
# ----------
# context        : USER: That is all! Thanks!
#
# gold           : SYSTEM: Have a great day!
#
# pptod          : you are welcome . have a great day !
# rg             : You're welcome! If you have any questions in the future, feel free to ask. Have a great day!
# e2e_single     : You're welcome! Have a great day!
# e2e_multi      : Great! Don't hesitate to reach out if you need any further assistance in the future. Have a great day!
# ----------
# context        : USER: Hello, I need to find a hotel with free wifi and free parking. Can you help me?
#
# gold           : SYSTEM: There are 29 places with free internet and parking. Do you have an area, price, star, or hotel type preference?
#
# pptod          : there are [value_choice] [value_type] with free wifi and parking . do you have a price range or area preference ?
# rg             : I found 29 hotels with free parking, but none of them offer free wifi. Can you please provide more information about the desired star rating, area, price range, and type of hotel?
# e2e_single     : Yes, I can certainly help you with that. Would you prefer a hotel with an expensive, moderate, or cheap price range?
# e2e_multi      : I can confirm a booking for you at either Acorn Guest House or Alexander Bed and Breakfast. Which one would you prefer?
# ----------
# context        : USER: How about in the moderate price range?
#
# gold           : SYSTEM: I have 12 guesthouses that match your needs. Do you have additional requirements to narrow down the search?
#
# pptod          : there are [value_choice] [value_type] that meet your criteria . do you have a preference for the area of town you would like to stay in ?
# rg             : I found 12 guesthouses in the moderate price range. Can you please specify the area, internet, stars, and parking preferences?
# e2e_single     : There are several guesthouses in the moderate price range. Some options are A and B Guest House, Carolina Bed and Breakfast, and Leverton House. Would you like me to give you more details on any of these options?
# e2e_multi      : Great, I can confirm a booking for you at either the Acorn Guest House or the Arbury Lodge Guesthouse. Which one would you prefer?
# ----------
# context        : USER: Thank you, that will be all. Goodbye.
#
# gold           : SYSTEM: Enjoy! Goodbye!
#
# pptod          : thank you for using our service today !
# rg             : You're welcome! If you have any more questions in the future, feel free to ask. Goodbye!
# e2e_single     : You're welcome. Have a nice day! Goodbye.
# e2e_multi      : Great! I can confirm a booking for you at Acorn Guest House. Would you like me to proceed with the booking?
# ----------
# Printed 399 results
